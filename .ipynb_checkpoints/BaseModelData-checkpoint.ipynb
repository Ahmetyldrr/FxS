# %%
import http.client
import pandas as pd
import json
from datetime import datetime, timedelta
import ssl

def ApiFiksturModel(date):
    
    context = ssl._create_unverified_context()
    conn = http.client.HTTPSConnection('www.sofascore.com', context=context)  # SSL doğrulaması devre dışı
    conn.request(
        'GET',
        f'/api/v1/sport/football/scheduled-events/{date}'
    )
    response = conn.getresponse()
    data = response.read()
    data = json.loads(data)["events"]
    df = pd.DataFrame(data)
    df_exploded = df.explode('data')
    expanded_data = pd.json_normalize(df_exploded['data'])

    model_data = [{
        'data_id':date.replace("-",""),
        'tarih': date,
        'data': data,
        'count':len(expanded_data),
        'isprogress':False
    }]
   
    return model_data

data = ApiFiksturModel("2024-10-21")
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'data'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 32
#      22     model_data = [{
#      23         'data_id':date.replace("-",""),
#      24         'tarih': date,
#    (...)
#      27         'isprogress':False
#      28     }]
#      30     return model_data
# ---> 32 data = ApiFiksturModel("2024-10-21")
#      33 data
#
# Cell In[9], line 19, in ApiFiksturModel(date)
#      17 data = json.loads(data)["events"]
#      18 df = pd.DataFrame(data)
# ---> 19 df_exploded = df.explode('data')
#      20 expanded_data = pd.json_normalize(df_exploded['data'])
#      22 model_data = [{
#      23     'data_id':date.replace("-",""),
#      24     'tarih': date,
#    (...)
#      27     'isprogress':False
#      28 }]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:9543, in DataFrame.explode(self, column, ignore_index)
#    9541 df = self.reset_index(drop=True)
#    9542 if len(columns) == 1:
# -> 9543     result = df[columns[0]].explode()
#    9544 else:
#    9545     mylen = lambda x: len(x) if (is_list_like(x) and len(x) > 0) else 1
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'data'

# %%
import os
import django
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'Home.settings')
django.setup()
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
from basemodels.models import FikstureModelData

def save_fixtures_to_db(api_data):
    for item in api_data:
        # Tarih'e göre zaten kayıt olup olmadığını kontrol et
        existing_entry = FikstureModelData.objects.filter(tarih=item['tarih']).first()

        if not existing_entry:
            # Eğer o tarihe ait veri yoksa, yeni kayıt ekle
            FikstureModelData.objects.create(
                data_id=item['data_id'],
                tarih=item['tarih'],
                data=item['data'],
                count = item["count"],
                isprogress=item['isprogress']
            )
            print(f"Veri eklendi: {item['tarih']}")
        else:
            print(f"Bu tarihe ait veri zaten mevcut: {item['tarih']}")

# Api'den gelen veriyi kaydet
data = ApiFiksturModel("2024-10-21")
save_fixtures_to_db(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'data'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 22
#      19             print(f"Bu tarihe ait veri zaten mevcut: {item['tarih']}")
#      21 # Api'den gelen veriyi kaydet
# ---> 22 data = ApiFiksturModel("2024-10-21")
#      23 save_fixtures_to_db(data)
#
# Cell In[5], line 19, in ApiFiksturModel(date)
#      17 data = json.loads(data)["events"]
#      18 df = pd.DataFrame(data)
# ---> 19 df_exploded = df.explode('data')
#      20 expanded_data = pd.json_normalize(df_exploded['data'])
#      22 model_data = [{
#      23     'data_id':date.replace("-",""),
#      24     'tarih': date,
#    (...)
#      27     'isprogress':False
#      28 }]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:9543, in DataFrame.explode(self, column, ignore_index)
#    9541 df = self.reset_index(drop=True)
#    9542 if len(columns) == 1:
# -> 9543     result = df[columns[0]].explode()
#    9544 else:
#    9545     mylen = lambda x: len(x) if (is_list_like(x) and len(x) > 0) else 1
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'data'

# %%
df = pd.DataFrame(data)
df_exploded = df.explode('data')
expanded_data = pd.json_normalize(df_exploded['data'])
expanded_data
# Out:
#       customId  winnerCode  hasGlobalHighlights hasEventPlayerStatistics  \
# 0          dsr         2.0                 True                     True
# 1          NsU         1.0                 True                     True
# 2          hso         NaN                False                      NaN
# 3      tgbsBgb         1.0                 True                     True
# 4      LgbsVgb         1.0                 True                     True
# ..         ...         ...                  ...                      ...
# 328  gRqbsXCmc         NaN                False                      NaN
# 329   iQrsROke         1.0                 True                      NaN
# 330    nkpskQr         1.0                 True                      NaN
# 331    nNosnQr         1.0                 True                      NaN
# 332   rlpsJIdb         2.0                 True                      NaN
#
#     hasEventPlayerHeatMap  detailId  crowdsourcingDataDisplayEnabled  \
# 0                    True       1.0                            False
# 1                    True       1.0                            False
# 2                     NaN       1.0                            False
# 3                    True       1.0                            False
# 4                    True       1.0                            False
# ..                    ...       ...                              ...
# 328                   NaN       NaN                            False
# 329                   NaN       NaN                            False
# 330                   NaN       NaN                            False
# 331                   NaN       NaN                            False
# 332                   NaN       NaN                            False
#
#            id  startTimestamp                              slug  ...  \
# 0    12437039      1729429200     manchester-city-wolverhampton  ...
# 1    12437032      1729438200                 liverpool-chelsea  ...
# 2    12437036      1729537200  nottingham-forest-crystal-palace  ...
# 3    12437847      1729425600           mallorca-rayo-vallecano  ...
# 4    12437835      1729433700           leganes-atletico-madrid  ...
# ..        ...             ...                               ...  ...
# 328  12872194      1729537200   cardiff-city-u21-cardiff-met-fc  ...
# 329  12464034      1729454400         kenya-u17-north-korea-u17  ...
# 330  12464033      1729465200            mexico-u17-england-u17  ...
# 331  12464080      1729454400              brazil-u17-japan-u17  ...
# 332  12464079      1729465200             zambia-u17-poland-u17  ...
#
#      tournament.isGroup  tournament.isLive  roundInfo.name  \
# 0                   NaN                NaN             NaN
# 1                   NaN                NaN             NaN
# 2                   NaN                NaN             NaN
# 3                   NaN                NaN             NaN
# 4                   NaN                NaN             NaN
# ..                  ...                ...             ...
# 328                 NaN                NaN   Quarterfinals
# 329                 NaN                NaN             NaN
# 330                 NaN                NaN             NaN
# 331                 NaN                NaN             NaN
# 332                 NaN                NaN             NaN
#
#     roundInfo.cupRoundType homeTeam.gender awayTeam.gender  \
# 0                      NaN             NaN             NaN
# 1                      NaN             NaN             NaN
# 2                      NaN             NaN             NaN
# 3                      NaN             NaN             NaN
# 4                      NaN             NaN             NaN
# ..                     ...             ...             ...
# 328                    4.0             NaN             NaN
# 329                    NaN             NaN             NaN
# 330                    NaN             NaN             NaN
# 331                    NaN             NaN             NaN
# 332                    NaN             NaN             NaN
#
#     homeScore.aggregated awayScore.aggregated homeScore.penalties  \
# 0                    NaN                  NaN                 NaN
# 1                    NaN                  NaN                 NaN
# 2                    NaN                  NaN                 NaN
# 3                    NaN                  NaN                 NaN
# 4                    NaN                  NaN                 NaN
# ..                   ...                  ...                 ...
# 328                  NaN                  NaN                 NaN
# 329                  NaN                  NaN                 NaN
# 330                  NaN                  NaN                 NaN
# 331                  NaN                  NaN                 NaN
# 332                  NaN                  NaN                 NaN
#
#      awayScore.penalties
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ..                   ...
# 328                  NaN
# 329                  NaN
# 330                  NaN
# 331                  NaN
# 332                  NaN
#
# [333 rows x 132 columns]
