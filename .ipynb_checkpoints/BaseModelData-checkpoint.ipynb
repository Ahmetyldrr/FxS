# %%
import os
import django
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'Home.settings')
django.setup()
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
import http.client
import pandas as pd
import json
from datetime import datetime
import ssl
from django.db import IntegrityError, transaction
from basemodels.models import FikstureModelData


class FixtureDataHandler:

    def __init__(self, date):
        self.date = date

    def fetch_fixtures_from_api(self):
        """
        API'den fikstür verilerini çeker, hata durumunda boş değerlerle döner.
        """
        try:
            context = ssl._create_unverified_context()
            conn = http.client.HTTPSConnection('www.sofascore.com', context=context)
            conn.request('GET', f'/api/v1/sport/football/scheduled-events/{self.date}')
            response = conn.getresponse()
            print(response.status)
            data = json.loads(response.read())["events"]
            df = pd.DataFrame(data)
            model_data = [{
                'data_id': self.date.replace("-", ""),
                'tarih': self.date,
                'data': data,
                'count': len(df),
                'isprogress': False
            }]
        except Exception as e:
            print(f"API'den veri çekerken hata oluştu: {e}")
            model_data = [{
                'data_id': self.date.replace("-", ""),
                'tarih': self.date,
                'data': {},
                'count': 0,
                'isprogress': False
            }]
        
        return model_data

    def save_fixtures_to_db(self, api_data):
        """
        API'den gelen verileri veritabanına kaydeder. Mevcut kayıt varsa siler ve yenisini ekler.
        """
        for item in api_data:
            try:
                # Tarih formatını kontrol et ve hatalıysa varsayılan değeri kullan
                try:
                    tarih = datetime.strptime(item['tarih'], "%Y-%m-%d").date()
                except ValueError:
                    print(f"Geçersiz tarih formatı: {item['tarih']}, varsayılan tarih atanıyor.")
                    tarih = datetime.strptime("1900-01-01", "%Y-%m-%d").date()

                # Veritabanı işlemlerini atomik olarak başlat
                with transaction.atomic():
                    existing_entry = FikstureModelData.objects.filter(data_id=item['data_id']).first()

                    if existing_entry:
                        # Eğer veri mevcutsa, kaydı sil
                        existing_entry.delete()
                        print(f"Eski veri silindi: {item['data_id']}")

                    # Yeni kayıt ekle
                    FikstureModelData.objects.create(
                        data_id=item['data_id'],
                        tarih=tarih,  # Doğrulanmış tarih
                        data=item['data'],
                        count=item['count'],
                        isprogress=item['isprogress']
                    )
                    print(f"Yeni veri eklendi: {tarih}")

            except IntegrityError as e:
                print(f"IntegrityError oluştu: {e}")

                # Hata durumunda varsayılan değerlerle kayıt ekle
                with transaction.atomic():
                    FikstureModelData.objects.create(
                        data_id='19000101',  # Varsayılan data_id
                        tarih=datetime.strptime("1900-01-01", "%Y-%m-%d").date(),  # Varsayılan tarih
                        data={},  # Boş dictionary
                        count=0,  # Varsayılan 0
                        isprogress=False  # Varsayılan False
                    )
                    print(f"Boş değerlerle veri eklendi.")


# Örnek kullanım:
handler = FixtureDataHandler("2024-07-21")
data = handler.fetch_fixtures_from_api()
handler.save_fixtures_to_db(data)
print("İşlem Tamamlandı")
data
# Out:
# 403
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240721
# Yeni veri eklendi: 2024-07-21
# İşlem Tamamlandı
# [{'data_id': '20240721',
#   'tarih': '2024-07-21',
#   'data': {},
#   'count': 0,
#   'isprogress': False}]

# %%
from datetime import datetime, timedelta

# Başlangıç tarihi
start_date = datetime.strptime("2024-06-21", "%Y-%m-%d")
# Bitiş tarihi (bugünün tarihi)
end_date = datetime.strptime("2024-08-01", "%Y-%m-%d")

# Başlangıç ve bitiş tarihleri arasındaki gün sayısını hesapla
delta = end_date - start_date

# Her gün için döngü
for i in range(delta.days + 1):
    current_date = start_date + timedelta(days=i)
    date_str = current_date.strftime("%Y-%m-%d")
    
    # FixtureDataHandler'ı mevcut tarih ile oluştur
    handler = FixtureDataHandler(date_str)
    
    # API'den verileri çek
    data = handler.fetch_fixtures_from_api()
    
    # Verileri veritabanına kaydet
    handler.save_fixtures_to_db(data)
    
    print(f"{date_str} işlemi tamamlandı.")

print("Tüm işlemler tamamlandı.")
# Out:
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240621
# Yeni veri eklendi: 2024-06-21
# 2024-06-21 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240622
# Yeni veri eklendi: 2024-06-22
# 2024-06-22 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240623
# Yeni veri eklendi: 2024-06-23
# 2024-06-23 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240624
# Yeni veri eklendi: 2024-06-24
# 2024-06-24 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240625
# Yeni veri eklendi: 2024-06-25
# 2024-06-25 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240626
# Yeni veri eklendi: 2024-06-26
# 2024-06-26 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240627
# Yeni veri eklendi: 2024-06-27
# 2024-06-27 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240628
# Yeni veri eklendi: 2024-06-28
# 2024-06-28 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240629
# Yeni veri eklendi: 2024-06-29
# 2024-06-29 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240630
# Yeni veri eklendi: 2024-06-30
# 2024-06-30 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240701
# Yeni veri eklendi: 2024-07-01
# 2024-07-01 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240702
# Yeni veri eklendi: 2024-07-02
# 2024-07-02 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240703
# Yeni veri eklendi: 2024-07-03
# 2024-07-03 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240704
# Yeni veri eklendi: 2024-07-04
# 2024-07-04 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240705
# Yeni veri eklendi: 2024-07-05
# 2024-07-05 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240706
# Yeni veri eklendi: 2024-07-06
# 2024-07-06 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240707
# Yeni veri eklendi: 2024-07-07
# 2024-07-07 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240708
# Yeni veri eklendi: 2024-07-08
# 2024-07-08 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240709
# Yeni veri eklendi: 2024-07-09
# 2024-07-09 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240710
# Yeni veri eklendi: 2024-07-10
# 2024-07-10 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240711
# Yeni veri eklendi: 2024-07-11
# 2024-07-11 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240712
# Yeni veri eklendi: 2024-07-12
# 2024-07-12 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240713
# Yeni veri eklendi: 2024-07-13
# 2024-07-13 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240714
# Yeni veri eklendi: 2024-07-14
# 2024-07-14 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240715
# Yeni veri eklendi: 2024-07-15
# 2024-07-15 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240716
# Yeni veri eklendi: 2024-07-16
# 2024-07-16 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240717
# Yeni veri eklendi: 2024-07-17
# 2024-07-17 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240718
# Yeni veri eklendi: 2024-07-18
# 2024-07-18 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240719
# Yeni veri eklendi: 2024-07-19
# 2024-07-19 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240720
# Yeni veri eklendi: 2024-07-20
# 2024-07-20 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240721
# Yeni veri eklendi: 2024-07-21
# 2024-07-21 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240722
# Yeni veri eklendi: 2024-07-22
# 2024-07-22 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240723
# Yeni veri eklendi: 2024-07-23
# 2024-07-23 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240724
# Yeni veri eklendi: 2024-07-24
# 2024-07-24 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240725
# Yeni veri eklendi: 2024-07-25
# 2024-07-25 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240726
# Yeni veri eklendi: 2024-07-26
# 2024-07-26 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240727
# Yeni veri eklendi: 2024-07-27
# 2024-07-27 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240728
# Yeni veri eklendi: 2024-07-28
# 2024-07-28 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240729
# Yeni veri eklendi: 2024-07-29
# 2024-07-29 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240730
# Yeni veri eklendi: 2024-07-30
# 2024-07-30 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240731
# Yeni veri eklendi: 2024-07-31
# 2024-07-31 işlemi tamamlandı.
# API'den veri çekerken hata oluştu: Expecting value: line 2 column 1 (char 1)
# Eski veri silindi: 20240801
# Yeni veri eklendi: 2024-08-01
# 2024-08-01 işlemi tamamlandı.
# Tüm işlemler tamamlandı.

# %%
import http.client
import pandas as pd
import json
import ssl
from datetime import datetime
from django.db import IntegrityError, transaction
from basemodels.models import FikstureModelData, ErrorLog

class FixtureDataHandler:
    API_BASE_URL = 'www.sofascore.com'

    def __init__(self, date):
        self.date = date

    def fetch_fixtures_from_api(self):
        """
        API'den fikstür verilerini çeker, hata durumunda boş değerlerle döner.
        """
        try:
            context = ssl._create_unverified_context()
            conn = http.client.HTTPSConnection(self.API_BASE_URL, context=context)
            conn.request('GET', f'/api/v1/sport/football/scheduled-events/{self.date}')
            response = conn.getresponse()
            if response.status != 200:
                error_message = f"API hatası: {response.status} - {response.reason}"
                ErrorLog.objects.create(error_type="API Error", details=error_message)
                return [{ 'data_id': self.date.replace("-", ""),
                          'tarih':self.date,
                         'status':response.status}]

            data = json.loads(response.read()).get("events", [])
            return [{
                'data_id': self.date.replace("-", ""),
                'tarih': self.date,
                'data': data,
                'count': len(data),
                'isprogress': False
            }]
        except Exception as e:
            error_message = f"API'den veri çekerken hata oluştu: {e}"
            ErrorLog.objects.create(error_type="API Error", details=error_message)
            return [{
                'data_id': self.date.replace("-", ""),
                'tarih': self.date,
                'data': {'data_id': self.date.replace("-", ""),
                          'tarih':self.date,
                         'status':response.status},
                'count': 0,
                'isprogress': False
            }]

    def save_fixtures_to_db(self, api_data):
        """
        API'den gelen verileri veritabanına kaydeder. Mevcut kayıt varsa siler ve yenisini ekler.
        """
        for item in api_data:
            try:
                
                tarih = datetime.strptime(item['tarih'], "%Y-%m-%d").date()
                
                with transaction.atomic():
                    
                    FikstureModelData.objects.filter(data_id=item['data_id']).delete()
                    try:
                        FikstureModelData.objects.create(
                            data_id=item['data_id'],
                            tarih=tarih,
                            data=item['data'],
                            count=item['count'],
                            isprogress=item['isprogress']
                        )
                    except:
                        pass

            
            except IntegrityError as e:
                error_message = f"Veritabanı IntegrityError oluştu: {e}"
                ErrorLog.objects.create(error_type="Database Integrity Error", details=error_message)

handler = FixtureDataHandler("2024-11-12")
data = handler.fetch_fixtures_from_api()
handler.save_fixtures_to_db(data)
print("İşlem Tamamlandı")
data
# Out:
# İşlem Tamamlandı
# [{'data_id': '20241112',
#   'tarih': '2024-11-12',
#   'data': [{'tournament': {'name': 'Africa Cup of Nations, Qualification, Group G',
#      'slug': 'africa-cup-of-nations-qualification-group-g',
#      'category': {'name': 'Africa',
#       'slug': 'africa',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'id': 1466,
#       'country': {},
#       'flag': 'africa'},
#      'uniqueTournament': {'name': 'Africa Cup of Nations Qual.',
#       'slug': 'africa-cup-of-nations-qual',
#       'category': {'name': 'Africa',
#        'slug': 'africa',
#        'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#        'id': 1466,
#        'country': {},
#        'flag': 'africa'},
#       'userCount': 87722,
#       'hasPerformanceGraphFeature': False,
#       'id': 1848,
#       'hasEventPlayerStatistics': True,
#       'displayInverseHomeAwayTeams': False},
#      'priority': 495,
#      'id': 59845},
#     'season': {'name': 'Africa Cup of Nations, Qualification 2024',
#      'year': '2024',
#      'editor': False,
#      'id': 58857},
#     'roundInfo': {'round': 5},
#     'customId': 'MUbsOkd',
#     'status': {'code': 60, 'description': 'Postponed', 'type': 'postponed'},
#     'homeTeam': {'name': 'Chad',
#      'slug': 'chad',
#      'shortName': 'Chad',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 7167,
#      'nameCode': 'CHA',
#      'disabled': False,
#      'national': True,
#      'type': 0,
#      'id': 8039,
#      'country': {'alpha2': 'TD',
#       'alpha3': 'TCD',
#       'name': 'Chad',
#       'slug': 'chad'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'تشاد', 'ru': 'Чад'},
#       'shortNameTranslation': {}}},
#     'awayTeam': {'name': 'Sierra Leone',
#      'slug': 'sierra-leone',
#      'shortName': 'Sierra Leone',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 18063,
#      'nameCode': 'SLE',
#      'national': True,
#      'type': 0,
#      'id': 4737,
#      'country': {'alpha2': 'SL',
#       'alpha3': 'SLE',
#       'name': 'Sierra Leone',
#       'slug': 'sierra-leone'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'سيراليون',
#        'ru': 'Сьерра-Леоне'},
#       'shortNameTranslation': {}}},
#     'homeScore': {},
#     'awayScore': {},
#     'time': {},
#     'changes': {'changes': ['status.code',
#       'status.description',
#       'status.type'],
#      'changeTimestamp': 1730727038},
#     'hasGlobalHighlights': False,
#     'hasEventPlayerStatistics': False,
#     'hasEventPlayerHeatMap': False,
#     'detailId': 1,
#     'crowdsourcingDataDisplayEnabled': False,
#     'id': 12526664,
#     'startTimestamp': 1731348000,
#     'slug': 'chad-sierra-leone',
#     'finalResultOnly': False,
#     'feedLocked': False,
#     'isEditor': False},
#    {'tournament': {'name': 'Africa Cup of Nations, Qualification, Group J',
#      'slug': 'africa-cup-of-nations-qualification-group-j',
#      'category': {'name': 'Africa',
#       'slug': 'africa',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'id': 1466,
#       'country': {},
#       'flag': 'africa'},
#      'uniqueTournament': {'name': 'Africa Cup of Nations Qual.',
#       'slug': 'africa-cup-of-nations-qual',
#       'category': {'name': 'Africa',
#        'slug': 'africa',
#        'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#        'id': 1466,
#        'country': {},
#        'flag': 'africa'},
#       'userCount': 87722,
#       'hasPerformanceGraphFeature': False,
#       'id': 1848,
#       'hasEventPlayerStatistics': True,
#       'displayInverseHomeAwayTeams': False},
#      'priority': 490,
#      'id': 59847},
#     'season': {'name': 'Africa Cup of Nations, Qualification 2024',
#      'year': '2024',
#      'editor': False,
#      'id': 58857},
#     'roundInfo': {'round': 5},
#     'customId': 'bVbsHWb',
#     'status': {'code': 31, 'description': 'Halftime', 'type': 'inprogress'},
#     'homeTeam': {'name': 'Namibia',
#      'slug': 'namibia',
#      'shortName': 'Namibia',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 24889,
#      'nameCode': 'NAM',
#      'disabled': False,
#      'national': True,
#      'type': 0,
#      'id': 4832,
#      'country': {'alpha2': 'NA',
#       'alpha3': 'NAM',
#       'name': 'Namibia',
#       'slug': 'namibia'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'ناميبيا',
#        'ru': 'Намибия'},
#       'shortNameTranslation': {}}},
#     'awayTeam': {'name': 'Cameroon',
#      'slug': 'cameroon',
#      'shortName': 'Cameroon',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 159415,
#      'nameCode': 'CMR',
#      'disabled': False,
#      'national': True,
#      'type': 0,
#      'id': 4751,
#      'country': {'alpha2': 'CM',
#       'alpha3': 'CMR',
#       'name': 'Cameroon',
#       'slug': 'cameroon'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'الكاميرون',
#        'ru': 'Камерун'},
#       'shortNameTranslation': {}}},
#     'homeScore': {'current': 0, 'display': 0, 'period1': 0, 'normaltime': 0},
#     'awayScore': {'current': 0, 'display': 0, 'period1': 0, 'normaltime': 0},
#     'time': {'injuryTime1': 1, 'currentPeriodStartTimestamp': 1731503110},
#     'changes': {'changes': ['time.injuryTime1',
#       'status.code',
#       'status.description'],
#      'changeTimestamp': 1731505914},
#     'hasGlobalHighlights': False,
#     'hasEventPlayerStatistics': True,
#     'hasEventPlayerHeatMap': True,
#     'detailId': 1,
#     'crowdsourcingDataDisplayEnabled': False,
#     'id': 12526760,
#     'startTimestamp': 1731502800,
#     'slug': 'namibia-cameroon',
#     'finalResultOnly': False,
#     'feedLocked': False,
#     'isEditor': False},
#    {'tournament': {'name': 'Liga Profesional',
#      'slug': 'liga-profesional',
#      'category': {'name': 'Argentina',
#       'slug': 'argentina',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'id': 48,
#       'country': {'alpha2': 'AR',
#        'alpha3': 'ARG',
#        'name': 'Argentina',
#        'slug': 'argentina'},
#       'flag': 'argentina',
#       'alpha2': 'AR'},
#      'uniqueTournament': {'name': 'Liga Profesional de Fútbol',
#       'slug': 'liga-profesional-de-futbol',
#       'category': {'name': 'Argentina',
#        'slug': 'argentina',
#        'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#        'id': 48,
#        'country': {'alpha2': 'AR',
#         'alpha3': 'ARG',
#         'name': 'Argentina',
#         'slug': 'argentina'},
#        'flag': 'argentina',
#        'alpha2': 'AR'},
#       'userCount': 57856,
#       'id': 155,
#       'hasEventPlayerStatistics': True,
#       'displayInverseHomeAwayTeams': False},
#      'priority': 396,
#      'id': 68},
#     'season': {'name': 'Liga Profesional 2024',
#      'year': '2024',
#      'editor': False,
#      'id': 57478},
#     'roundInfo': {'round': 22},
#     'customId': 'iobsyUAb',
#     'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#     'winnerCode': 3,
#     'homeTeam': {'name': 'Deportivo Riestra',
#      'slug': 'deportivo-riestra',
#      'shortName': 'Dep. Riestra',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 8582,
#      'nameCode': 'RIE',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 189723,
#      'country': {'alpha2': 'AR',
#       'alpha3': 'ARG',
#       'name': 'Argentina',
#       'slug': 'argentina'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'ديبورتيفو رييسترا',
#        'ru': 'Депортиво Риестра'},
#       'shortNameTranslation': {}}},
#     'awayTeam': {'name': 'Vélez Sarsfield',
#      'slug': 'velez-sarsfield',
#      'shortName': 'Vélez Sarsfield',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 28432,
#      'nameCode': 'VEL',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 3208,
#      'country': {'alpha2': 'AR',
#       'alpha3': 'ARG',
#       'name': 'Argentina',
#       'slug': 'argentina'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'Велес Сарсфилд'},
#       'shortNameTranslation': {}}},
#     'homeScore': {'current': 1,
#      'display': 1,
#      'period1': 0,
#      'period2': 1,
#      'normaltime': 1},
#     'awayScore': {'current': 1,
#      'display': 1,
#      'period1': 1,
#      'period2': 0,
#      'normaltime': 1},
#     'time': {'injuryTime1': 4,
#      'injuryTime2': 5,
#      'currentPeriodStartTimestamp': 1731358528},
#     'changes': {'changes': ['status.code',
#       'status.description',
#       'status.type',
#       'homeScore.period2',
#       'homeScore.normaltime',
#       'awayScore.period2',
#       'awayScore.normaltime',
#       'time.currentPeriodStart'],
#      'changeTimestamp': 1731358532},
#     'hasGlobalHighlights': True,
#     'hasEventPlayerStatistics': True,
#     'hasEventPlayerHeatMap': True,
#     'detailId': 1,
#     'crowdsourcingDataDisplayEnabled': False,
#     'id': 11937412,
#     'startTimestamp': 1731351600,
#     'slug': 'deportivo-riestra-velez-sarsfield',
#     'finalResultOnly': False,
#     'feedLocked': False,
#     'isEditor': False},
#    {'tournament': {'name': 'Liga Profesional',
#      'slug': 'liga-profesional',
#      'category': {'name': 'Argentina',
#       'slug': 'argentina',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'id': 48,
#       'country': {'alpha2': 'AR',
#        'alpha3': 'ARG',
#        'name': 'Argentina',
#        'slug': 'argentina'},
#       'flag': 'argentina',
#       'alpha2': 'AR'},
#      'uniqueTournament': {'name': 'Liga Profesional de Fútbol',
#       'slug': 'liga-profesional-de-futbol',
#       'category': {'name': 'Argentina',
#        'slug': 'argentina',
#        'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#        'id': 48,
#        'country': {'alpha2': 'AR',
#         'alpha3': 'ARG',
#         'name': 'Argentina',
#         'slug': 'argentina'},
#        'flag': 'argentina',
#        'alpha2': 'AR'},
#       'userCount': 57856,
#       'id': 155,
#       'hasEventPlayerStatistics': True,
#       'displayInverseHomeAwayTeams': False},
#      'priority': 396,
#      'id': 68},
#     'season': {'name': 'Liga Profesional 2024',
#      'year': '2024',
#      'editor': False,
#      'id': 57478},
#     'roundInfo': {'round': 22},
#     'customId': 'tobsMLo',
#     'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#     'winnerCode': 3,
#     'homeTeam': {'name': 'Lanús',
#      'slug': 'lanus',
#      'shortName': 'Lanús',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 22382,
#      'nameCode': 'LAN',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 3218,
#      'country': {'alpha2': 'AR',
#       'alpha3': 'ARG',
#       'name': 'Argentina',
#       'slug': 'argentina'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'Атлетико Ланус'},
#       'shortNameTranslation': {}}},
#     'awayTeam': {'name': 'Platense',
#      'slug': 'platense',
#      'shortName': 'Platense',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 12884,
#      'nameCode': 'PLA',
#      'national': False,
#      'type': 0,
#      'id': 36837,
#      'country': {'alpha2': 'AR',
#       'alpha3': 'ARG',
#       'name': 'Argentina',
#       'slug': 'argentina'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'КА Платенсе'},
#       'shortNameTranslation': {}}},
#     'homeScore': {'current': 0,
#      'display': 0,
#      'period1': 0,
#      'period2': 0,
#      'normaltime': 0},
#     'awayScore': {'current': 0,
#      'display': 0,
#      'period1': 0,
#      'period2': 0,
#      'normaltime': 0},
#     'time': {'injuryTime1': 2,
#      'injuryTime2': 5,
#      'currentPeriodStartTimestamp': 1731368419},
#     'changes': {'changes': ['status.code',
#       'status.description',
#       'status.type',
#       'homeScore.period2',
#       'homeScore.normaltime',
#       'awayScore.period2',
#       'awayScore.normaltime',
#       'time.currentPeriodStart'],
#      'changeTimestamp': 1731368423},
#     'hasGlobalHighlights': True,
#     'hasEventPlayerStatistics': True,
#     'hasEventPlayerHeatMap': True,
#     'detailId': 1,
#     'crowdsourcingDataDisplayEnabled': False,
#     'id': 11937413,
#     'startTimestamp': 1731361500,
#     'slug': 'platense-lanus',
#     'finalResultOnly': False,
#     'feedLocked': False,
#     'isEditor': False},
#    {'tournament': {'name': 'Liga Profesional',
#      'slug': 'liga-profesional',
#      'category': {'name': 'Argentina',
#       'slug': 'argentina',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'id': 48,
#       'country': {'alpha2': 'AR',
#        'alpha3': 'ARG',
#        'name': 'Argentina',
#        'slug': 'argentina'},
#       'flag': 'argentina',
#       'alpha2': 'AR'},
#      'uniqueTournament': {'name': 'Liga Profesional de Fútbol',
#       'slug': 'liga-profesional-de-futbol',
#       'category': {'name': 'Argentina',
#        'slug': 'argentina',
#        'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#        'id': 48,
#        'country': {'alpha2': 'AR',
#         'alpha3': 'ARG',
#         'name': 'Argentina',
#         'slug': 'argentina'},
#        'flag': 'argentina',
#        'alpha2': 'AR'},
#       'userCount': 57856,
#       'id': 155,
#       'hasEventPlayerStatistics': True,
#       'displayInverseHomeAwayTeams': False},
#      'priority': 396,
#      'id': 68},
#     'season': {'name': 'Liga Profesional 2024',
#      'year': '2024',
#      'editor': False,
#      'id': 57478},
#     'roundInfo': {'round': 22},
#     'customId': 'DcdsOLo',
#     'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#     'winnerCode': 2,
#     'homeTeam': {'name': 'Tigre',
#      'slug': 'tigre',
#      'shortName': 'Tigre',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 14882,
#      'nameCode': 'TIG',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 7628,
#      'country': {'alpha2': 'AR',
#       'alpha3': 'ARG',
#       'name': 'Argentina',
#       'slug': 'argentina'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'КА Тигре'},
#       'shortNameTranslation': {}}},
#     'awayTeam': {'name': 'Defensa y Justicia',
#      'slug': 'defensa-y-justicia',
#      'shortName': 'Def y Justicia',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 22766,
#      'nameCode': 'DYJ',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 36839,
#      'country': {'alpha2': 'AR',
#       'alpha3': 'ARG',
#       'name': 'Argentina',
#       'slug': 'argentina'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'ديفنسا خوستيكا',
#        'ru': 'Дефенса и Юстиция'},
#       'shortNameTranslation': {}}},
#     'homeScore': {'current': 0,
#      'display': 0,
#      'period1': 0,
#      'period2': 0,
#      'normaltime': 0},
#     'awayScore': {'current': 4,
#      'display': 4,
#      'period1': 0,
#      'period2': 4,
#      'normaltime': 4},
#     'time': {'injuryTime1': 3,
#      'injuryTime2': 3,
#      'currentPeriodStartTimestamp': 1731368260},
#     'changes': {'changes': ['homeScore.period2',
#       'homeScore.normaltime',
#       'awayScore.period2',
#       'awayScore.normaltime'],
#      'changeTimestamp': 1731368338},
#     'hasGlobalHighlights': True,
#     'hasEventPlayerStatistics': True,
#     'hasEventPlayerHeatMap': True,
#     'detailId': 1,
#     'crowdsourcingDataDisplayEnabled': False,
#     'id': 11937411,
#     'startTimestamp': 1731361500,
#     'slug': 'defensa-y-justicia-tigre',
#     'finalResultOnly': False,
#     'feedLocked': False,
#     'isEditor': False},
#    {'tournament': {'name': 'Liga Profesional',
#      'slug': 'liga-profesional',
#      'category': {'name': 'Argentina',
#       'slug': 'argentina',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'id': 48,
#       'country': {'alpha2': 'AR',
#        'alpha3': 'ARG',
#        'name': 'Argentina',
#        'slug': 'argentina'},
#       'flag': 'argentina',
#       'alpha2': 'AR'},
#      'uniqueTournament': {'name': 'Liga Profesional de Fútbol',
#       'slug': 'liga-profesional-de-futbol',
#       'category': {'name': 'Argentina',
#        'slug': 'argentina',
#        'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#        'id': 48,
#        'country': {'alpha2': 'AR',
#         'alpha3': 'ARG',
#         'name': 'Argentina',
#         'slug': 'argentina'},
#        'flag': 'argentina',
#        'alpha2': 'AR'},
#       'userCount': 57856,
#       'id': 155,
#       'hasEventPlayerStatistics': True,
#       'displayInverseHomeAwayTeams': False},
#      'priority': 396,
#      'id': 68},
#     'season': {'name': 'Liga Profesional 2024',
#      'year': '2024',
#      'editor': False,
#      'id': 57478},
#     'roundInfo': {'round': 22},
#     'customId': 'qobsuob',
#     'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#     'winnerCode': 1,
#     'homeTeam': {'name': 'Argentinos Juniors',
#      'slug': 'argentinos-juniors',
#      'shortName': 'Argentinos Jrs.',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 25275,
#      'nameCode': 'ARG',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 3216,
#      'country': {'alpha2': 'AR',
#       'alpha3': 'ARG',
#       'name': 'Argentina',
#       'slug': 'argentina'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'أرجنتينوس جونيورز',
#        'ru': 'Аргентинос Хуниорс'},
#       'shortNameTranslation': {}}},
#     'awayTeam': {'name': 'Banfield',
#      'slug': 'banfield',
#      'shortName': 'Banfield',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 12427,
#      'nameCode': 'BAN',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 3219,
#      'country': {'alpha2': 'AR',
#       'alpha3': 'ARG',
#       'name': 'Argentina',
#       'slug': 'argentina'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'КА Банфилд'},
#       'shortNameTranslation': {}}},
#     'homeScore': {'current': 1,
#      'display': 1,
#      'period1': 1,
#      'period2': 0,
#      'normaltime': 1},
#     'awayScore': {'current': 0,
#      'display': 0,
#      'period1': 0,
#      'period2': 0,
#      'normaltime': 0},
#     'time': {'injuryTime1': 2,
#      'injuryTime2': 5,
#      'currentPeriodStartTimestamp': 1731376611},
#     'changes': {'changes': ['status.code',
#       'status.description',
#       'status.type',
#       'homeScore.period2',
#       'homeScore.normaltime',
#       'awayScore.period2',
#       'awayScore.normaltime',
#       'time.currentPeriodStart'],
#      'changeTimestamp': 1731376613},
#     'hasGlobalHighlights': True,
#     'hasEventPlayerStatistics': True,
#     'hasEventPlayerHeatMap': True,
#     'detailId': 1,
#     'crowdsourcingDataDisplayEnabled': False,
#     'id': 11937410,
#     'startTimestamp': 1731369600,
#     'slug': 'banfield-argentinos-juniors',
#     'finalResultOnly': False,
#     'feedLocked': False,
#     'isEditor': False},
#    {'tournament': {'name': 'Liga Profesional',
#      'slug': 'liga-profesional',
#      'category': {'name': 'Argentina',
#       'slug': 'argentina',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'id': 48,
#       'country': {'alpha2': 'AR',
#        'alpha3': 'ARG',
#        'name': 'Argentina',
#        'slug': 'argentina'},
#       'flag': 'argentina',
#       'alpha2': 'AR'},
#      'uniqueTournament': {'name': 'Liga Profesional de Fútbol',
#       'slug': 'liga-profesional-de-futbol',
#       'category': {'name': 'Argentina',
#        'slug': 'argentina',
#        'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#        'id': 48,
#        'country': {'alpha2': 'AR',
#         'alpha3': 'ARG',
#         'name': 'Argentina',
#         'slug': 'argentina'},
#        'flag': 'argentina',
#        'alpha2': 'AR'},
#       'userCount': 57856,
#       'id': 155,
#       'hasEventPlayerStatistics': True,
#       'displayInverseHomeAwayTeams': False},
#      'priority': 396,
#      'id': 68},
#     'season': {'name': 'Liga Profesional 2024',
#      'year': '2024',
#      'editor': False,
#      'id': 57478},
#     'roundInfo': {'round': 22},
#     'customId': 'dobsMYb',
#     'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#     'winnerCode': 1,
#     'homeTeam': {'name': 'Belgrano',
#      'slug': 'belgrano',
#      'shortName': 'Belgrano',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 19849,
#      'nameCode': 'BEL',
#      'national': False,
#      'type': 0,
#      'id': 3203,
#      'country': {'alpha2': 'AR',
#       'alpha3': 'ARG',
#       'name': 'Argentina',
#       'slug': 'argentina'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'Бельграно де Кордоба'},
#       'shortNameTranslation': {}}},
#     'awayTeam': {'name': 'Instituto De Córdoba',
#      'slug': 'instituto-cordoba',
#      'shortName': 'Instituto',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 10802,
#      'nameCode': 'IAC',
#      'national': False,
#      'type': 0,
#      'id': 4937,
#      'country': {'alpha2': 'AR',
#       'alpha3': 'ARG',
#       'name': 'Argentina',
#       'slug': 'argentina'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'Институто Атлетико'},
#       'shortNameTranslation': {}}},
#     'homeScore': {'current': 3,
#      'display': 3,
#      'period1': 2,
#      'period2': 1,
#      'normaltime': 3},
#     'awayScore': {'current': 1,
#      'display': 1,
#      'period1': 1,
#      'period2': 0,
#      'normaltime': 1},
#     'time': {'injuryTime1': 5,
#      'injuryTime2': 4,
#      'currentPeriodStartTimestamp': 1731376528},
#     'changes': {'changes': ['status.code',
#       'status.description',
#       'status.type',
#       'homeScore.period2',
#       'homeScore.normaltime',
#       'awayScore.period2',
#       'awayScore.normaltime',
#       'time.currentPeriodStart'],
#      'changeTimestamp': 1731376532},
#     'hasGlobalHighlights': True,
#     'hasEventPlayerStatistics': True,
#     'hasEventPlayerHeatMap': True,
#     'detailId': 1,
#     'crowdsourcingDataDisplayEnabled': False,
#     'id': 11937409,
#     'awayRedCards': 1,
#     'startTimestamp': 1731369600,
#     'slug': 'instituto-de-cordoba-belgrano',
#     'finalResultOnly': False,
#     'feedLocked': False,
#     'isEditor': False},
#    {'tournament': {'name': 'UEFA Champions League, Women, Group C',
#      'slug': 'uefa-champions-league-women-group-c',
#      'category': {'name': 'Europe',
#       'slug': 'europe',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'id': 1465,
#       'country': {},
#       'flag': 'europe'},
#      'uniqueTournament': {'name': "UEFA Women's Champions League",
#       'slug': 'uefa-womens-champions-league',
#       'category': {'name': 'Europe',
#        'slug': 'europe',
#        'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#        'id': 1465,
#        'country': {},
#        'flag': 'europe'},
#       'userCount': 53416,
#       'hasPerformanceGraphFeature': False,
#       'id': 696,
#       'hasEventPlayerStatistics': True,
#       'displayInverseHomeAwayTeams': False},
#      'priority': 333,
#      'id': 95256},
#     'season': {'name': 'UEFA Champions League Women 24/25',
#      'year': '24/25',
#      'editor': False,
#      'id': 63572},
#     'roundInfo': {'round': 3},
#     'customId': 'TzkszWhc',
#     'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#     'winnerCode': 2,
#     'homeTeam': {'name': 'Juventus',
#      'slug': 'juventus',
#      'shortName': 'Juventus',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 27459,
#      'nameCode': 'JUV',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 269824,
#      'country': {'alpha2': 'IT',
#       'alpha3': 'ITA',
#       'name': 'Italy',
#       'slug': 'italy'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'Ювентус'},
#       'shortNameTranslation': {}}},
#     'awayTeam': {'name': 'Arsenal Women',
#      'slug': 'arsenal-women',
#      'shortName': 'Arsenal',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 71128,
#      'nameCode': 'ARS',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 26243,
#      'country': {'alpha2': 'EN',
#       'alpha3': 'ENG',
#       'name': 'England',
#       'slug': 'england'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'Арсенал ЛФК'},
#       'shortNameTranslation': {}}},
#     'homeScore': {'current': 0,
#      'display': 0,
#      'period1': 0,
#      'period2': 0,
#      'normaltime': 0},
#     'awayScore': {'current': 4,
#      'display': 4,
#      'period1': 1,
#      'period2': 3,
#      'normaltime': 4},
#     'time': {'injuryTime1': 2,
#      'injuryTime2': 4,
#      'currentPeriodStartTimestamp': 1731437342},
#     'changes': {'changes': ['status.code',
#       'status.description',
#       'status.type'],
#      'changeTimestamp': 1731440289},
#     'hasGlobalHighlights': True,
#     'hasEventPlayerStatistics': True,
#     'hasEventPlayerHeatMap': True,
#     'detailId': 1,
#     'crowdsourcingDataDisplayEnabled': False,
#     'id': 12918815,
#     'startTimestamp': 1731433500,
#     'slug': 'juventus-arsenal-women',
#     'finalResultOnly': False,
#     'feedLocked': False,
#     'isEditor': False},
#    {'tournament': {'name': 'UEFA Champions League, Women, Group C',
#      'slug': 'uefa-champions-league-women-group-c',
#      'category': {'name': 'Europe',
#       'slug': 'europe',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'id': 1465,
#       'country': {},
#       'flag': 'europe'},
#      'uniqueTournament': {'name': "UEFA Women's Champions League",
#       'slug': 'uefa-womens-champions-league',
#       'category': {'name': 'Europe',
#        'slug': 'europe',
#        'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#        'id': 1465,
#        'country': {},
#        'flag': 'europe'},
#       'userCount': 53416,
#       'hasPerformanceGraphFeature': False,
#       'id': 696,
#       'hasEventPlayerStatistics': True,
#       'displayInverseHomeAwayTeams': False},
#      'priority': 333,
#      'id': 95256},
#     'season': {'name': 'UEFA Champions League Women 24/25',
#      'year': '24/25',
#      'editor': False,
#      'id': 63572},
#     'roundInfo': {'round': 3},
#     'customId': 'TkcscUz',
#     'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#     'winnerCode': 1,
#     'homeTeam': {'name': 'FC Bayern München',
#      'slug': 'fc-bayern-munchen',
#      'shortName': 'Bayern',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 50873,
#      'nameCode': 'BAY',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 5543,
#      'country': {'alpha2': 'DE',
#       'alpha3': 'DEU',
#       'name': 'Germany',
#       'slug': 'germany'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'Фк Бавария Мюнхен'},
#       'shortNameTranslation': {}}},
#     'awayTeam': {'name': 'Vålerenga',
#      'slug': 'valerenga',
#      'shortName': 'Vålerenga',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 6566,
#      'nameCode': 'VAL',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 62202,
#      'country': {'alpha2': 'NO',
#       'alpha3': 'NOR',
#       'name': 'Norway',
#       'slug': 'norway'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'ФК Валеренга'},
#       'shortNameTranslation': {}}},
#     'homeScore': {'current': 3,
#      'display': 3,
#      'period1': 2,
#      'period2': 1,
#      'normaltime': 3},
#     'awayScore': {'current': 0,
#      'display': 0,
#      'period1': 0,
#      'period2': 0,
#      'normaltime': 0},
#     'time': {'injuryTime1': 0,
#      'injuryTime2': 4,
#      'currentPeriodStartTimestamp': 1731445395},
#     'changes': {'changes': ['status.code',
#       'status.description',
#       'status.type'],
#      'changeTimestamp': 1731448361},
#     'hasGlobalHighlights': True,
#     'hasEventPlayerStatistics': True,
#     'hasEventPlayerHeatMap': True,
#     'detailId': 1,
#     'crowdsourcingDataDisplayEnabled': False,
#     'id': 12918816,
#     'startTimestamp': 1731441600,
#     'slug': 'valerenga-fc-bayern-munchen',
#     'finalResultOnly': False,
#     'feedLocked': False,
#     'isEditor': False},
#    {'tournament': {'name': 'UEFA Champions League, Women, Group D',
#      'slug': 'uefa-champions-league-women-group-d',
#      'category': {'name': 'Europe',
#       'slug': 'europe',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'id': 1465,
#       'country': {},
#       'flag': 'europe'},
#      'uniqueTournament': {'name': "UEFA Women's Champions League",
#       'slug': 'uefa-womens-champions-league',
#       'category': {'name': 'Europe',
#        'slug': 'europe',
#        'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#        'id': 1465,
#        'country': {},
#        'flag': 'europe'},
#       'userCount': 53416,
#       'hasPerformanceGraphFeature': False,
#       'id': 696,
#       'hasEventPlayerStatistics': True,
#       'displayInverseHomeAwayTeams': False},
#      'priority': 332,
#      'id': 95257},
#     'season': {'name': 'UEFA Champions League Women 24/25',
#      'year': '24/25',
#      'editor': False,
#      'id': 63572},
#     'roundInfo': {'round': 3},
#     'customId': 'OhGsLDX',
#     'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#     'winnerCode': 1,
#     'homeTeam': {'name': 'Barcelona',
#      'slug': 'barcelona',
#      'shortName': 'Barcelona',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 273785,
#      'nameCode': 'FCB',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 77889,
#      'country': {'alpha2': 'ES',
#       'alpha3': 'ESP',
#       'name': 'Spain',
#       'slug': 'spain'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'ФК Барселона'},
#       'shortNameTranslation': {}}},
#     'awayTeam': {'name': 'SKN St. Pölten',
#      'slug': 'skn-st-polten',
#      'shortName': 'St. Pölten',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 6033,
#      'nameCode': 'STP',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 118936,
#      'country': {'alpha2': 'AT',
#       'alpha3': 'AUT',
#       'name': 'Austria',
#       'slug': 'austria'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'}},
#     'homeScore': {'current': 7,
#      'display': 7,
#      'period1': 5,
#      'period2': 2,
#      'normaltime': 7},
#     'awayScore': {'current': 0,
#      'display': 0,
#      'period1': 0,
#      'period2': 0,
#      'normaltime': 0},
#     'time': {'injuryTime1': 1,
#      'injuryTime2': 2,
#      'currentPeriodStartTimestamp': 1731437200},
#     'changes': {'changes': ['status.code',
#       'status.description',
#       'status.type'],
#      'changeTimestamp': 1731440041},
#     'hasGlobalHighlights': True,
#     'hasEventPlayerStatistics': True,
#     'hasEventPlayerHeatMap': True,
#     'detailId': 1,
#     'crowdsourcingDataDisplayEnabled': False,
#     'id': 12921264,
#     'startTimestamp': 1731433500,
#     'slug': 'skn-st-polten-barcelona',
#     'finalResultOnly': False,
#     'feedLocked': False,
#     'isEditor': False},
#    {'tournament': {'name': 'UEFA Champions League, Women, Group D',
#      'slug': 'uefa-champions-league-women-group-d',
#      'category': {'name': 'Europe',
#       'slug': 'europe',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'id': 1465,
#       'country': {},
#       'flag': 'europe'},
#      'uniqueTournament': {'name': "UEFA Women's Champions League",
#       'slug': 'uefa-womens-champions-league',
#       'category': {'name': 'Europe',
#        'slug': 'europe',
#        'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#        'id': 1465,
#        'country': {},
#        'flag': 'europe'},
#       'userCount': 53416,
#       'hasPerformanceGraphFeature': False,
#       'id': 696,
#       'hasEventPlayerStatistics': True,
#       'displayInverseHomeAwayTeams': False},
#      'priority': 332,
#      'id': 95257},
#     'season': {'name': 'UEFA Champions League Women 24/25',
#      'year': '24/25',
#      'editor': False,
#      'id': 63572},
#     'roundInfo': {'round': 3},
#     'customId': 'JMsidhb',
#     'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#     'winnerCode': 1,
#     'homeTeam': {'name': 'Manchester City W.F.C.',
#      'slug': 'manchester-city-wfc',
#      'shortName': 'Man. City',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 38497,
#      'nameCode': 'MCI',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 142658,
#      'country': {'alpha2': 'EN',
#       'alpha3': 'ENG',
#       'name': 'England',
#       'slug': 'england'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'Манчестер Сити'},
#       'shortNameTranslation': {}}},
#     'awayTeam': {'name': 'Hammarby IF',
#      'slug': 'hammarby-if',
#      'shortName': 'Hammarby',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 6644,
#      'nameCode': 'HAM',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 1884,
#      'country': {'alpha2': 'SE',
#       'alpha3': 'SWE',
#       'name': 'Sweden',
#       'slug': 'sweden'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'هاماربي اي اف دي إف إف',
#        'ru': 'Хаммарбю'},
#       'shortNameTranslation': {}}},
#     'homeScore': {'current': 2,
#      'display': 2,
#      'period1': 0,
#      'period2': 2,
#      'normaltime': 2},
#     'awayScore': {'current': 0,
#      'display': 0,
#      'period1': 0,
#      'period2': 0,
#      'normaltime': 0},
#     'time': {'injuryTime1': 2,
#      'injuryTime2': 4,
#      'currentPeriodStartTimestamp': 1731445481},
#     'changes': {'changes': ['status.code',
#       'status.description',
#       'status.type'],
#      'changeTimestamp': 1731448543},
#     'hasGlobalHighlights': True,
#     'hasEventPlayerStatistics': True,
#     'hasEventPlayerHeatMap': True,
#     'detailId': 1,
#     'crowdsourcingDataDisplayEnabled': False,
#     'id': 12921265,
#     'startTimestamp': 1731441600,
#     'slug': 'manchester-cityfc-hammarby-if',
#     'finalResultOnly': False,
#     'feedLocked': False,
#     'isEditor': False},
#    {'tournament': {'name': 'LaLiga 2',
#      'slug': 'laliga-2',
#      'category': {'name': 'Spain',
#       'slug': 'spain',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'id': 32,
#       'country': {'alpha2': 'ES',
#        'alpha3': 'ESP',
#        'name': 'Spain',
#        'slug': 'spain'},
#       'flag': 'spain',
#       'alpha2': 'ES'},
#      'uniqueTournament': {'name': 'LaLiga 2',
#       'slug': 'laliga-2',
#       'category': {'name': 'Spain',
#        'slug': 'spain',
#        'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#        'id': 32,
#        'country': {'alpha2': 'ES',
#         'alpha3': 'ESP',
#         'name': 'Spain',
#         'slug': 'spain'},
#        'flag': 'spain',
#        'alpha2': 'ES'},
#       'userCount': 53158,
#       'id': 54,
#       'hasEventPlayerStatistics': True,
#       'displayInverseHomeAwayTeams': False},
#      'priority': 319,
#      'id': 37},
#     'season': {'name': 'LaLiga 2 24/25',
#      'year': '24/25',
#      'editor': False,
#      'id': 62048},
#     'roundInfo': {'round': 14},
#     'customId': 'HgbsOgb',
#     'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#     'winnerCode': 1,
#     'homeTeam': {'name': 'Deportivo La Coruña',
#      'slug': 'deportivo-la-coruna',
#      'shortName': 'Deportivo',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 20779,
#      'nameCode': 'COR',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 2832,
#      'country': {'alpha2': 'ES',
#       'alpha3': 'ESP',
#       'name': 'Spain',
#       'slug': 'spain'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'ديبورتيفو لا كورونيا',
#        'ru': 'Депортиво Ла-Корунья'},
#       'shortNameTranslation': {}}},
#     'awayTeam': {'name': 'Eibar',
#      'slug': 'eibar',
#      'shortName': 'Eibar',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 46377,
#      'nameCode': 'EIB',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 2839,
#      'country': {'alpha2': 'ES',
#       'alpha3': 'ESP',
#       'name': 'Spain',
#       'slug': 'spain'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'ايبار', 'ru': 'Эйбар'},
#       'shortNameTranslation': {}}},
#     'homeScore': {'current': 1,
#      'display': 1,
#      'period1': 0,
#      'period2': 1,
#      'normaltime': 1},
#     'awayScore': {'current': 0,
#      'display': 0,
#      'period1': 0,
#      'period2': 0,
#      'normaltime': 0},
#     'time': {'injuryTime1': 1,
#      'injuryTime2': 3,
#      'currentPeriodStartTimestamp': 1731357296},
#     'changes': {'changes': ['status.code',
#       'status.description',
#       'status.type',
#       'homeScore.period2',
#       'homeScore.normaltime'],
#      'changeTimestamp': 1731360249},
#     'hasGlobalHighlights': True,
#     'hasEventPlayerStatistics': True,
#     'hasEventPlayerHeatMap': True,
#     'detailId': 1,
#     'crowdsourcingDataDisplayEnabled': False,
#     'id': 12467646,
#     'startTimestamp': 1731353400,
#     'slug': 'eibar-deportivo-la-coruna',
#     'finalResultOnly': False,
#     'feedLocked': False,
#     'isEditor': False},
#    {'tournament': {'name': 'Brasileirão Série B',
#      'slug': 'brasileirao-serie-b',
#      'category': {'name': 'Brazil',
#       'slug': 'brazil',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'id': 13,
#       'country': {'alpha2': 'BR',
#        'alpha3': 'BRA',
#        'name': 'Brazil',
#        'slug': 'brazil'},
#       'flag': 'brazil',
#       'alpha2': 'BR'},
#      'uniqueTournament': {'name': 'Brasileirão Série B',
#       'slug': 'brasileirao-serie-b',
#       'category': {'name': 'Brazil',
#        'slug': 'brazil',
#        'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#        'id': 13,
#        'country': {'alpha2': 'BR',
#         'alpha3': 'BRA',
#         'name': 'Brazil',
#         'slug': 'brazil'},
#        'flag': 'brazil',
#        'alpha2': 'BR'},
#       'userCount': 88065,
#       'id': 390,
#       'hasEventPlayerStatistics': True,
#       'displayInverseHomeAwayTeams': False},
#      'priority': 300,
#      'id': 1449},
#     'season': {'name': 'Brasileiro Serie B 2024',
#      'year': '2024',
#      'editor': False,
#      'id': 59015},
#     'roundInfo': {'round': 36},
#     'customId': 'uOswP',
#     'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#     'winnerCode': 1,
#     'homeTeam': {'name': 'Vila Nova FC',
#      'slug': 'vila-nova',
#      'shortName': 'Vila Nova',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 27278,
#      'nameCode': 'VIN',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 2021,
#      'country': {'alpha2': 'BR',
#       'alpha3': 'BRA',
#       'name': 'Brazil',
#       'slug': 'brazil'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'ФК Вила Нова ГО'},
#       'shortNameTranslation': {}}},
#     'awayTeam': {'name': 'Ponte Preta',
#      'slug': 'ponte-preta',
#      'shortName': 'Ponte Preta',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 22052,
#      'nameCode': 'PON',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 1969,
#      'country': {'alpha2': 'BR',
#       'alpha3': 'BRA',
#       'name': 'Brazil',
#       'slug': 'brazil'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'Понте Прета'},
#       'shortNameTranslation': {}}},
#     'homeScore': {'current': 2,
#      'display': 2,
#      'period1': 1,
#      'period2': 1,
#      'normaltime': 2},
#     'awayScore': {'current': 1,
#      'display': 1,
#      'period1': 1,
#      'period2': 0,
#      'normaltime': 1},
#     'time': {'injuryTime1': 5,
#      'injuryTime2': 9,
#      'currentPeriodStartTimestamp': 1731364548},
#     'changes': {'changes': ['time.injuryTime2',
#       'status.code',
#       'status.description',
#       'status.type'],
#      'changeTimestamp': 1731367854},
#     'hasGlobalHighlights': True,
#     'hasEventPlayerStatistics': True,
#     'hasEventPlayerHeatMap': True,
#     'detailId': 1,
#     'crowdsourcingDataDisplayEnabled': False,
#     'id': 12146548,
#     'awayRedCards': 2,
#     'startTimestamp': 1731360600,
#     'slug': 'vila-nova-fc-ponte-preta',
#     'finalResultOnly': False,
#     'feedLocked': False,
#     'isEditor': False},
#    {'tournament': {'name': 'Brasileirão Série B',
#      'slug': 'brasileirao-serie-b',
#      'category': {'name': 'Brazil',
#       'slug': 'brazil',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'id': 13,
#       'country': {'alpha2': 'BR',
#        'alpha3': 'BRA',
#        'name': 'Brazil',
#        'slug': 'brazil'},
#       'flag': 'brazil',
#       'alpha2': 'BR'},
#      'uniqueTournament': {'name': 'Brasileirão Série B',
#       'slug': 'brasileirao-serie-b',
#       'category': {'name': 'Brazil',
#        'slug': 'brazil',
#        'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#        'id': 13,
#        'country': {'alpha2': 'BR',
#         'alpha3': 'BRA',
#         'name': 'Brazil',
#         'slug': 'brazil'},
#        'flag': 'brazil',
#        'alpha2': 'BR'},
#       'userCount': 88065,
#       'id': 390,
#       'hasEventPlayerStatistics': True,
#       'displayInverseHomeAwayTeams': False},
#      'priority': 300,
#      'id': 1449},
#     'season': {'name': 'Brasileiro Serie B 2024',
#      'year': '2024',
#      'editor': False,
#      'id': 59015},
#     'roundInfo': {'round': 36},
#     'customId': 'tOsHO',
#     'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#     'winnerCode': 2,
#     'homeTeam': {'name': 'Coritiba',
#      'slug': 'coritiba',
#      'shortName': 'Coritiba',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 53378,
#      'nameCode': 'COR',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 1982,
#      'country': {'alpha2': 'BR',
#       'alpha3': 'BRA',
#       'name': 'Brazil',
#       'slug': 'brazil'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'ФК Коритиба'},
#       'shortNameTranslation': {}}},
#     'awayTeam': {'name': 'Santos',
#      'slug': 'santos',
#      'shortName': 'Santos',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 236142,
#      'nameCode': 'SAN',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 1968,
#      'country': {'alpha2': 'BR',
#       'alpha3': 'BRA',
#       'name': 'Brazil',
#       'slug': 'brazil'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'ФК Сантос'},
#       'shortNameTranslation': {}}},
#     'homeScore': {'current': 0,
#      'display': 0,
#      'period1': 0,
#      'period2': 0,
#      'normaltime': 0},
#     'awayScore': {'current': 2,
#      'display': 2,
#      'period1': 2,
#      'period2': 0,
#      'normaltime': 2},
#     'time': {'injuryTime1': 2,
#      'injuryTime2': 3,
#      'currentPeriodStartTimestamp': 1731373570},
#     'changes': {'changes': ['status.code',
#       'status.description',
#       'status.type'],
#      'changeTimestamp': 1731376452},
#     'hasGlobalHighlights': True,
#     'hasEventPlayerStatistics': True,
#     'hasEventPlayerHeatMap': True,
#     'detailId': 1,
#     'crowdsourcingDataDisplayEnabled': False,
#     'id': 12146545,
#     'startTimestamp': 1731369600,
#     'slug': 'coritiba-santos',
#     'finalResultOnly': False,
#     'feedLocked': False,
#     'isEditor': False},
#    {'tournament': {'name': 'Brasileirão Série B',
#      'slug': 'brasileirao-serie-b',
#      'category': {'name': 'Brazil',
#       'slug': 'brazil',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'id': 13,
#       'country': {'alpha2': 'BR',
#        'alpha3': 'BRA',
#        'name': 'Brazil',
#        'slug': 'brazil'},
#       'flag': 'brazil',
#       'alpha2': 'BR'},
#      'uniqueTournament': {'name': 'Brasileirão Série B',
#       'slug': 'brasileirao-serie-b',
#       'category': {'name': 'Brazil',
#        'slug': 'brazil',
#        'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#        'id': 13,
#        'country': {'alpha2': 'BR',
#         'alpha3': 'BRA',
#         'name': 'Brazil',
#         'slug': 'brazil'},
#        'flag': 'brazil',
#        'alpha2': 'BR'},
#       'userCount': 88065,
#       'id': 390,
#       'hasEventPlayerStatistics': True,
#       'displayInverseHomeAwayTeams': False},
#      'priority': 300,
#      'id': 1449},
#     'season': {'name': 'Brasileiro Serie B 2024',
#      'year': '2024',
#      'editor': False,
#      'id': 59015},
#     'roundInfo': {'round': 36},
#     'customId': 'XOsJMi',
#     'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#     'winnerCode': 1,
#     'homeTeam': {'name': 'Paysandu SC',
#      'slug': 'paysandu-sc',
#      'shortName': 'Paysandu',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 27864,
#      'nameCode': 'PAY',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 1997,
#      'country': {'alpha2': 'BR',
#       'alpha3': 'BRA',
#       'name': 'Brazil',
#       'slug': 'brazil'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'}},
#     'awayTeam': {'name': 'Brusque',
#      'slug': 'brusque',
#      'shortName': 'Brusque',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 13895,
#      'nameCode': 'BRU',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 21884,
#      'country': {'alpha2': 'BR',
#       'alpha3': 'BRA',
#       'name': 'Brazil',
#       'slug': 'brazil'},
#      'subTeams': [],
# ...
#        'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#        'id': 57,
#        'country': {'alpha2': 'UY',
#         'alpha3': 'URY',
#         'name': 'Uruguay',
#         'slug': 'uruguay'},
#        'flag': 'uruguay',
#        'alpha2': 'UY'},
#       'userCount': 12498,
#       'id': 278,
#       'hasEventPlayerStatistics': False,
#       'displayInverseHomeAwayTeams': False},
#      'priority': 0,
#      'id': 17126},
#     'season': {'name': 'Primera Division 2024',
#      'year': '2024',
#      'editor': False,
#      'id': 58264},
#     'roundInfo': {'round': 12},
#     'customId': 'Jobskak',
#     'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#     'winnerCode': 2,
#     'homeTeam': {'name': 'Deportivo Maldonado',
#      'slug': 'deportivo-maldonado',
#      'shortName': 'Dep. Maldonado',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 4174,
#      'nameCode': 'MAL',
#      'national': False,
#      'type': 0,
#      'id': 3234,
#      'country': {'alpha2': 'UY',
#       'alpha3': 'URY',
#       'name': 'Uruguay',
#       'slug': 'uruguay'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'ديبورتيفو مالدونادو',
#        'ru': 'Депортиво Мальдонадо'},
#       'shortNameTranslation': {}}},
#     'awayTeam': {'name': 'Racing de Montevideo',
#      'slug': 'racing-de-montevideo',
#      'shortName': 'Racing',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 7772,
#      'nameCode': 'RCM',
#      'national': False,
#      'type': 0,
#      'id': 25010,
#      'country': {'alpha2': 'UY',
#       'alpha3': 'URY',
#       'name': 'Uruguay',
#       'slug': 'uruguay'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'Расинг Клуб Монтевидео'},
#       'shortNameTranslation': {}}},
#     'homeScore': {'current': 0,
#      'display': 0,
#      'period1': 0,
#      'period2': 0,
#      'normaltime': 0},
#     'awayScore': {'current': 1,
#      'display': 1,
#      'period1': 0,
#      'period2': 1,
#      'normaltime': 1},
#     'time': {'injuryTime1': 1,
#      'injuryTime2': 4,
#      'currentPeriodStartTimestamp': 1731455447},
#     'changes': {'changes': ['status.code',
#       'status.description',
#       'status.type',
#       'homeScore.period2',
#       'homeScore.normaltime',
#       'awayScore.period2',
#       'awayScore.normaltime',
#       'time.currentPeriodStart'],
#      'changeTimestamp': 1731455450},
#     'hasGlobalHighlights': False,
#     'crowdsourcingDataDisplayEnabled': False,
#     'id': 13054022,
#     'startTimestamp': 1731448800,
#     'slug': 'racing-de-montevideo-deportivo-maldonado',
#     'finalResultOnly': False,
#     'feedLocked': False,
#     'isEditor': False},
#    {'tournament': {'name': 'Primera Division, Clausura',
#      'slug': 'primera-division-clausura',
#      'category': {'name': 'Uruguay',
#       'slug': 'uruguay',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'id': 57,
#       'country': {'alpha2': 'UY',
#        'alpha3': 'URY',
#        'name': 'Uruguay',
#        'slug': 'uruguay'},
#       'flag': 'uruguay',
#       'alpha2': 'UY'},
#      'uniqueTournament': {'name': 'Uruguayan Primera División',
#       'slug': 'primera-division',
#       'category': {'name': 'Uruguay',
#        'slug': 'uruguay',
#        'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#        'id': 57,
#        'country': {'alpha2': 'UY',
#         'alpha3': 'URY',
#         'name': 'Uruguay',
#         'slug': 'uruguay'},
#        'flag': 'uruguay',
#        'alpha2': 'UY'},
#       'userCount': 12498,
#       'id': 278,
#       'hasEventPlayerStatistics': False,
#       'displayInverseHomeAwayTeams': False},
#      'priority': 0,
#      'id': 17126},
#     'season': {'name': 'Primera Division 2024',
#      'year': '2024',
#      'editor': False,
#      'id': 58264},
#     'roundInfo': {'round': 12},
#     'customId': 'MobsFMc',
#     'status': {'code': 7, 'description': '2nd half', 'type': 'inprogress'},
#     'homeTeam': {'name': 'River Plate UY',
#      'slug': 'river-plate-uy',
#      'shortName': 'River',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 4389,
#      'nameCode': 'RIV',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 3237,
#      'country': {'alpha2': 'UY',
#       'alpha3': 'URY',
#       'name': 'Uruguay',
#       'slug': 'uruguay'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'Калифорния Ривер Плейт (УРУ)'},
#       'shortNameTranslation': {}}},
#     'awayTeam': {'name': 'Miramar Misiones',
#      'slug': 'miramar-misiones',
#      'shortName': 'Miramar',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 3046,
#      'nameCode': 'MIM',
#      'national': False,
#      'type': 0,
#      'id': 6880,
#      'country': {'alpha2': 'UY',
#       'alpha3': 'URY',
#       'name': 'Uruguay',
#       'slug': 'uruguay'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'}},
#     'homeScore': {'current': 0, 'display': 0, 'period1': 0},
#     'awayScore': {'current': 0, 'display': 0, 'period1': 0},
#     'time': {'injuryTime1': 1,
#      'initial': 2700,
#      'max': 5400,
#      'extra': 540,
#      'currentPeriodStartTimestamp': 1731505778},
#     'changes': {'changes': ['time.currentPeriodStart'],
#      'changeTimestamp': 1731506123},
#     'hasGlobalHighlights': False,
#     'crowdsourcingDataDisplayEnabled': False,
#     'id': 13054032,
#     'statusTime': {'prefix': '',
#      'initial': 2700,
#      'max': 5400,
#      'timestamp': 1731505778,
#      'extra': 540},
#     'startTimestamp': 1731501900,
#     'slug': 'miramar-misiones-river-plate-uy',
#     'lastPeriod': 'period2',
#     'finalResultOnly': False,
#     'feedLocked': False,
#     'isEditor': False},
#    {'tournament': {'name': 'Primera Division, Clausura, Main Round, Group A',
#      'slug': 'primera-division-clausura-main-round-group-a',
#      'category': {'name': 'Venezuela',
#       'slug': 'venezuela',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'id': 281,
#       'country': {'alpha2': 'VE',
#        'alpha3': 'VEN',
#        'name': 'Venezuela',
#        'slug': 'venezuela'},
#       'flag': 'venezuela',
#       'alpha2': 'VE'},
#      'uniqueTournament': {'name': 'Liga FUTVE',
#       'slug': 'primera-division',
#       'category': {'name': 'Venezuela',
#        'slug': 'venezuela',
#        'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#        'id': 281,
#        'country': {'alpha2': 'VE',
#         'alpha3': 'VEN',
#         'name': 'Venezuela',
#         'slug': 'venezuela'},
#        'flag': 'venezuela',
#        'alpha2': 'VE'},
#       'userCount': 5774,
#       'id': 231,
#       'hasEventPlayerStatistics': True,
#       'displayInverseHomeAwayTeams': False},
#      'priority': 0,
#      'id': 140603},
#     'season': {'name': 'Primera Division 2024',
#      'year': '2024',
#      'editor': False,
#      'id': 57694},
#     'roundInfo': {'round': 5},
#     'customId': 'FzcsGzc',
#     'status': {'code': 90, 'description': 'Abandoned', 'type': 'canceled'},
#     'homeTeam': {'name': 'Caracas F.C.',
#      'slug': 'caracas-fc',
#      'shortName': 'Caracas',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 7013,
#      'nameCode': 'CAR',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 6230,
#      'country': {'alpha2': 'VE',
#       'alpha3': 'VEN',
#       'name': 'Venezuela',
#       'slug': 'venezuela'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'Каракас ФК'},
#       'shortNameTranslation': {}}},
#     'awayTeam': {'name': 'Deportivo Táchira',
#      'slug': 'deportivo-tachira',
#      'shortName': 'Dep. Táchira',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 9189,
#      'nameCode': 'TAC',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 6231,
#      'country': {'alpha2': 'VE',
#       'alpha3': 'VEN',
#       'name': 'Venezuela',
#       'slug': 'venezuela'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'Депортиво Тачира'},
#       'shortNameTranslation': {}}},
#     'homeScore': {'current': 0,
#      'display': 0,
#      'period1': 0,
#      'period2': 0,
#      'normaltime': 0},
#     'awayScore': {'current': 4,
#      'display': 4,
#      'period1': 2,
#      'period2': 2,
#      'normaltime': 4},
#     'time': {'injuryTime1': 3, 'currentPeriodStartTimestamp': 1731454429},
#     'changes': {'changes': ['status.code',
#       'status.description',
#       'status.type'],
#      'changeTimestamp': 1731457371},
#     'hasGlobalHighlights': False,
#     'hasEventPlayerStatistics': False,
#     'hasEventPlayerHeatMap': False,
#     'detailId': 1,
#     'crowdsourcingDataDisplayEnabled': False,
#     'id': 13049163,
#     'startTimestamp': 1731450600,
#     'slug': 'deportivo-tachira-caracasc',
#     'finalResultOnly': False,
#     'feedLocked': False,
#     'isEditor': False},
#    {'tournament': {'name': 'Primera Division, Clausura, Main Round, Group A',
#      'slug': 'primera-division-clausura-main-round-group-a',
#      'category': {'name': 'Venezuela',
#       'slug': 'venezuela',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'id': 281,
#       'country': {'alpha2': 'VE',
#        'alpha3': 'VEN',
#        'name': 'Venezuela',
#        'slug': 'venezuela'},
#       'flag': 'venezuela',
#       'alpha2': 'VE'},
#      'uniqueTournament': {'name': 'Liga FUTVE',
#       'slug': 'primera-division',
#       'category': {'name': 'Venezuela',
#        'slug': 'venezuela',
#        'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#        'id': 281,
#        'country': {'alpha2': 'VE',
#         'alpha3': 'VEN',
#         'name': 'Venezuela',
#         'slug': 'venezuela'},
#        'flag': 'venezuela',
#        'alpha2': 'VE'},
#       'userCount': 5774,
#       'id': 231,
#       'hasEventPlayerStatistics': True,
#       'displayInverseHomeAwayTeams': False},
#      'priority': 0,
#      'id': 140603},
#     'season': {'name': 'Primera Division 2024',
#      'year': '2024',
#      'editor': False,
#      'id': 57694},
#     'roundInfo': {'round': 5},
#     'customId': 'MzcskBed',
#     'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#     'winnerCode': 3,
#     'homeTeam': {'name': 'Zamora',
#      'slug': 'zamora',
#      'shortName': 'Zamora',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 3183,
#      'nameCode': 'ZAM',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 6237,
#      'country': {'alpha2': 'VE',
#       'alpha3': 'VEN',
#       'name': 'Venezuela',
#       'slug': 'venezuela'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ar': 'زامورا إف سي',
#        'ru': 'Замора ФК'},
#       'shortNameTranslation': {}}},
#     'awayTeam': {'name': 'Rayo Zuliano',
#      'slug': 'rayo-zuliano',
#      'shortName': 'Rayo Zuliano',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 2877,
#      'nameCode': 'RAY',
#      'national': False,
#      'type': 0,
#      'id': 386310,
#      'country': {'alpha2': 'VE',
#       'alpha3': 'VEN',
#       'name': 'Venezuela',
#       'slug': 'venezuela'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'}},
#     'homeScore': {'current': 3,
#      'display': 3,
#      'period1': 2,
#      'period2': 1,
#      'normaltime': 3},
#     'awayScore': {'current': 3,
#      'display': 3,
#      'period1': 2,
#      'period2': 1,
#      'normaltime': 3},
#     'time': {'injuryTime1': 7,
#      'injuryTime2': 5,
#      'currentPeriodStartTimestamp': 1731454801},
#     'changes': {'changes': ['status.code',
#       'status.description',
#       'status.type'],
#      'changeTimestamp': 1731457772},
#     'hasGlobalHighlights': True,
#     'hasEventPlayerStatistics': True,
#     'hasEventPlayerHeatMap': True,
#     'detailId': 1,
#     'crowdsourcingDataDisplayEnabled': False,
#     'id': 13049164,
#     'homeRedCards': 1,
#     'awayRedCards': 1,
#     'startTimestamp': 1731450600,
#     'slug': 'rayo-zuliano-zamora',
#     'finalResultOnly': False,
#     'feedLocked': False,
#     'isEditor': False},
#    {'tournament': {'name': 'V-League 1',
#      'slug': 'v-league-1',
#      'category': {'name': 'Vietnam',
#       'slug': 'vietnam',
#       'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#       'id': 366,
#       'country': {'alpha2': 'VN',
#        'alpha3': 'VNM',
#        'name': 'Vietnam',
#        'slug': 'vietnam'},
#       'flag': 'vietnam',
#       'alpha2': 'VN'},
#      'uniqueTournament': {'name': 'V-League 1',
#       'slug': 'v-league-1',
#       'category': {'name': 'Vietnam',
#        'slug': 'vietnam',
#        'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#        'id': 366,
#        'country': {'alpha2': 'VN',
#         'alpha3': 'VNM',
#         'name': 'Vietnam',
#         'slug': 'vietnam'},
#        'flag': 'vietnam',
#        'alpha2': 'VN'},
#       'userCount': 4379,
#       'id': 626,
#       'hasEventPlayerStatistics': False,
#       'displayInverseHomeAwayTeams': False},
#      'priority': 0,
#      'id': 4104},
#     'season': {'name': 'V-League 1 24/25',
#      'year': '24/25',
#      'editor': False,
#      'seasonCoverageInfo': {'editorCoverageLevel': 3},
#      'id': 65000},
#     'roundInfo': {'round': 7},
#     'customId': 'vmnsCmn',
#     'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#     'winnerCode': 2,
#     'homeTeam': {'name': 'Hồ Chí Minh City',
#      'slug': 'ho-chi-minh-city',
#      'shortName': 'Hồ Chí Minh',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 2093,
#      'nameCode': 'HCM',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 33120,
#      'country': {'alpha2': 'VN',
#       'alpha3': 'VNM',
#       'name': 'Vietnam',
#       'slug': 'vietnam'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'Хошимин'},
#       'shortNameTranslation': {}}},
#     'awayTeam': {'name': 'Nam Định',
#      'slug': 'nam-djinh',
#      'shortName': 'Nam Định',
#      'sport': {'name': 'Football', 'slug': 'football', 'id': 1},
#      'userCount': 5261,
#      'nameCode': 'DIN',
#      'disabled': False,
#      'national': False,
#      'type': 0,
#      'id': 33127,
#      'country': {'alpha2': 'VN',
#       'alpha3': 'VNM',
#       'name': 'Vietnam',
#       'slug': 'vietnam'},
#      'subTeams': [],
#      'teamColors': {'primary': '#374df5',
#       'secondary': '#374df5',
#       'text': '#ffffff'},
#      'fieldTranslations': {'nameTranslation': {'ru': 'ФК Нам Динх'},
#       'shortNameTranslation': {}}},
#     'homeScore': {'current': 0,
#      'display': 0,
#      'period1': 0,
#      'period2': 0,
#      'normaltime': 0},
#     'awayScore': {'current': 3,
#      'display': 3,
#      'period1': 2,
#      'period2': 1,
#      'normaltime': 3},
#     'time': {'injuryTime1': 5,
#      'injuryTime2': 4,
#      'currentPeriodStartTimestamp': 1731334285},
#     'changes': {'changes': ['status.code',
#       'status.description',
#       'status.type',
#       'homeScore.period2',
#       'homeScore.normaltime',
#       'awayScore.period2',
#       'awayScore.normaltime',
#       'time.currentPeriodStart'],
#      'changeTimestamp': 1731334289},
#     'hasGlobalHighlights': True,
#     'crowdsourcingDataDisplayEnabled': False,
#     'id': 12694146,
#     'startTimestamp': 1731327300,
#     'slug': 'nam-dinh-ho-chi-minh-city',
#     'finalResultOnly': False,
#     'feedLocked': False,
#     'isEditor': False}],
#   'count': 77,
#   'isprogress': False}]

# %%
from datetime import datetime, timedelta

# Başlangıç tarihi
start_date = datetime.strptime("2024-06-21", "%Y-%m-%d")
# Bitiş tarihi (bugünün tarihi)
end_date = datetime.strptime("2024-08-01", "%Y-%m-%d")

# Başlangıç ve bitiş tarihleri arasındaki gün sayısını hesapla
delta = end_date - start_date

# Her gün için döngü
for i in range(delta.days + 1):
    current_date = start_date + timedelta(days=i)
    date_str = current_date.strftime("%Y-%m-%d")
    
    # FixtureDataHandler'ı mevcut tarih ile oluştur
    handler = FixtureDataHandler(date_str)
    
    # API'den verileri çek
    data = handler.fetch_fixtures_from_api()
    
    # Verileri veritabanına kaydet
    handler.save_fixtures_to_db(data)
    
    print(f"{date_str} işlemi tamamlandı.")

print("Tüm işlemler tamamlandı.")
# Out:
# 2024-06-21 işlemi tamamlandı.
# 2024-06-22 işlemi tamamlandı.
# 2024-06-23 işlemi tamamlandı.
# 2024-06-24 işlemi tamamlandı.
# 2024-06-25 işlemi tamamlandı.
# 2024-06-26 işlemi tamamlandı.
# 2024-06-27 işlemi tamamlandı.
# 2024-06-28 işlemi tamamlandı.
# 2024-06-29 işlemi tamamlandı.
# 2024-06-30 işlemi tamamlandı.
# 2024-07-01 işlemi tamamlandı.
# 2024-07-02 işlemi tamamlandı.
# 2024-07-03 işlemi tamamlandı.
# 2024-07-04 işlemi tamamlandı.
# 2024-07-05 işlemi tamamlandı.
# 2024-07-06 işlemi tamamlandı.
# 2024-07-07 işlemi tamamlandı.
# 2024-07-08 işlemi tamamlandı.
# 2024-07-09 işlemi tamamlandı.
# 2024-07-10 işlemi tamamlandı.
# 2024-07-11 işlemi tamamlandı.
# 2024-07-12 işlemi tamamlandı.
# 2024-07-13 işlemi tamamlandı.
# 2024-07-14 işlemi tamamlandı.
# 2024-07-15 işlemi tamamlandı.
# 2024-07-16 işlemi tamamlandı.
# 2024-07-17 işlemi tamamlandı.
# 2024-07-18 işlemi tamamlandı.
# 2024-07-19 işlemi tamamlandı.
# 2024-07-20 işlemi tamamlandı.
# 2024-07-21 işlemi tamamlandı.
# 2024-07-22 işlemi tamamlandı.
# 2024-07-23 işlemi tamamlandı.
# 2024-07-24 işlemi tamamlandı.
# 2024-07-25 işlemi tamamlandı.
# 2024-07-26 işlemi tamamlandı.
# 2024-07-27 işlemi tamamlandı.
# 2024-07-28 işlemi tamamlandı.
# 2024-07-29 işlemi tamamlandı.
# 2024-07-30 işlemi tamamlandı.
# 2024-07-31 işlemi tamamlandı.
# 2024-08-01 işlemi tamamlandı.
# Tüm işlemler tamamlandı.
