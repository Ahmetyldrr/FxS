# %%
import os
import django
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'Home.settings')
django.setup()
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
#verileri oku
from basemodels.models import FikstureModelData
import pandas as pd

data = FikstureModelData.objects.all().values()
data_list = list(data)
df = pd.DataFrame(data_list)
df_exploded = df.explode('data')
expanded_data = pd.json_normalize(df_exploded['data'])
expanded_data['tarih'] = list(df_exploded['tarih'])
expanded_data
# Out:
#      customId  winnerCode  hasGlobalHighlights hasEventPlayerStatistics  \
# 0         dsr         2.0                 True                     True
# 1         NsU         1.0                 True                     True
# 2         hso         1.0                 True                     True
# 3     tgbsBgb         1.0                 True                     True
# 4     LgbsVgb         1.0                 True                     True
# ..        ...         ...                  ...                      ...
# 549   fYbsmYb         NaN                False                      NaN
# 550  lQrsjlLb         NaN                False                      NaN
# 551  fQrsXlpd         NaN                False                      NaN
# 552   wlpskEu         NaN                False                      NaN
# 553   oNosxEu         NaN                False                      NaN
#
#     hasEventPlayerHeatMap  detailId  crowdsourcingDataDisplayEnabled  \
# 0                    True       1.0                            False
# 1                    True       1.0                            False
# 2                    True       1.0                            False
# 3                    True       1.0                            False
# 4                    True       1.0                            False
# ..                    ...       ...                              ...
# 549                   NaN       NaN                            False
# 550                   NaN       NaN                            False
# 551                   NaN       NaN                            False
# 552                   NaN       NaN                            False
# 553                   NaN       NaN                            False
#
#            id  startTimestamp                                  slug  ...  \
# 0    12437039      1729429200         manchester-city-wolverhampton  ...
# 1    12437032      1729438200                     liverpool-chelsea  ...
# 2    12437036      1729537200      nottingham-forest-crystal-palace  ...
# 3    12437847      1729425600               mallorca-rayo-vallecano  ...
# 4    12437835      1729433700               leganes-atletico-madrid  ...
# ..        ...             ...                                   ...  ...
# 549  12872190      1729622700  connahs-quay-nomads-aberystwyth-town  ...
# 550  12464047      1729638000           ecuador-u17-new-zealand-u17  ...
# 551  12464084      1729638000    dominican-republic-u17-nigeria-u17  ...
# 552  12464043      1729627200                colombia-u17-spain-u17  ...
# 553  12464038      1729627200               usa-u17-south-korea-u17  ...
#
#      homeTeam.gender  awayTeam.gender  homeScore.aggregated  \
# 0                NaN              NaN                   NaN
# 1                NaN              NaN                   NaN
# 2                NaN              NaN                   NaN
# 3                NaN              NaN                   NaN
# 4                NaN              NaN                   NaN
# ..               ...              ...                   ...
# 549              NaN              NaN                   NaN
# 550              NaN              NaN                   NaN
# 551              NaN              NaN                   NaN
# 552              NaN              NaN                   NaN
# 553              NaN              NaN                   NaN
#
#     awayScore.aggregated homeScore.penalties awayScore.penalties  \
# 0                    NaN                 NaN                 NaN
# 1                    NaN                 NaN                 NaN
# 2                    NaN                 NaN                 NaN
# 3                    NaN                 NaN                 NaN
# 4                    NaN                 NaN                 NaN
# ..                   ...                 ...                 ...
# 549                  NaN                 NaN                 NaN
# 550                  NaN                 NaN                 NaN
# 551                  NaN                 NaN                 NaN
# 552                  NaN                 NaN                 NaN
# 553                  NaN                 NaN                 NaN
#
#     tournament.uniqueTournament.primaryColorHex  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 549                                         NaN
# 550                                         NaN
# 551                                         NaN
# 552                                         NaN
# 553                                         NaN
#
#     tournament.uniqueTournament.secondaryColorHex coverage       tarih
# 0                                             NaN      NaN  2024-10-21
# 1                                             NaN      NaN  2024-10-21
# 2                                             NaN      NaN  2024-10-21
# 3                                             NaN      NaN  2024-10-21
# 4                                             NaN      NaN  2024-10-21
# ..                                            ...      ...         ...
# 549                                           NaN      NaN  2024-10-22
# 550                                           NaN      NaN  2024-10-22
# 551                                           NaN      NaN  2024-10-22
# 552                                           NaN      NaN  2024-10-22
# 553                                           NaN      NaN  2024-10-22
#
# [554 rows x 143 columns]

# %%
expanded_data.to_excel("FullData.xlsx")

# %%
list(expanded_data.columns)
# Out:
# ['customId',
#  'winnerCode',
#  'hasGlobalHighlights',
#  'hasEventPlayerStatistics',
#  'hasEventPlayerHeatMap',
#  'detailId',
#  'crowdsourcingDataDisplayEnabled',
#  'id',
#  'startTimestamp',
#  'slug',
#  'finalResultOnly',
#  'feedLocked',
#  'isEditor',
#  'tournament.name',
#  'tournament.slug',
#  'tournament.category.name',
#  'tournament.category.slug',
#  'tournament.category.sport.name',
#  'tournament.category.sport.slug',
#  'tournament.category.sport.id',
#  'tournament.category.id',
#  'tournament.category.country.alpha2',
#  'tournament.category.country.alpha3',
#  'tournament.category.country.name',
#  'tournament.category.country.slug',
#  'tournament.category.flag',
#  'tournament.category.alpha2',
#  'tournament.uniqueTournament.name',
#  'tournament.uniqueTournament.slug',
#  'tournament.uniqueTournament.category.name',
#  'tournament.uniqueTournament.category.slug',
#  'tournament.uniqueTournament.category.sport.name',
#  'tournament.uniqueTournament.category.sport.slug',
#  'tournament.uniqueTournament.category.sport.id',
#  'tournament.uniqueTournament.category.id',
#  'tournament.uniqueTournament.category.country.alpha2',
#  'tournament.uniqueTournament.category.country.alpha3',
#  'tournament.uniqueTournament.category.country.name',
#  'tournament.uniqueTournament.category.country.slug',
#  'tournament.uniqueTournament.category.flag',
#  'tournament.uniqueTournament.category.alpha2',
#  'tournament.uniqueTournament.userCount',
#  'tournament.uniqueTournament.id',
#  'tournament.uniqueTournament.hasEventPlayerStatistics',
#  'tournament.uniqueTournament.displayInverseHomeAwayTeams',
#  'tournament.priority',
#  'tournament.id',
#  'season.name',
#  'season.year',
#  'season.editor',
#  'season.id',
#  'roundInfo.round',
#  'status.code',
#  'status.description',
#  'status.type',
#  'homeTeam.name',
#  'homeTeam.slug',
#  'homeTeam.shortName',
#  'homeTeam.sport.name',
#  'homeTeam.sport.slug',
#  'homeTeam.sport.id',
#  'homeTeam.userCount',
#  'homeTeam.nameCode',
#  'homeTeam.disabled',
#  'homeTeam.national',
#  'homeTeam.type',
#  'homeTeam.id',
#  'homeTeam.country.alpha2',
#  'homeTeam.country.alpha3',
#  'homeTeam.country.name',
#  'homeTeam.country.slug',
#  'homeTeam.subTeams',
#  'homeTeam.teamColors.primary',
#  'homeTeam.teamColors.secondary',
#  'homeTeam.teamColors.text',
#  'homeTeam.fieldTranslations.nameTranslation.ar',
#  'homeTeam.fieldTranslations.nameTranslation.ru',
#  'awayTeam.name',
#  'awayTeam.slug',
#  'awayTeam.shortName',
#  'awayTeam.sport.name',
#  'awayTeam.sport.slug',
#  'awayTeam.sport.id',
#  'awayTeam.userCount',
#  'awayTeam.nameCode',
#  'awayTeam.disabled',
#  'awayTeam.national',
#  'awayTeam.type',
#  'awayTeam.id',
#  'awayTeam.country.alpha2',
#  'awayTeam.country.alpha3',
#  'awayTeam.country.name',
#  'awayTeam.country.slug',
#  'awayTeam.subTeams',
#  'awayTeam.teamColors.primary',
#  'awayTeam.teamColors.secondary',
#  'awayTeam.teamColors.text',
#  'awayTeam.fieldTranslations.nameTranslation.ar',
#  'awayTeam.fieldTranslations.nameTranslation.ru',
#  'homeScore.current',
#  'homeScore.display',
#  'homeScore.period1',
#  'homeScore.period2',
#  'homeScore.normaltime',
#  'awayScore.current',
#  'awayScore.display',
#  'awayScore.period1',
#  'awayScore.period2',
#  'awayScore.normaltime',
#  'time.injuryTime1',
#  'time.injuryTime2',
#  'time.currentPeriodStartTimestamp',
#  'changes.changes',
#  'changes.changeTimestamp',
#  'homeRedCards',
#  'awayRedCards',
#  'tournament.uniqueTournament.hasPerformanceGraphFeature',
#  'season.seasonCoverageInfo.editorCoverageLevel',
#  'lastPeriod',
#  'time.initial',
#  'time.max',
#  'time.extra',
#  'statusTime.prefix',
#  'statusTime.initial',
#  'statusTime.max',
#  'statusTime.timestamp',
#  'statusTime.extra',
#  'aggregatedWinnerCode',
#  'previousLegEventId',
#  'tournament.isGroup',
#  'tournament.isLive',
#  'roundInfo.name',
#  'roundInfo.cupRoundType',
#  'homeTeam.gender',
#  'awayTeam.gender',
#  'homeScore.aggregated',
#  'awayScore.aggregated',
#  'homeScore.penalties',
#  'awayScore.penalties',
#  'tournament.uniqueTournament.primaryColorHex',
#  'tournament.uniqueTournament.secondaryColorHex',
#  'coverage',
#  'tarih']

# %%
model_cols = ['id','startTimestamp','slug','tournament.uniqueTournament.id','season.id',
                'roundInfo.round','status.type','homeTeam.id','awayTeam.id',
                'homeScore.current','homeScore.display','homeScore.period1','homeScore.period2','homeScore.normaltime',
                'awayScore.current','awayScore.display','awayScore.period1','awayScore.period2','awayScore.normaltime',
                ]

new_cols = ['id','date','slug','tournament_uniqueTournament_id','season_id',
                'roundInfo_round','status_type','homeTeam_id','awayTeam_id',
                'homeScore_current','homeScore_display','homeScore_period1','homeScore_period2','homeScore_normaltime',
                'awayScore_current','awayScore_display','awayScore_period1','awayScore_period2','awayScore_normaltime',
                ]


df1 = expanded_data[model_cols]
df1.columns = new_cols
df1
# Out:
#            id        date                                  slug  \
# 0    12437039  1729429200         manchester-city-wolverhampton
# 1    12437032  1729438200                     liverpool-chelsea
# 2    12437036  1729537200      nottingham-forest-crystal-palace
# 3    12437847  1729425600               mallorca-rayo-vallecano
# 4    12437835  1729433700               leganes-atletico-madrid
# ..        ...         ...                                   ...
# 549  12872190  1729622700  connahs-quay-nomads-aberystwyth-town
# 550  12464047  1729638000           ecuador-u17-new-zealand-u17
# 551  12464084  1729638000    dominican-republic-u17-nigeria-u17
# 552  12464043  1729627200                colombia-u17-spain-u17
# 553  12464038  1729627200               usa-u17-south-korea-u17
#
#      tournament_uniqueTournament_id  season_id  roundInfo_round status_type  \
# 0                                17      61627              8.0    finished
# 1                                17      61627              8.0    finished
# 2                                17      61627              8.0    finished
# 3                                 8      61643             10.0    finished
# 4                                 8      61643             10.0    finished
# ..                              ...        ...              ...         ...
# 549                             367      61686             27.0  notstarted
# 550                             827      61934              3.0  notstarted
# 551                             827      61934              3.0  notstarted
# 552                             827      61934              3.0  notstarted
# 553                             827      61934              3.0  notstarted
#
#      homeTeam_id  awayTeam_id  homeScore_current  homeScore_display  \
# 0              3           17                1.0                1.0
# 1             44           38                2.0                2.0
# 2             14            7                1.0                1.0
# 3           2826         2818                1.0                1.0
# 4           2836         2845                3.0                3.0
# ..           ...          ...                ...                ...
# 549         4912         4905                NaN                NaN
# 550       215559        44561                NaN                NaN
# 551        44555       413097                NaN                NaN
# 552        48960        38071                NaN                NaN
# 553        48972        36914                NaN                NaN
#
#      homeScore_period1  homeScore_period2  homeScore_normaltime  \
# 0                  1.0                0.0                   1.0
# 1                  1.0                1.0                   2.0
# 2                  0.0                1.0                   1.0
# 3                  0.0                1.0                   1.0
# 4                  0.0                3.0                   3.0
# ..                 ...                ...                   ...
# 549                NaN                NaN                   NaN
# 550                NaN                NaN                   NaN
# 551                NaN                NaN                   NaN
# 552                NaN                NaN                   NaN
# 553                NaN                NaN                   NaN
#
#      awayScore_current  awayScore_display  awayScore_period1  \
# 0                  2.0                2.0                1.0
# 1                  1.0                1.0                0.0
# 2                  0.0                0.0                0.0
# 3                  0.0                0.0                0.0
# 4                  1.0                1.0                1.0
# ..                 ...                ...                ...
# 549                NaN                NaN                NaN
# 550                NaN                NaN                NaN
# 551                NaN                NaN                NaN
# 552                NaN                NaN                NaN
# 553                NaN                NaN                NaN
#
#      awayScore_period2  awayScore_normaltime
# 0                  1.0                   2.0
# 1                  1.0                   1.0
# 2                  0.0                   0.0
# 3                  0.0                   0.0
# 4                  0.0                   1.0
# ..                 ...                   ...
# 549                NaN                   NaN
# 550                NaN                   NaN
# 551                NaN                   NaN
# 552                NaN                   NaN
# 553                NaN                   NaN
#
# [554 rows x 19 columns]

# %%
from basemodels.models import Tournament, Season, Team
from basemodels.models import FikstureModelData


class SofascoreAPI:
    def __init__(self):
        pass

    def fetch_data(self):
        data = FikstureModelData.objects.all().values()
        data_list = list(data)
        df = pd.DataFrame(data_list)
        df_exploded = df.explode('data')
        expanded_data = pd.json_normalize(df_exploded['data'])
        expanded_data['tarih'] = list(df_exploded['tarih'])
        veri = expanded_data.copy()
        veri.columns = [item.replace(".", "_") for item in veri.columns]
        return veri

    def tournament_data(self):
        verim = self.fetch_data()
        if verim is None:
            raise ValueError("Veri işlenmedi. Önce 'process_data()' metodunu çalıştırın.")
        
        # Aynı uniqueTournament_id'ye sahip olanları tekrar kontrol et
        verim = verim.drop_duplicates("tournament_uniqueTournament_id")
        
        cols = [
            "tournament_uniqueTournament_id", "tournament_name", "tournament_slug", "tournament_category_name",
            "tournament_category_slug", "tournament_uniqueTournament_category_id", 
            "tournament_uniqueTournament_hasEventPlayerStatistics", "tournament_id", "tournament_isGroup", 
            "tournament_uniqueTournament_hasPerformanceGraphFeature"
        ]
        
        for col in cols:
            if col not in verim.columns:
                verim.loc[:, col] = 0

        verim = verim[cols]

        for _, row in verim.iterrows():
            tournament_id = row['tournament_uniqueTournament_id']
            
            if pd.isna(tournament_id):
                print(f"Geçersiz tournament_uniqueTournament_id: {tournament_id}, atlanıyor.")
                continue
        
            if not Tournament.objects.filter(tournament_id=tournament_id).exists():
                Tournament.objects.create(
                    tournament_id=row['tournament_uniqueTournament_id'],
                    tournament_name=row['tournament_name'],
                    tournament_slug=row['tournament_slug'],
                    tournament_category_name=row['tournament_category_name'],
                    tournament_category_slug=row['tournament_category_slug'],
                    tournament_uniqueTournament_category_id=row['tournament_uniqueTournament_category_id'],
                    tournament_model_id=row['tournament_id'],
                    tournament_isGroup=row['tournament_isGroup'] if pd.notna(row['tournament_isGroup']) else False,
                    tournament_uniqueTournament_hasPerformanceGraphFeature=row['tournament_uniqueTournament_hasPerformanceGraphFeature'] if pd.notna(row['tournament_uniqueTournament_hasPerformanceGraphFeature']) else False
                )
                print(f"Tournament ID {tournament_id} başarıyla eklendi.")
            else:
                print(f"Tournament ID {tournament_id} zaten mevcut, eklenmedi.")

    def season_data(self):
        verim = self.fetch_data()
        if verim is None:
            raise ValueError("Veri işlenmedi. Önce 'process_data()' metodunu çalıştırın.")
        
        verim = verim.drop_duplicates("season_id")
        
        season_cols = ["season_id", "season_name", "season_year","tournament_uniqueTournament_id"]

        for col in season_cols:
            if col not in verim.columns:
                verim.loc[:, col] = 0

        verim = verim[season_cols]

        for _, row in verim.iterrows():
            season_id = row['season_id']
            tournament_id = row.get('tournament_uniqueTournament_id')
    
            if pd.isna(season_id) or pd.isna(tournament_id):
                print(f"Geçersiz season_id veya tournament_id: Season ID={season_id}, Tournament ID={tournament_id}. Atlanıyor.")
                continue
    
            if not Season.objects.filter(season_id=season_id).exists():
                tournament_instance = Tournament.objects.filter(tournament_id=tournament_id).first()
                
                if tournament_instance:
                    Season.objects.create(
                        season_id=row['season_id'],
                        season_name=row['season_name'],
                        season_year=row['season_year'],
                        tournament=tournament_instance  # Doğru sütun adı burada kullanılıyor
                    )
                    print(f"Season ID {season_id} başarıyla eklendi.")
                else:
                    print(f"Tournament ID {tournament_id} bulunamadı, Season ID {season_id} eklenemedi.")
            else:
                print(f"Season ID {season_id} zaten mevcut, eklenmedi.")
    
   
    def team_data(self):

        data = self.fetch_data()
        homecols = [
                    "homeTeam_id", "homeTeam_name", "homeTeam_slug", "homeTeam_shortName",
                    "homeTeam_nameCode", "homeTeam_national", "tournament_uniqueTournament_id", "season_id"
                ]
        
        awaycols = [
                    "awayTeam_id", "awayTeam_name", "awayTeam_slug", "awayTeam_shortName",
                    "awayTeam_nameCode", "awayTeam_national", "tournament_uniqueTournament_id", "season_id"
                ]
        
        # Home takımı için veri seçimi ve kolon isimlerinin ayarlanması
        homedata = data[homecols]
        homedata.columns = ["team_id", "team_name", "team_slug", "team_shortName",
                                       "team_nameCode", "team_national", "tournament_id", "season_id"]
        
        # Away takımı için veri seçimi ve kolon isimlerinin ayarlanması
        awaydata = data[awaycols]
        awaydata.columns  = ["team_id", "team_name", "team_slug", "team_shortName",
                                       "team_nameCode", "team_national", "tournament_id", "season_id"]
        
        # Home ve Away takımları birleştirme
        teamdata = pd.concat([homedata, awaydata])
        teamdata = teamdata.drop_duplicates(subset=["team_id", "tournament_id", "season_id"])
       
        for _, row in teamdata.iterrows():
            team_id = row['team_id']
            tournament_id = row['tournament_id']
            season_id = row['season_id']
            
            # Geçersiz veya eksik id'leri atla
            if pd.isna(team_id) or pd.isna(tournament_id) or pd.isna(season_id):
                print(f"Geçersiz değer: Team ID={team_id}, Tournament ID={tournament_id}, Season ID={season_id}. Atlanıyor.")
                continue

            # İlgili tournament ve season nesnelerini getir
            tournament_instance = Tournament.objects.filter(tournament_id=tournament_id).first()
            season_instance = Season.objects.filter(season_id=season_id).first()

            if tournament_instance and season_instance:
                # Takımın veritabanında var olup olmadığını kontrol et, yoksa oluştur
                if not Team.objects.filter(team_id=team_id, tournament=tournament_instance, season=season_instance).exists():
                    Team.objects.create(
                        team_id=team_id,
                        team_name=row['team_name'],
                        team_slug=row['team_slug'],
                        team_shortName=row['team_shortName'],
                        team_nameCode=row['team_nameCode'],
                        team_national=row['team_national'],
                        tournament=tournament_instance,  # ForeignKey olan alanlar
                        season=season_instance           # ForeignKey olan alanlar
                    )
                    print(f"Team ID {team_id} başarıyla eklendi.")
                else:
                    print(f"Team ID {team_id} zaten mevcut, eklenmedi.")
            else:
                print(f"Tournament ID {tournament_id} veya Season ID {season_id} bulunamadı.")

    def match_data(self):
        # Fetch data from the API or existing model
        verim = self.fetch_data()
        if verim is None:
            raise ValueError("Veri işlenmedi. Lütfen önce 'process_data()' metodunu çalıştırın.")
        
     
     
        new_cols = ['id', 'startTimestamp', 'slug', 'tournament_uniqueTournament_id', 'season_id',
                    'roundInfo_round', 'status_type', 'homeTeam_id', 'awayTeam_id',
                    'homeScore_current', 'homeScore_display', 'homeScore_period1', 'homeScore_period2', 'homeScore_normaltime',
                    'awayScore_current', 'awayScore_display', 'awayScore_period1', 'awayScore_period2', 'awayScore_normaltime']
        
        df1 = verim[model_cols]  # Verileri modeldeki sütunlara göre seçme
        df1.columns = new_cols  # Sütunları yeniden isimlendirme

        for _, row in df1.iterrows():
            match_id = row['id']
            tournament_id = row['tournament_uniqueTournament_id']
            season_id = row['season_id']
            home_team_id = row['homeTeam_id']
            away_team_id = row['awayTeam_id']
            
            # Geçersiz veya eksik id'leri atla
            if pd.isna(match_id) or pd.isna(tournament_id) or pd.isna(season_id) or pd.isna(home_team_id) or pd.isna(away_team_id):
                print(f"Geçersiz değer: Match ID={match_id}, Tournament ID={tournament_id}, Season ID={season_id}, Home Team ID={home_team_id}, Away Team ID={away_team_id}. Atlanıyor.")
                continue

            # İlgili foreign key nesnelerini getir
            tournament_instance = Tournament.objects.filter(tournament_id=tournament_id).first()
            season_instance = Season.objects.filter(season_id=season_id).first()
            home_team_instance = Team.objects.filter(team_id=home_team_id).first()
            away_team_instance = Team.objects.filter(team_id=away_team_id).first()

            if tournament_instance and season_instance and home_team_instance and away_team_instance:
                # Match'in veritabanında olup olmadığını kontrol et, yoksa oluştur
                if not Match.objects.filter(id=match_id).exists():
                    Match.objects.create(
                        id=match_id,
                        startTimestamp=row['date'],  # DateTimeField olarak datetime verisi
                        slug=row['slug'],
                        tournament=tournament_instance,
                        season=season_instance,
                        home_team=home_team_instance,
                        away_team=away_team_instance,
                        home_score_current=row['homeScore_current'],
                        home_score_display=row['homeScore_display'],
                        home_score_period1=row['homeScore_period1'],
                        home_score_period2=row['homeScore_period2'],
                        home_score_normaltime=row['homeScore_normaltime'],
                        away_score_current=row['awayScore_current'],
                        away_score_display=row['awayScore_display'],
                        away_score_period1=row['awayScore_period1'],
                        away_score_period2=row['awayScore_period2'],
                        away_score_normaltime=row['awayScore_normaltime']
                    )
                    print(f"Match ID {match_id} başarıyla eklendi.")
                else:
                    print(f"Match ID {match_id} zaten mevcut, eklenmedi.")
            else:
                print(f"Tournament ID {tournament_id}, Season ID {season_id}, Home Team ID {home_team_id}, Away Team ID {away_team_id} bulunamadı.")





# SofascoreAPI sınıfını kullanarak team_data'yı veritabanına kaydetmek için:
api = SofascoreAPI()
teamdata = api.fetch_data()  # Veriyi getirin (API'den ya da dosyadan)
api.tournament_data()
api.season_data()
api.team_data()
api.match_data()
print("İşlemler bitti")
# Out:
# Tournament ID 17 zaten mevcut, eklenmedi.
# Tournament ID 8 zaten mevcut, eklenmedi.
# Tournament ID 23 zaten mevcut, eklenmedi.
# Tournament ID 35 zaten mevcut, eklenmedi.
# Tournament ID 34 zaten mevcut, eklenmedi.
# Tournament ID 37 zaten mevcut, eklenmedi.
# Tournament ID 325 zaten mevcut, eklenmedi.
# Tournament ID 52 zaten mevcut, eklenmedi.
# Tournament ID 38 zaten mevcut, eklenmedi.
# Tournament ID 185 zaten mevcut, eklenmedi.
# Tournament ID 2132 zaten mevcut, eklenmedi.
# Tournament ID 155 zaten mevcut, eklenmedi.
# Tournament ID 11621 zaten mevcut, eklenmedi.
# Tournament ID 170 zaten mevcut, eklenmedi.
# Tournament ID 210 zaten mevcut, eklenmedi.
# Tournament ID 18 zaten mevcut, eklenmedi.
# Tournament ID 54 zaten mevcut, eklenmedi.
# Tournament ID 53 zaten mevcut, eklenmedi.
# Tournament ID 182 zaten mevcut, eklenmedi.
# Tournament ID 390 zaten mevcut, eklenmedi.
# Tournament ID 131 zaten mevcut, eklenmedi.
# Tournament ID 98 zaten mevcut, eklenmedi.
# Tournament ID 45 zaten mevcut, eklenmedi.
# Tournament ID 266 zaten mevcut, eklenmedi.
# Tournament ID 11653 zaten mevcut, eklenmedi.
# Tournament ID 11536 zaten mevcut, eklenmedi.
# Tournament ID 172 zaten mevcut, eklenmedi.
# Tournament ID 202 zaten mevcut, eklenmedi.
# Tournament ID 39 zaten mevcut, eklenmedi.
# Tournament ID 11541 zaten mevcut, eklenmedi.
# Tournament ID 240 zaten mevcut, eklenmedi.
# Tournament ID 1900 zaten mevcut, eklenmedi.
# Tournament ID 20 zaten mevcut, eklenmedi.
# Tournament ID 955 zaten mevcut, eklenmedi.
# Tournament ID 152 zaten mevcut, eklenmedi.
# Tournament ID 40 zaten mevcut, eklenmedi.
# Tournament ID 215 zaten mevcut, eklenmedi.
# Tournament ID 13362 zaten mevcut, eklenmedi.
# Tournament ID 203 zaten mevcut, eklenmedi.
# Tournament ID 1690 zaten mevcut, eklenmedi.
# Tournament ID 1032 zaten mevcut, eklenmedi.
# Tournament ID 1044 zaten mevcut, eklenmedi.
# Tournament ID 9 zaten mevcut, eklenmedi.
# Tournament ID 1139 zaten mevcut, eklenmedi.
# Tournament ID 10640 zaten mevcut, eklenmedi.
# Tournament ID 232 zaten mevcut, eklenmedi.
# Tournament ID 1127 zaten mevcut, eklenmedi.
# Tournament ID 187 zaten mevcut, eklenmedi.
# Tournament ID 211 zaten mevcut, eklenmedi.
# Tournament ID 703 zaten mevcut, eklenmedi.
# Tournament ID 463 zaten mevcut, eklenmedi.
# Tournament ID 709 zaten mevcut, eklenmedi.
# Tournament ID 846 zaten mevcut, eklenmedi.
# Tournament ID 169 zaten mevcut, eklenmedi.
# Tournament ID 16736 zaten mevcut, eklenmedi.
# Tournament ID 222 zaten mevcut, eklenmedi.
# Tournament ID 373 zaten mevcut, eklenmedi.
# Tournament ID 247 zaten mevcut, eklenmedi.
# Tournament ID 1240 zaten mevcut, eklenmedi.
# Tournament ID 11535 zaten mevcut, eklenmedi.
# Tournament ID 171 zaten mevcut, eklenmedi.
# Tournament ID 205 zaten mevcut, eklenmedi.
# Tournament ID 47 zaten mevcut, eklenmedi.
# Tournament ID 65 zaten mevcut, eklenmedi.
# Tournament ID 14688 zaten mevcut, eklenmedi.
# Tournament ID 704 zaten mevcut, eklenmedi.
# Tournament ID 491 zaten mevcut, eklenmedi.
# Tournament ID 42 zaten mevcut, eklenmedi.
# Tournament ID 1083 zaten mevcut, eklenmedi.
# Tournament ID 1079 zaten mevcut, eklenmedi.
# Tournament ID 1191 zaten mevcut, eklenmedi.
# Tournament ID 186 zaten mevcut, eklenmedi.
# Tournament ID 11619 zaten mevcut, eklenmedi.
# Tournament ID 188 zaten mevcut, eklenmedi.
# Tournament ID 1015 zaten mevcut, eklenmedi.
# Tournament ID 915 zaten mevcut, eklenmedi.
# Tournament ID 11445 zaten mevcut, eklenmedi.
# Tournament ID 11447 zaten mevcut, eklenmedi.
# Tournament ID 11446 zaten mevcut, eklenmedi.
# Tournament ID 2292 zaten mevcut, eklenmedi.
# Tournament ID 682 zaten mevcut, eklenmedi.
# Tournament ID 197 zaten mevcut, eklenmedi.
# Tournament ID 198 zaten mevcut, eklenmedi.
# Tournament ID 1000 zaten mevcut, eklenmedi.
# Tournament ID 629 zaten mevcut, eklenmedi.
# Tournament ID 11611 zaten mevcut, eklenmedi.
# Tournament ID 685 zaten mevcut, eklenmedi.
# Tournament ID 937 zaten mevcut, eklenmedi.
# Tournament ID 199 zaten mevcut, eklenmedi.
# Tournament ID 22 zaten mevcut, eklenmedi.
# Tournament ID 201 zaten mevcut, eklenmedi.
# Tournament ID 229 zaten mevcut, eklenmedi.
# Tournament ID 562 zaten mevcut, eklenmedi.
# Tournament ID 204 zaten mevcut, eklenmedi.
# Tournament ID 212 zaten mevcut, eklenmedi.
# Tournament ID 46 zaten mevcut, eklenmedi.
# Tournament ID 67 zaten mevcut, eklenmedi.
# Tournament ID 68 zaten mevcut, eklenmedi.
# Tournament ID 214 zaten mevcut, eklenmedi.
# Tournament ID 984 zaten mevcut, eklenmedi.
# Tournament ID 218 zaten mevcut, eklenmedi.
# Tournament ID 278 zaten mevcut, eklenmedi.
# Tournament ID 367 zaten mevcut, eklenmedi.
# Tournament ID 827 zaten mevcut, eklenmedi.
# Tournament ID 7 zaten mevcut, eklenmedi.
# Tournament ID 384 zaten mevcut, eklenmedi.
# Tournament ID 242 zaten mevcut, eklenmedi.
# Tournament ID 24 zaten mevcut, eklenmedi.
# Tournament ID 25 zaten mevcut, eklenmedi.
# Tournament ID 196 zaten mevcut, eklenmedi.
# Tournament ID 406 zaten mevcut, eklenmedi.
# Tournament ID 358 zaten mevcut, eklenmedi.
# Tournament ID 841 zaten mevcut, eklenmedi.
# Tournament ID 668 zaten mevcut, eklenmedi.
# Tournament ID 166 zaten mevcut, eklenmedi.
# Tournament ID 1238 zaten mevcut, eklenmedi.
# Tournament ID 173 zaten mevcut, eklenmedi.
# Tournament ID 178 zaten mevcut, eklenmedi.
# Tournament ID 55 zaten mevcut, eklenmedi.
# Tournament ID 1085 zaten mevcut, eklenmedi.
# Tournament ID 200 zaten mevcut, eklenmedi.
# Tournament ID 331 zaten mevcut, eklenmedi.
# Season ID 61627 zaten mevcut, eklenmedi.
# Season ID 61643 zaten mevcut, eklenmedi.
# Season ID 63515 zaten mevcut, eklenmedi.
# Season ID 63516 zaten mevcut, eklenmedi.
# Season ID 61736 zaten mevcut, eklenmedi.
# Season ID 61666 zaten mevcut, eklenmedi.
# Season ID 58766 zaten mevcut, eklenmedi.
# Season ID 63814 zaten mevcut, eklenmedi.
# Season ID 61459 zaten mevcut, eklenmedi.
# Season ID 64052 zaten mevcut, eklenmedi.
# Season ID 66456 zaten mevcut, eklenmedi.
# Season ID 57478 zaten mevcut, eklenmedi.
# Season ID 61419 zaten mevcut, eklenmedi.
# Season ID 61243 zaten mevcut, eklenmedi.
# Season ID 61448 zaten mevcut, eklenmedi.
# Season ID 61961 zaten mevcut, eklenmedi.
# Season ID 62048 zaten mevcut, eklenmedi.
# Season ID 63812 zaten mevcut, eklenmedi.
# Season ID 61737 zaten mevcut, eklenmedi.
# Season ID 59015 zaten mevcut, eklenmedi.
# Season ID 61667 zaten mevcut, eklenmedi.
# Season ID 64425 zaten mevcut, eklenmedi.
# Season ID 62629 zaten mevcut, eklenmedi.
# Season ID 61932 zaten mevcut, eklenmedi.
# Season ID 57883 zaten mevcut, eklenmedi.
# Season ID 63819 zaten mevcut, eklenmedi.
# Season ID 61716 zaten mevcut, eklenmedi.
# Season ID 61236 zaten mevcut, eklenmedi.
# Season ID 61326 zaten mevcut, eklenmedi.
# Season ID 63769 zaten mevcut, eklenmedi.
# Season ID 58043 zaten mevcut, eklenmedi.
# Season ID 65961 zaten mevcut, eklenmedi.
# Season ID 57322 zaten mevcut, eklenmedi.
# Season ID 63998 zaten mevcut, eklenmedi.
# Season ID 62837 zaten mevcut, eklenmedi.
# Season ID 57284 zaten mevcut, eklenmedi.
# Season ID 61658 zaten mevcut, eklenmedi.
# Season ID 57318 zaten mevcut, eklenmedi.
# Season ID 61712 zaten mevcut, eklenmedi.
# Season ID 58145 zaten mevcut, eklenmedi.
# Season ID 63500 zaten mevcut, eklenmedi.
# Season ID 64370 zaten mevcut, eklenmedi.
# Season ID 61412 zaten mevcut, eklenmedi.
# Season ID 64322 zaten mevcut, eklenmedi.
# Season ID 63768 zaten mevcut, eklenmedi.
# Season ID 64294 zaten mevcut, eklenmedi.
# Season ID 65687 zaten mevcut, eklenmedi.
# Season ID 61714 zaten mevcut, eklenmedi.
# Season ID 61728 zaten mevcut, eklenmedi.
# Season ID 57782 zaten mevcut, eklenmedi.
# Season ID 62485 zaten mevcut, eklenmedi.
# Season ID 64075 zaten mevcut, eklenmedi.
# Season ID 65070 zaten mevcut, eklenmedi.
# Season ID 58774 zaten mevcut, eklenmedi.
# Season ID 58156 zaten mevcut, eklenmedi.
# Season ID 63463 zaten mevcut, eklenmedi.
# Season ID 58134 zaten mevcut, eklenmedi.
# Season ID 61477 zaten mevcut, eklenmedi.
# Season ID 58194 zaten mevcut, eklenmedi.
# Season ID 61711 zaten mevcut, eklenmedi.
# Season ID 63498 zaten mevcut, eklenmedi.
# Season ID 61725 zaten mevcut, eklenmedi.
# Season ID 61669 zaten mevcut, eklenmedi.
# Season ID 61929 zaten mevcut, eklenmedi.
# Season ID 67785 zaten mevcut, eklenmedi.
# Season ID 57889 zaten mevcut, eklenmedi.
# Season ID 63786 zaten mevcut, eklenmedi.
# Season ID 63874 zaten mevcut, eklenmedi.
# Season ID 63556 zaten mevcut, eklenmedi.
# Season ID 63815 zaten mevcut, eklenmedi.
# Season ID 64783 zaten mevcut, eklenmedi.
# Season ID 66662 zaten mevcut, eklenmedi.
# Season ID 61855 zaten mevcut, eklenmedi.
# Season ID 57370 zaten mevcut, eklenmedi.
# Season ID 65049 zaten mevcut, eklenmedi.
# Season ID 65237 zaten mevcut, eklenmedi.
# Season ID 63975 zaten mevcut, eklenmedi.
# Season ID 63976 zaten mevcut, eklenmedi.
# Season ID 63973 zaten mevcut, eklenmedi.
# Season ID 64432 zaten mevcut, eklenmedi.
# Season ID 58620 zaten mevcut, eklenmedi.
# Season ID 58563 zaten mevcut, eklenmedi.
# Season ID 58463 zaten mevcut, eklenmedi.
# Season ID 59816 zaten mevcut, eklenmedi.
# Season ID 65067 zaten mevcut, eklenmedi.
# Season ID 63978 zaten mevcut, eklenmedi.
# Season ID 63546 zaten mevcut, eklenmedi.
# Season ID 65433 zaten mevcut, eklenmedi.
# Season ID 64685 zaten mevcut, eklenmedi.
# Season ID 57356 zaten mevcut, eklenmedi.
# Season ID 57359 zaten mevcut, eklenmedi.
# Season ID 61452 zaten mevcut, eklenmedi.
# Season ID 64111 zaten mevcut, eklenmedi.
# Season ID 63400 zaten mevcut, eklenmedi.
# Season ID 62660 zaten mevcut, eklenmedi.
# Season ID 57444 zaten mevcut, eklenmedi.
# Season ID 57893 zaten mevcut, eklenmedi.
# Season ID 57892 zaten mevcut, eklenmedi.
# Season ID 57379 zaten mevcut, eklenmedi.
# Season ID 65503 zaten mevcut, eklenmedi.
# Season ID 62656 zaten mevcut, eklenmedi.
# Season ID 58264 zaten mevcut, eklenmedi.
# Season ID 61686 zaten mevcut, eklenmedi.
# Season ID 61934 zaten mevcut, eklenmedi.
# Season ID 61644 zaten mevcut, eklenmedi.
# Season ID 57296 zaten mevcut, eklenmedi.
# Season ID 57317 zaten mevcut, eklenmedi.
# Season ID 61959 zaten mevcut, eklenmedi.
# Season ID 61960 zaten mevcut, eklenmedi.
# Season ID 57353 zaten mevcut, eklenmedi.
# Season ID 57741 zaten mevcut, eklenmedi.
# Season ID 65113 zaten mevcut, eklenmedi.
# Season ID 64102 zaten mevcut, eklenmedi.
# Season ID 62486 zaten mevcut, eklenmedi.
# Season ID 61661 zaten mevcut, eklenmedi.
# Season ID 57388 zaten mevcut, eklenmedi.
# Season ID 63807 zaten mevcut, eklenmedi.
# Season ID 57905 zaten mevcut, eklenmedi.
# Season ID 58125 zaten mevcut, eklenmedi.
# Season ID 61829 zaten mevcut, eklenmedi.
# Season ID 62405 zaten mevcut, eklenmedi.
# Season ID 63699 zaten mevcut, eklenmedi.
# Team ID 3 zaten mevcut, eklenmedi.
# Team ID 44 zaten mevcut, eklenmedi.
# Team ID 14 zaten mevcut, eklenmedi.
# Team ID 2826 zaten mevcut, eklenmedi.
# Team ID 2836 zaten mevcut, eklenmedi.
# Team ID 2819 zaten mevcut, eklenmedi.
# Team ID 2817 zaten mevcut, eklenmedi.
# Team ID 2828 zaten mevcut, eklenmedi.
# Team ID 2689 zaten mevcut, eklenmedi.
# Team ID 2688 zaten mevcut, eklenmedi.
# Team ID 2719 zaten mevcut, eklenmedi.
# Team ID 2702 zaten mevcut, eklenmedi.
# Team ID 2701 zaten mevcut, eklenmedi.
# Team ID 2573 zaten mevcut, eklenmedi.
# Team ID 2524 zaten mevcut, eklenmedi.
# Team ID 1662 zaten mevcut, eklenmedi.
# Team ID 1646 zaten mevcut, eklenmedi.
# Team ID 1647 zaten mevcut, eklenmedi.
# Team ID 1681 zaten mevcut, eklenmedi.
# Team ID 1642 zaten mevcut, eklenmedi.
# Team ID 2951 zaten mevcut, eklenmedi.
# Team ID 2977 zaten mevcut, eklenmedi.
# Team ID 2971 zaten mevcut, eklenmedi.
# Team ID 1980 zaten mevcut, eklenmedi.
# Team ID 3050 zaten mevcut, eklenmedi.
# Team ID 6362 zaten mevcut, eklenmedi.
# Team ID 3053 zaten mevcut, eklenmedi.
# Team ID 202390 zaten mevcut, eklenmedi.
# Team ID 2918 zaten mevcut, eklenmedi.
# Team ID 2901 zaten mevcut, eklenmedi.
# Team ID 5044 zaten mevcut, eklenmedi.
# Team ID 3245 zaten mevcut, eklenmedi.
# Team ID 3241 zaten mevcut, eklenmedi.
# Team ID 3252 zaten mevcut, eklenmedi.
# Team ID 3250 zaten mevcut, eklenmedi.
# Team ID 174568 zaten mevcut, eklenmedi.
# Team ID 90120 zaten mevcut, eklenmedi.
# Team ID 90122 zaten mevcut, eklenmedi.
# Team ID 120874 zaten mevcut, eklenmedi.
# Team ID 90138 zaten mevcut, eklenmedi.
# Team ID 42729 zaten mevcut, eklenmedi.
# Team ID 3216 zaten mevcut, eklenmedi.
# Team ID 3206 zaten mevcut, eklenmedi.
# Team ID 3217 zaten mevcut, eklenmedi.
# Team ID 6074 zaten mevcut, eklenmedi.
# Team ID 3201 zaten mevcut, eklenmedi.
# Team ID 1933 zaten mevcut, eklenmedi.
# Team ID 2042 zaten mevcut, eklenmedi.
# Team ID 231380 zaten mevcut, eklenmedi.
# Team ID 7771 zaten mevcut, eklenmedi.
# Team ID 25736 zaten mevcut, eklenmedi.
# Team ID 96 zaten mevcut, eklenmedi.
# Team ID 4488 zaten mevcut, eklenmedi.
# Team ID 2843 zaten mevcut, eklenmedi.
# Team ID 2846 zaten mevcut, eklenmedi.
# Team ID 2815 zaten mevcut, eklenmedi.
# Team ID 2848 zaten mevcut, eklenmedi.
# Team ID 2745 zaten mevcut, eklenmedi.
# Team ID 5324 zaten mevcut, eklenmedi.
# Team ID 24516 zaten mevcut, eklenmedi.
# Team ID 2742 zaten mevcut, eklenmedi.
# Team ID 1652 zaten mevcut, eklenmedi.
# Team ID 39634 zaten mevcut, eklenmedi.
# Team ID 1969 zaten mevcut, eklenmedi.
# Team ID 1959 zaten mevcut, eklenmedi.
# Team ID 21845 zaten mevcut, eklenmedi.
# Team ID 2974 zaten mevcut, eklenmedi.
# Team ID 46160 zaten mevcut, eklenmedi.
# Team ID 46168 zaten mevcut, eklenmedi.
# Team ID 2970 zaten mevcut, eklenmedi.
# Team ID 6414 zaten mevcut, eklenmedi.
# Team ID 388264 zaten mevcut, eklenmedi.
# Team ID 3080 zaten mevcut, eklenmedi.
# Team ID 262480 zaten mevcut, eklenmedi.
# Team ID 43254 zaten mevcut, eklenmedi.
# Team ID 5405 zaten mevcut, eklenmedi.
# Team ID 2055 zaten mevcut, eklenmedi.
# Team ID 86406 zaten mevcut, eklenmedi.
# Team ID 5333 zaten mevcut, eklenmedi.
# Team ID 39525 zaten mevcut, eklenmedi.
# Team ID 3157 zaten mevcut, eklenmedi.
# Team ID 3162 zaten mevcut, eklenmedi.
# Team ID 3165 zaten mevcut, eklenmedi.
# Team ID 89506 zaten mevcut, eklenmedi.
# Team ID 33596 zaten mevcut, eklenmedi.
# Team ID 48242 zaten mevcut, eklenmedi.
# Team ID 6102 zaten mevcut, eklenmedi.
# Team ID 6103 zaten mevcut, eklenmedi.
# Team ID 6106 zaten mevcut, eklenmedi.
# Team ID 6975 zaten mevcut, eklenmedi.
# Team ID 6114 zaten mevcut, eklenmedi.
# Team ID 89370 zaten mevcut, eklenmedi.
# Team ID 6117 zaten mevcut, eklenmedi.
# Team ID 6118 zaten mevcut, eklenmedi.
# Team ID 61504 zaten mevcut, eklenmedi.
# Team ID 48244 zaten mevcut, eklenmedi.
# Team ID 6105 zaten mevcut, eklenmedi.
# Team ID 4871 zaten mevcut, eklenmedi.
# Team ID 23951 zaten mevcut, eklenmedi.
# Team ID 2205 zaten mevcut, eklenmedi.
# Team ID 3110 zaten mevcut, eklenmedi.
# Team ID 35268 zaten mevcut, eklenmedi.
# Team ID 7295 zaten mevcut, eklenmedi.
# Team ID 1290 zaten mevcut, eklenmedi.
# Team ID 1756 zaten mevcut, eklenmedi.
# Team ID 1292 zaten mevcut, eklenmedi.
# Team ID 1295 zaten mevcut, eklenmedi.
# Team ID 1291 zaten mevcut, eklenmedi.
# Team ID 36439 zaten mevcut, eklenmedi.
# Team ID 5996 zaten mevcut, eklenmedi.
# Team ID 5992 zaten mevcut, eklenmedi.
# Team ID 5998 zaten mevcut, eklenmedi.
# Team ID 5249 zaten mevcut, eklenmedi.
# Team ID 213638 zaten mevcut, eklenmedi.
# Team ID 5250 zaten mevcut, eklenmedi.
# Team ID 118660 zaten mevcut, eklenmedi.
# Team ID 267915 zaten mevcut, eklenmedi.
# Team ID 1161 zaten mevcut, eklenmedi.
# Team ID 666 zaten mevcut, eklenmedi.
# Team ID 786 zaten mevcut, eklenmedi.
# Team ID 957 zaten mevcut, eklenmedi.
# Team ID 1164 zaten mevcut, eklenmedi.
# Team ID 687 zaten mevcut, eklenmedi.
# Team ID 56023 zaten mevcut, eklenmedi.
# Team ID 336456 zaten mevcut, eklenmedi.
# Team ID 34318 zaten mevcut, eklenmedi.
# Team ID 116223 zaten mevcut, eklenmedi.
# Team ID 3292 zaten mevcut, eklenmedi.
# Team ID 44319 zaten mevcut, eklenmedi.
# Team ID 295403 zaten mevcut, eklenmedi.
# Team ID 1891 zaten mevcut, eklenmedi.
# Team ID 1786 zaten mevcut, eklenmedi.
# Team ID 1758 zaten mevcut, eklenmedi.
# Team ID 1769 zaten mevcut, eklenmedi.
# Team ID 1761 zaten mevcut, eklenmedi.
# Team ID 2501 zaten mevcut, eklenmedi.
# Team ID 2446 zaten mevcut, eklenmedi.
# Team ID 2460 zaten mevcut, eklenmedi.
# Team ID 405294 zaten mevcut, eklenmedi.
# Team ID 24118 zaten mevcut, eklenmedi.
# Team ID 2333 zaten mevcut, eklenmedi.
# Team ID 34718 zaten mevcut, eklenmedi.
# Team ID 151012 zaten mevcut, eklenmedi.
# Team ID 408169 zaten mevcut, eklenmedi.
# Team ID 255498 zaten mevcut, eklenmedi.
# Team ID 254730 zaten mevcut, eklenmedi.
# Team ID 66774 zaten mevcut, eklenmedi.
# Team ID 299289 zaten mevcut, eklenmedi.
# Team ID 297802 zaten mevcut, eklenmedi.
# Team ID 66768 zaten mevcut, eklenmedi.
# Team ID 35076 zaten mevcut, eklenmedi.
# Team ID 371484 zaten mevcut, eklenmedi.
# Team ID 264964 zaten mevcut, eklenmedi.
# Team ID 301414 zaten mevcut, eklenmedi.
# Team ID 269819 zaten mevcut, eklenmedi.
# Team ID 5551 zaten mevcut, eklenmedi.
# Team ID 5550 zaten mevcut, eklenmedi.
# Team ID 36623 zaten mevcut, eklenmedi.
# Team ID 38322 zaten mevcut, eklenmedi.
# Team ID 253896 zaten mevcut, eklenmedi.
# Team ID 1922 zaten mevcut, eklenmedi.
# Team ID 1925 zaten mevcut, eklenmedi.
# Team ID 189813 zaten mevcut, eklenmedi.
# Team ID 2402 zaten mevcut, eklenmedi.
# Team ID 222120 zaten mevcut, eklenmedi.
# Team ID 213361 zaten mevcut, eklenmedi.
# Team ID 5292 zaten mevcut, eklenmedi.
# Team ID 213042 zaten mevcut, eklenmedi.
# Team ID 34976 zaten mevcut, eklenmedi.
# Team ID 43741 zaten mevcut, eklenmedi.
# Team ID 112499 zaten mevcut, eklenmedi.
# Team ID 93513 zaten mevcut, eklenmedi.
# Team ID 36834 zaten mevcut, eklenmedi.
# Team ID 107201 zaten mevcut, eklenmedi.
# Team ID 48912 zaten mevcut, eklenmedi.
# Team ID 41537 zaten mevcut, eklenmedi.
# Team ID 34218 zaten mevcut, eklenmedi.
# Team ID 3371 zaten mevcut, eklenmedi.
# Team ID 37082 zaten mevcut, eklenmedi.
# Team ID 39733 zaten mevcut, eklenmedi.
# Team ID 61532 zaten mevcut, eklenmedi.
# Team ID 40660 zaten mevcut, eklenmedi.
# Team ID 173406 zaten mevcut, eklenmedi.
# Team ID 44497 zaten mevcut, eklenmedi.
# Team ID 45474 zaten mevcut, eklenmedi.
# Team ID 45475 zaten mevcut, eklenmedi.
# Team ID 117220 zaten mevcut, eklenmedi.
# Team ID 7304 zaten mevcut, eklenmedi.
# Team ID 3349 zaten mevcut, eklenmedi.
# Team ID 3359 zaten mevcut, eklenmedi.
# Team ID 47701 zaten mevcut, eklenmedi.
# Team ID 47700 zaten mevcut, eklenmedi.
# Team ID 33820 zaten mevcut, eklenmedi.
# Team ID 6149 zaten mevcut, eklenmedi.
# Team ID 5235 zaten mevcut, eklenmedi.
# Team ID 5178 zaten mevcut, eklenmedi.
# Team ID 1957 zaten mevcut, eklenmedi.
# Team ID 3280 zaten mevcut, eklenmedi.
# Team ID 201203 zaten mevcut, eklenmedi.
# Team ID 252080 zaten mevcut, eklenmedi.
# Team ID 33595 zaten mevcut, eklenmedi.
# Team ID 243490 zaten mevcut, eklenmedi.
# Team ID 39219 zaten mevcut, eklenmedi.
# Team ID 3150 zaten mevcut, eklenmedi.
# Team ID 7048 zaten mevcut, eklenmedi.
# Team ID 6574 zaten mevcut, eklenmedi.
# Team ID 7047 zaten mevcut, eklenmedi.
# Team ID 275943 zaten mevcut, eklenmedi.
# Team ID 3396 zaten mevcut, eklenmedi.
# Team ID 3404 zaten mevcut, eklenmedi.
# Team ID 3402 zaten mevcut, eklenmedi.
# Team ID 3399 zaten mevcut, eklenmedi.
# Team ID 76775 zaten mevcut, eklenmedi.
# Team ID 1297 zaten mevcut, eklenmedi.
# Team ID 1403 zaten mevcut, eklenmedi.
# Team ID 175002 zaten mevcut, eklenmedi.
# Team ID 6910 zaten mevcut, eklenmedi.
# Team ID 116312 zaten mevcut, eklenmedi.
# Team ID 33819 zaten mevcut, eklenmedi.
# Team ID 2540 zaten mevcut, eklenmedi.
# Team ID 2555 zaten mevcut, eklenmedi.
# Team ID 323848 zaten mevcut, eklenmedi.
# Team ID 5800 zaten mevcut, eklenmedi.
# Team ID 43901 zaten mevcut, eklenmedi.
# Team ID 7864 zaten mevcut, eklenmedi.
# Team ID 2571 zaten mevcut, eklenmedi.
# Team ID 41755 zaten mevcut, eklenmedi.
# Team ID 42611 zaten mevcut, eklenmedi.
# Team ID 396192 zaten mevcut, eklenmedi.
# Team ID 213969 zaten mevcut, eklenmedi.
# Team ID 274973 zaten mevcut, eklenmedi.
# Team ID 81951 zaten mevcut, eklenmedi.
# Team ID 404788 zaten mevcut, eklenmedi.
# Team ID 458766 zaten mevcut, eklenmedi.
# Team ID 81751 zaten mevcut, eklenmedi.
# Team ID 25228 zaten mevcut, eklenmedi.
# Team ID 5761 zaten mevcut, eklenmedi.
# Team ID 3244 zaten mevcut, eklenmedi.
# Team ID 894568 zaten mevcut, eklenmedi.
# Team ID 203021 zaten mevcut, eklenmedi.
# Team ID 298481 zaten mevcut, eklenmedi.
# Team ID 375950 zaten mevcut, eklenmedi.
# Team ID 1896 zaten mevcut, eklenmedi.
# Team ID 7121 zaten mevcut, eklenmedi.
# Team ID 86576 zaten mevcut, eklenmedi.
# Team ID 270969 zaten mevcut, eklenmedi.
# Team ID 258972 zaten mevcut, eklenmedi.
# Team ID 2741 zaten mevcut, eklenmedi.
# Team ID 2782 zaten mevcut, eklenmedi.
# Team ID 2753 zaten mevcut, eklenmedi.
# Team ID 43685 zaten mevcut, eklenmedi.
# Team ID 530559 zaten mevcut, eklenmedi.
# Team ID 43680 zaten mevcut, eklenmedi.
# Team ID 228753 zaten mevcut, eklenmedi.
# Team ID 2803 zaten mevcut, eklenmedi.
# Team ID 294884 zaten mevcut, eklenmedi.
# Team ID 43686 zaten mevcut, eklenmedi.
# Team ID 2720 zaten mevcut, eklenmedi.
# Team ID 2718 zaten mevcut, eklenmedi.
# Team ID 205714 zaten mevcut, eklenmedi.
# Team ID 53857 zaten mevcut, eklenmedi.
# Team ID 826810 zaten mevcut, eklenmedi.
# Team ID 826817 zaten mevcut, eklenmedi.
# Team ID 36142 zaten mevcut, eklenmedi.
# Team ID 68718 zaten mevcut, eklenmedi.
# Team ID 5346 zaten mevcut, eklenmedi.
# Team ID 312564 zaten mevcut, eklenmedi.
# Team ID 192536 zaten mevcut, eklenmedi.
# Team ID 3330 zaten mevcut, eklenmedi.
# Team ID 5206 zaten mevcut, eklenmedi.
# Team ID 53755 zaten mevcut, eklenmedi.
# Team ID 38305 zaten mevcut, eklenmedi.
# Team ID 7704 zaten mevcut, eklenmedi.
# Team ID 354925 zaten mevcut, eklenmedi.
# Team ID 1943 zaten mevcut, eklenmedi.
# Team ID 5265 zaten mevcut, eklenmedi.
# Team ID 55037 zaten mevcut, eklenmedi.
# Team ID 226868 zaten mevcut, eklenmedi.
# Team ID 390513 zaten mevcut, eklenmedi.
# Team ID 259121 zaten mevcut, eklenmedi.
# Team ID 6079 zaten mevcut, eklenmedi.
# Team ID 5212 zaten mevcut, eklenmedi.
# Team ID 43576 zaten mevcut, eklenmedi.
# Team ID 677 zaten mevcut, eklenmedi.
# Team ID 663 zaten mevcut, eklenmedi.
# Team ID 672 zaten mevcut, eklenmedi.
# Team ID 903 zaten mevcut, eklenmedi.
# Team ID 662 zaten mevcut, eklenmedi.
# Team ID 929 zaten mevcut, eklenmedi.
# Team ID 1165 zaten mevcut, eklenmedi.
# Team ID 682 zaten mevcut, eklenmedi.
# Team ID 62202 zaten mevcut, eklenmedi.
# Team ID 5064 zaten mevcut, eklenmedi.
# Team ID 3123 zaten mevcut, eklenmedi.
# Team ID 37207 zaten mevcut, eklenmedi.
# Team ID 312033 zaten mevcut, eklenmedi.
# Team ID 2330 zaten mevcut, eklenmedi.
# Team ID 75207 zaten mevcut, eklenmedi.
# Team ID 245709 zaten mevcut, eklenmedi.
# Team ID 261800 zaten mevcut, eklenmedi.
# Team ID 2418 zaten mevcut, eklenmedi.
# Team ID 1781 zaten mevcut, eklenmedi.
# Team ID 1890 zaten mevcut, eklenmedi.
# Team ID 379203 zaten mevcut, eklenmedi.
# Team ID 22238 zaten mevcut, eklenmedi.
# Team ID 1849 zaten mevcut, eklenmedi.
# Team ID 1812 zaten mevcut, eklenmedi.
# Team ID 1829 zaten mevcut, eklenmedi.
# Team ID 61572 zaten mevcut, eklenmedi.
# Team ID 7391 zaten mevcut, eklenmedi.
# Team ID 1886 zaten mevcut, eklenmedi.
# Team ID 1878 zaten mevcut, eklenmedi.
# Team ID 59616 zaten mevcut, eklenmedi.
# Team ID 59622 zaten mevcut, eklenmedi.
# Team ID 59630 zaten mevcut, eklenmedi.
# Team ID 35188 zaten mevcut, eklenmedi.
# Team ID 148874 zaten mevcut, eklenmedi.
# Team ID 3310 zaten mevcut, eklenmedi.
# Team ID 5987 zaten mevcut, eklenmedi.
# Team ID 229644 zaten mevcut, eklenmedi.
# Team ID 25009 zaten mevcut, eklenmedi.
# Team ID 22011 zaten mevcut, eklenmedi.
# Team ID 6881 zaten mevcut, eklenmedi.
# Team ID 3240 zaten mevcut, eklenmedi.
# Team ID 6880 zaten mevcut, eklenmedi.
# Team ID 3229 zaten mevcut, eklenmedi.
# Team ID 281397 zaten mevcut, eklenmedi.
# Team ID 44558 zaten mevcut, eklenmedi.
# Team ID 38013 zaten mevcut, eklenmedi.
# Team ID 36913 zaten mevcut, eklenmedi.
# Team ID 134184 zaten mevcut, eklenmedi.
# Team ID 1653 zaten mevcut, eklenmedi.
# Team ID 2692 zaten mevcut, eklenmedi.
# Team ID 42 zaten mevcut, eklenmedi.
# Team ID 40 zaten mevcut, eklenmedi.
# Team ID 24264 zaten mevcut, eklenmedi.
# Team ID 2687 zaten mevcut, eklenmedi.
# Team ID 1644 zaten mevcut, eklenmedi.
# Team ID 2829 zaten mevcut, eklenmedi.
# Team ID 2051 zaten mevcut, eklenmedi.
# Team ID 1977 zaten mevcut, eklenmedi.
# Team ID 1961 zaten mevcut, eklenmedi.
# Team ID 301517 zaten mevcut, eklenmedi.
# Team ID 120854 zaten mevcut, eklenmedi.
# Team ID 854567 zaten mevcut, eklenmedi.
# Team ID 296233 zaten mevcut, eklenmedi.
# Team ID 78135 zaten mevcut, eklenmedi.
# Team ID 72070 zaten mevcut, eklenmedi.
# Team ID 297859 zaten mevcut, eklenmedi.
# Team ID 206357 zaten mevcut, eklenmedi.
# Team ID 78113 zaten mevcut, eklenmedi.
# Team ID 328789 zaten mevcut, eklenmedi.
# Team ID 392254 zaten mevcut, eklenmedi.
# Team ID 114685 zaten mevcut, eklenmedi.
# Team ID 107707 zaten mevcut, eklenmedi.
# Team ID 390244 zaten mevcut, eklenmedi.
# Team ID 264769 zaten mevcut, eklenmedi.
# Team ID 1948 zaten mevcut, eklenmedi.
# Team ID 1938 zaten mevcut, eklenmedi.
# Team ID 1931 zaten mevcut, eklenmedi.
# Team ID 1946 zaten mevcut, eklenmedi.
# Team ID 22006 zaten mevcut, eklenmedi.
# Team ID 61 zaten mevcut, eklenmedi.
# Team ID 34 zaten mevcut, eklenmedi.
# Team ID 95 zaten mevcut, eklenmedi.
# Team ID 21 zaten mevcut, eklenmedi.
# Team ID 12 zaten mevcut, eklenmedi.
# Team ID 29 zaten mevcut, eklenmedi.
# Team ID 1 zaten mevcut, eklenmedi.
# Team ID 2851 zaten mevcut, eklenmedi.
# Team ID 5067 zaten mevcut, eklenmedi.
# Team ID 1685 zaten mevcut, eklenmedi.
# Team ID 22032 zaten mevcut, eklenmedi.
# Team ID 1968 zaten mevcut, eklenmedi.
# Team ID 135514 zaten mevcut, eklenmedi.
# Team ID 2021 zaten mevcut, eklenmedi.
# Team ID 2973 zaten mevcut, eklenmedi.
# Team ID 2965 zaten mevcut, eklenmedi.
# Team ID 2968 zaten mevcut, eklenmedi.
# Team ID 53067 zaten mevcut, eklenmedi.
# Team ID 5204 zaten mevcut, eklenmedi.
# Team ID 23 zaten mevcut, eklenmedi.
# Team ID 9 zaten mevcut, eklenmedi.
# Team ID 76 zaten mevcut, eklenmedi.
# Team ID 134 zaten mevcut, eklenmedi.
# Team ID 4875 zaten mevcut, eklenmedi.
# Team ID 86 zaten mevcut, eklenmedi.
# Team ID 83 zaten mevcut, eklenmedi.
# Team ID 54 zaten mevcut, eklenmedi.
# Team ID 133 zaten mevcut, eklenmedi.
# Team ID 10 zaten mevcut, eklenmedi.
# Team ID 49 zaten mevcut, eklenmedi.
# Team ID 64 zaten mevcut, eklenmedi.
# Team ID 23957 zaten mevcut, eklenmedi.
# Team ID 97 zaten mevcut, eklenmedi.
# Team ID 69 zaten mevcut, eklenmedi.
# Team ID 68 zaten mevcut, eklenmedi.
# Team ID 84 zaten mevcut, eklenmedi.
# Team ID 23959 zaten mevcut, eklenmedi.
# Team ID 20 zaten mevcut, eklenmedi.
# Team ID 159 zaten mevcut, eklenmedi.
# Team ID 4 zaten mevcut, eklenmedi.
# Team ID 37998 zaten mevcut, eklenmedi.
# Team ID 51 zaten mevcut, eklenmedi.
# Team ID 26 zaten mevcut, eklenmedi.
# Team ID 174592 zaten mevcut, eklenmedi.
# Team ID 5128 zaten mevcut, eklenmedi.
# Team ID 3138 zaten mevcut, eklenmedi.
# Team ID 3145 zaten mevcut, eklenmedi.
# Team ID 282538 zaten mevcut, eklenmedi.
# Team ID 252254 zaten mevcut, eklenmedi.
# Team ID 2308 zaten mevcut, eklenmedi.
# Team ID 2311 zaten mevcut, eklenmedi.
# Team ID 7668 zaten mevcut, eklenmedi.
# Team ID 42201 zaten mevcut, eklenmedi.
# Team ID 186100 zaten mevcut, eklenmedi.
# Team ID 7653 zaten mevcut, eklenmedi.
# Team ID 3373 zaten mevcut, eklenmedi.
# Team ID 34312 zaten mevcut, eklenmedi.
# Team ID 34316 zaten mevcut, eklenmedi.
# Team ID 34060 zaten mevcut, eklenmedi.
# Team ID 189871 zaten mevcut, eklenmedi.
# Team ID 3135 zaten mevcut, eklenmedi.
# Team ID 39946 zaten mevcut, eklenmedi.
# Team ID 3323 zaten mevcut, eklenmedi.
# Team ID 386185 zaten mevcut, eklenmedi.
# Team ID 396625 zaten mevcut, eklenmedi.
# Team ID 33714 zaten mevcut, eklenmedi.
# Team ID 6968 zaten mevcut, eklenmedi.
# Team ID 89372 zaten mevcut, eklenmedi.
# Team ID 89352 zaten mevcut, eklenmedi.
# Team ID 6110 zaten mevcut, eklenmedi.
# Team ID 39866 zaten mevcut, eklenmedi.
# Team ID 89374 zaten mevcut, eklenmedi.
# Team ID 6119 zaten mevcut, eklenmedi.
# Team ID 484422 zaten mevcut, eklenmedi.
# Team ID 89376 zaten mevcut, eklenmedi.
# Team ID 2220 zaten mevcut, eklenmedi.
# Team ID 121 zaten mevcut, eklenmedi.
# Team ID 94 zaten mevcut, eklenmedi.
# Team ID 166 zaten mevcut, eklenmedi.
# Team ID 103 zaten mevcut, eklenmedi.
# Team ID 102 zaten mevcut, eklenmedi.
# Team ID 73 zaten mevcut, eklenmedi.
# Team ID 3342 zaten mevcut, eklenmedi.
# Team ID 138566 zaten mevcut, eklenmedi.
# Team ID 2256 zaten mevcut, eklenmedi.
# Team ID 2554 zaten mevcut, eklenmedi.
# Team ID 2535 zaten mevcut, eklenmedi.
# Team ID 2566 zaten mevcut, eklenmedi.
# Team ID 53365 zaten mevcut, eklenmedi.
# Team ID 6157 zaten mevcut, eklenmedi.
# Team ID 52767 zaten mevcut, eklenmedi.
# Team ID 5883 zaten mevcut, eklenmedi.
# Team ID 2544 zaten mevcut, eklenmedi.
# Team ID 24267 zaten mevcut, eklenmedi.
# Team ID 2559 zaten mevcut, eklenmedi.
# Team ID 5050 zaten mevcut, eklenmedi.
# Team ID 23949 zaten mevcut, eklenmedi.
# Team ID 257618 zaten mevcut, eklenmedi.
# Team ID 275608 zaten mevcut, eklenmedi.
# Team ID 86578 zaten mevcut, eklenmedi.
# Team ID 76319 zaten mevcut, eklenmedi.
# Team ID 316183 zaten mevcut, eklenmedi.
# Team ID 192763 zaten mevcut, eklenmedi.
# Team ID 227164 zaten mevcut, eklenmedi.
# Team ID 55039 zaten mevcut, eklenmedi.
# Team ID 327830 zaten mevcut, eklenmedi.
# Team ID 55043 zaten mevcut, eklenmedi.
# Team ID 41757 zaten mevcut, eklenmedi.
# Team ID 5181 zaten mevcut, eklenmedi.
# Team ID 3125 zaten mevcut, eklenmedi.
# Team ID 386972 zaten mevcut, eklenmedi.
# Team ID 1807 zaten mevcut, eklenmedi.
# Team ID 35186 zaten mevcut, eklenmedi.
# Team ID 4912 zaten mevcut, eklenmedi.
# Team ID 215559 zaten mevcut, eklenmedi.
# Team ID 44555 zaten mevcut, eklenmedi.
# Team ID 48960 zaten mevcut, eklenmedi.
# Team ID 48972 zaten mevcut, eklenmedi.
# Team ID 17 zaten mevcut, eklenmedi.
# Team ID 38 zaten mevcut, eklenmedi.
# Team ID 7 zaten mevcut, eklenmedi.
# Team ID 2818 zaten mevcut, eklenmedi.
# Team ID 2845 zaten mevcut, eklenmedi.
# Team ID 2859 zaten mevcut, eklenmedi.
# Team ID 2833 zaten mevcut, eklenmedi.
# Team ID 6577 zaten mevcut, eklenmedi.
# Team ID 2693 zaten mevcut, eklenmedi.
# Team ID 2686 zaten mevcut, eklenmedi.
# Team ID 2696 zaten mevcut, eklenmedi.
# Team ID 2697 zaten mevcut, eklenmedi.
# Team ID 2729 zaten mevcut, eklenmedi.
# Team ID 2547 zaten mevcut, eklenmedi.
# Team ID 2534 zaten mevcut, eklenmedi.
# Team ID 1649 zaten mevcut, eklenmedi.
# Team ID 1682 zaten mevcut, eklenmedi.
# Team ID 1661 zaten mevcut, eklenmedi.
# Team ID 1684 zaten mevcut, eklenmedi.
# Team ID 1641 zaten mevcut, eklenmedi.
# Team ID 2948 zaten mevcut, eklenmedi.
# Team ID 2953 zaten mevcut, eklenmedi.
# Team ID 2947 zaten mevcut, eklenmedi.
# Team ID 1963 zaten mevcut, eklenmedi.
# Team ID 3085 zaten mevcut, eklenmedi.
# Team ID 6063 zaten mevcut, eklenmedi.
# Team ID 3052 zaten mevcut, eklenmedi.
# Team ID 3064 zaten mevcut, eklenmedi.
# Team ID 2889 zaten mevcut, eklenmedi.
# Team ID 2898 zaten mevcut, eklenmedi.
# Team ID 4858 zaten mevcut, eklenmedi.
# Team ID 5063 zaten mevcut, eklenmedi.
# Team ID 3248 zaten mevcut, eklenmedi.
# Team ID 3255 zaten mevcut, eklenmedi.
# Team ID 3251 zaten mevcut, eklenmedi.
# Team ID 197184 zaten mevcut, eklenmedi.
# Team ID 107723 zaten mevcut, eklenmedi.
# Team ID 79047 zaten mevcut, eklenmedi.
# Team ID 231976 zaten mevcut, eklenmedi.
# Team ID 90140 zaten mevcut, eklenmedi.
# Team ID 43732 zaten mevcut, eklenmedi.
# Team ID 3210 zaten mevcut, eklenmedi.
# Team ID 4937 zaten mevcut, eklenmedi.
# Team ID 3219 zaten mevcut, eklenmedi.
# Team ID 3212 zaten mevcut, eklenmedi.
# Team ID 65668 zaten mevcut, eklenmedi.
# Team ID 1950 zaten mevcut, eklenmedi.
# Team ID 2036 zaten mevcut, eklenmedi.
# Team ID 43917 zaten mevcut, eklenmedi.
# Team ID 308176 zaten mevcut, eklenmedi.
# Team ID 5152 zaten mevcut, eklenmedi.
# Team ID 41 zaten mevcut, eklenmedi.
# Team ID 2835 zaten mevcut, eklenmedi.
# Team ID 24265 zaten mevcut, eklenmedi.
# Team ID 2852 zaten mevcut, eklenmedi.
# Team ID 2858 zaten mevcut, eklenmedi.
# Team ID 2854 zaten mevcut, eklenmedi.
# Team ID 2770 zaten mevcut, eklenmedi.
# Team ID 2761 zaten mevcut, eklenmedi.
# Team ID 2801 zaten mevcut, eklenmedi.
# Team ID 2711 zaten mevcut, eklenmedi.
# Team ID 6070 zaten mevcut, eklenmedi.
# Team ID 1997 zaten mevcut, eklenmedi.
# Team ID 1972 zaten mevcut, eklenmedi.
# Team ID 1979 zaten mevcut, eklenmedi.
# Team ID 1960 zaten mevcut, eklenmedi.
# Team ID 2954 zaten mevcut, eklenmedi.
# Team ID 2966 zaten mevcut, eklenmedi.
# Team ID 2967 zaten mevcut, eklenmedi.
# Team ID 2994 zaten mevcut, eklenmedi.
# Team ID 77629 zaten mevcut, eklenmedi.
# Team ID 202391 zaten mevcut, eklenmedi.
# Team ID 3066 zaten mevcut, eklenmedi.
# Team ID 6366 zaten mevcut, eklenmedi.
# Team ID 2203 zaten mevcut, eklenmedi.
# Team ID 2058 zaten mevcut, eklenmedi.
# Team ID 2075 zaten mevcut, eklenmedi.
# Team ID 5391 zaten mevcut, eklenmedi.
# Team ID 5202 zaten mevcut, eklenmedi.
# Team ID 5395 zaten mevcut, eklenmedi.
# Team ID 3155 zaten mevcut, eklenmedi.
# Team ID 3164 zaten mevcut, eklenmedi.
# Team ID 3167 zaten mevcut, eklenmedi.
# Team ID 5032 zaten mevcut, eklenmedi.
# Team ID 3159 zaten mevcut, eklenmedi.
# Team ID 3153 zaten mevcut, eklenmedi.
# Team ID 6112 zaten mevcut, eklenmedi.
# Team ID 6115 zaten mevcut, eklenmedi.
# Team ID 6116 zaten mevcut, eklenmedi.
# Team ID 504899 zaten mevcut, eklenmedi.
# Team ID 6109 zaten mevcut, eklenmedi.
# Team ID 6113 zaten mevcut, eklenmedi.
# Team ID 89368 zaten mevcut, eklenmedi.
# Team ID 6107 zaten mevcut, eklenmedi.
# Team ID 6111 zaten mevcut, eklenmedi.
# Team ID 2208 zaten mevcut, eklenmedi.
# Team ID 2221 zaten mevcut, eklenmedi.
# Team ID 2216 zaten mevcut, eklenmedi.
# Team ID 38732 zaten mevcut, eklenmedi.
# Team ID 3117 zaten mevcut, eklenmedi.
# Team ID 38729 zaten mevcut, eklenmedi.
# Team ID 1301 zaten mevcut, eklenmedi.
# Team ID 1288 zaten mevcut, eklenmedi.
# Team ID 1285 zaten mevcut, eklenmedi.
# Team ID 1289 zaten mevcut, eklenmedi.
# Team ID 1281 zaten mevcut, eklenmedi.
# Team ID 5991 zaten mevcut, eklenmedi.
# Team ID 5997 zaten mevcut, eklenmedi.
# Team ID 5994 zaten mevcut, eklenmedi.
# Team ID 33001 zaten mevcut, eklenmedi.
# Team ID 6001 zaten mevcut, eklenmedi.
# Team ID 5254 zaten mevcut, eklenmedi.
# Team ID 5255 zaten mevcut, eklenmedi.
# Team ID 174598 zaten mevcut, eklenmedi.
# Team ID 331840 zaten mevcut, eklenmedi.
# Team ID 1159 zaten mevcut, eklenmedi.
# Team ID 822 zaten mevcut, eklenmedi.
# Team ID 673 zaten mevcut, eklenmedi.
# Team ID 1163 zaten mevcut, eklenmedi.
# Team ID 659 zaten mevcut, eklenmedi.
# Team ID 664 zaten mevcut, eklenmedi.
# Team ID 269199 zaten mevcut, eklenmedi.
# Team ID 168088 zaten mevcut, eklenmedi.
# Team ID 114259 zaten mevcut, eklenmedi.
# Team ID 24798 zaten mevcut, eklenmedi.
# Team ID 3301 zaten mevcut, eklenmedi.
# Team ID 44259 zaten mevcut, eklenmedi.
# Team ID 3294 zaten mevcut, eklenmedi.
# Team ID 1783 zaten mevcut, eklenmedi.
# Team ID 1842 zaten mevcut, eklenmedi.
# Team ID 1759 zaten mevcut, eklenmedi.
# Team ID 1787 zaten mevcut, eklenmedi.
# Team ID 1764 zaten mevcut, eklenmedi.
# Team ID 2442 zaten mevcut, eklenmedi.
# Team ID 2458 zaten mevcut, eklenmedi.
# Team ID 2443 zaten mevcut, eklenmedi.
# Team ID 312633 zaten mevcut, eklenmedi.
# Team ID 2322 zaten mevcut, eklenmedi.
# Team ID 2315 zaten mevcut, eklenmedi.
# Team ID 215083 zaten mevcut, eklenmedi.
# Team ID 34714 zaten mevcut, eklenmedi.
# Team ID 278067 zaten mevcut, eklenmedi.
# Team ID 252115 zaten mevcut, eklenmedi.
# Team ID 255501 zaten mevcut, eklenmedi.
# Team ID 234204 zaten mevcut, eklenmedi.
# Team ID 36704 zaten mevcut, eklenmedi.
# Team ID 26243 zaten mevcut, eklenmedi.
# Team ID 273547 zaten mevcut, eklenmedi.
# Team ID 2933 zaten mevcut, eklenmedi.
# Team ID 204712 zaten mevcut, eklenmedi.
# Team ID 26245 zaten mevcut, eklenmedi.
# Team ID 298858 zaten mevcut, eklenmedi.
# Team ID 404899 zaten mevcut, eklenmedi.
# Team ID 5556 zaten mevcut, eklenmedi.
# Team ID 322623 zaten mevcut, eklenmedi.
# Team ID 5543 zaten mevcut, eklenmedi.
# Team ID 77889 zaten mevcut, eklenmedi.
# Team ID 305051 zaten mevcut, eklenmedi.
# Team ID 1923 zaten mevcut, eklenmedi.
# Team ID 1926 zaten mevcut, eklenmedi.
# Team ID 7887 zaten mevcut, eklenmedi.
# Team ID 4503 zaten mevcut, eklenmedi.
# Team ID 43740 zaten mevcut, eklenmedi.
# Team ID 266694 zaten mevcut, eklenmedi.
# Team ID 93107 zaten mevcut, eklenmedi.
# Team ID 201162 zaten mevcut, eklenmedi.
# Team ID 3207 zaten mevcut, eklenmedi.
# Team ID 7772 zaten mevcut, eklenmedi.
# Team ID 3200 zaten mevcut, eklenmedi.
# Team ID 53801 zaten mevcut, eklenmedi.
# Team ID 265787 zaten mevcut, eklenmedi.
# Team ID 188441 zaten mevcut, eklenmedi.
# Team ID 3327 zaten mevcut, eklenmedi.
# Team ID 5966 zaten mevcut, eklenmedi.
# Team ID 7650 zaten mevcut, eklenmedi.
# Team ID 3137 zaten mevcut, eklenmedi.
# Team ID 21895 zaten mevcut, eklenmedi.
# Team ID 34314 zaten mevcut, eklenmedi.
# Team ID 34310 zaten mevcut, eklenmedi.
# Team ID 34469 zaten mevcut, eklenmedi.
# Team ID 267828 zaten mevcut, eklenmedi.
# Team ID 36951 zaten mevcut, eklenmedi.
# Team ID 60428 zaten mevcut, eklenmedi.
# Team ID 45471 zaten mevcut, eklenmedi.
# Team ID 42965 zaten mevcut, eklenmedi.
# Team ID 5231 zaten mevcut, eklenmedi.
# Team ID 3353 zaten mevcut, eklenmedi.
# Team ID 32529 zaten mevcut, eklenmedi.
# Team ID 268083 zaten mevcut, eklenmedi.
# Team ID 372975 zaten mevcut, eklenmedi.
# Team ID 37064 zaten mevcut, eklenmedi.
# Team ID 5240 zaten mevcut, eklenmedi.
# Team ID 37250 zaten mevcut, eklenmedi.
# Team ID 5981 zaten mevcut, eklenmedi.
# Team ID 232494 zaten mevcut, eklenmedi.
# Team ID 43840 zaten mevcut, eklenmedi.
# Team ID 274971 zaten mevcut, eklenmedi.
# Team ID 5601 zaten mevcut, eklenmedi.
# Team ID 3156 zaten mevcut, eklenmedi.
# Team ID 3152 zaten mevcut, eklenmedi.
# Team ID 5034 zaten mevcut, eklenmedi.
# Team ID 226871 zaten mevcut, eklenmedi.
# Team ID 262906 zaten mevcut, eklenmedi.
# Team ID 6576 zaten mevcut, eklenmedi.
# Team ID 7044 zaten mevcut, eklenmedi.
# Team ID 3397 zaten mevcut, eklenmedi.
# Team ID 3403 zaten mevcut, eklenmedi.
# Team ID 389259 zaten mevcut, eklenmedi.
# Team ID 3407 zaten mevcut, eklenmedi.
# Team ID 36741 zaten mevcut, eklenmedi.
# Team ID 1305 zaten mevcut, eklenmedi.
# Team ID 294406 zaten mevcut, eklenmedi.
# Team ID 42368 zaten mevcut, eklenmedi.
# Team ID 371622 zaten mevcut, eklenmedi.
# Team ID 5419 zaten mevcut, eklenmedi.
# Team ID 44217 zaten mevcut, eklenmedi.
# Team ID 2581 zaten mevcut, eklenmedi.
# Team ID 2536 zaten mevcut, eklenmedi.
# Team ID 24072 zaten mevcut, eklenmedi.
# Team ID 36572 zaten mevcut, eklenmedi.
# Team ID 24148 zaten mevcut, eklenmedi.
# Team ID 2578 zaten mevcut, eklenmedi.
# Team ID 2584 zaten mevcut, eklenmedi.
# Team ID 196369 zaten mevcut, eklenmedi.
# Team ID 81943 zaten mevcut, eklenmedi.
# Team ID 42610 zaten mevcut, eklenmedi.
# Team ID 42614 zaten mevcut, eklenmedi.
# Team ID 42613 zaten mevcut, eklenmedi.
# Team ID 486320 zaten mevcut, eklenmedi.
# Team ID 458755 zaten mevcut, eklenmedi.
# Team ID 115787 zaten mevcut, eklenmedi.
# Team ID 296031 zaten mevcut, eklenmedi.
# Team ID 3262 zaten mevcut, eklenmedi.
# Team ID 3265 zaten mevcut, eklenmedi.
# Team ID 120228 zaten mevcut, eklenmedi.
# Team ID 25230 zaten mevcut, eklenmedi.
# Team ID 23961 zaten mevcut, eklenmedi.
# Team ID 7730 zaten mevcut, eklenmedi.
# Team ID 163298 zaten mevcut, eklenmedi.
# Team ID 1902 zaten mevcut, eklenmedi.
# Team ID 1893 zaten mevcut, eklenmedi.
# Team ID 64299 zaten mevcut, eklenmedi.
# Team ID 53703 zaten mevcut, eklenmedi.
# Team ID 2769 zaten mevcut, eklenmedi.
# Team ID 37173 zaten mevcut, eklenmedi.
# Team ID 24745 zaten mevcut, eklenmedi.
# Team ID 2708 zaten mevcut, eklenmedi.
# Team ID 2736 zaten mevcut, eklenmedi.
# Team ID 117262 zaten mevcut, eklenmedi.
# Team ID 2754 zaten mevcut, eklenmedi.
# Team ID 393551 zaten mevcut, eklenmedi.
# Team ID 2725 zaten mevcut, eklenmedi.
# Team ID 2730 zaten mevcut, eklenmedi.
# Team ID 263397 zaten mevcut, eklenmedi.
# Team ID 25137 zaten mevcut, eklenmedi.
# Team ID 2733 zaten mevcut, eklenmedi.
# Team ID 7936 zaten mevcut, eklenmedi.
# Team ID 6361 zaten mevcut, eklenmedi.
# Team ID 826812 zaten mevcut, eklenmedi.
# Team ID 826802 zaten mevcut, eklenmedi.
# Team ID 5360 zaten mevcut, eklenmedi.
# Team ID 36080 zaten mevcut, eklenmedi.
# Team ID 36081 zaten mevcut, eklenmedi.
# Team ID 5343 zaten mevcut, eklenmedi.
# Team ID 5345 zaten mevcut, eklenmedi.
# Team ID 75279 zaten mevcut, eklenmedi.
# Team ID 33578 zaten mevcut, eklenmedi.
# Team ID 58327 zaten mevcut, eklenmedi.
# Team ID 38304 zaten mevcut, eklenmedi.
# Team ID 33584 zaten mevcut, eklenmedi.
# Team ID 354926 zaten mevcut, eklenmedi.
# Team ID 36526 zaten mevcut, eklenmedi.
# Team ID 283764 zaten mevcut, eklenmedi.
# Team ID 87180 zaten mevcut, eklenmedi.
# Team ID 388950 zaten mevcut, eklenmedi.
# Team ID 5403 zaten mevcut, eklenmedi.
# Team ID 5407 zaten mevcut, eklenmedi.
# Team ID 136548 zaten mevcut, eklenmedi.
# Team ID 43575 zaten mevcut, eklenmedi.
# Team ID 5413 zaten mevcut, eklenmedi.
# Team ID 667 zaten mevcut, eklenmedi.
# Team ID 668 zaten mevcut, eklenmedi.
# Team ID 1162 zaten mevcut, eklenmedi.
# Team ID 665 zaten mevcut, eklenmedi.
# Team ID 866 zaten mevcut, eklenmedi.
# Team ID 657 zaten mevcut, eklenmedi.
# Team ID 920 zaten mevcut, eklenmedi.
# Team ID 708 zaten mevcut, eklenmedi.
# Team ID 739 zaten mevcut, eklenmedi.
# Team ID 162252 zaten mevcut, eklenmedi.
# Team ID 7920 zaten mevcut, eklenmedi.
# Team ID 3105 zaten mevcut, eklenmedi.
# Team ID 44255 zaten mevcut, eklenmedi.
# Team ID 7517 zaten mevcut, eklenmedi.
# Team ID 2319 zaten mevcut, eklenmedi.
# Team ID 35301 zaten mevcut, eklenmedi.
# Team ID 2420 zaten mevcut, eklenmedi.
# Team ID 37737 zaten mevcut, eklenmedi.
# Team ID 7101 zaten mevcut, eklenmedi.
# Team ID 1763 zaten mevcut, eklenmedi.
# Team ID 199313 zaten mevcut, eklenmedi.
# Team ID 5954 zaten mevcut, eklenmedi.
# Team ID 47812 zaten mevcut, eklenmedi.
# Team ID 409200 zaten mevcut, eklenmedi.
# Team ID 1824 zaten mevcut, eklenmedi.
# Team ID 32871 zaten mevcut, eklenmedi.
# Team ID 8086 zaten mevcut, eklenmedi.
# Team ID 1884 zaten mevcut, eklenmedi.
# Team ID 1889 zaten mevcut, eklenmedi.
# Team ID 274247 zaten mevcut, eklenmedi.
# Team ID 59634 zaten mevcut, eklenmedi.
# Team ID 59628 zaten mevcut, eklenmedi.
# Team ID 59636 zaten mevcut, eklenmedi.
# Team ID 231649 zaten mevcut, eklenmedi.
# Team ID 200773 zaten mevcut, eklenmedi.
# Team ID 294048 zaten mevcut, eklenmedi.
# Team ID 3316 zaten mevcut, eklenmedi.
# Team ID 3228 zaten mevcut, eklenmedi.
# Team ID 25010 zaten mevcut, eklenmedi.
# Team ID 3230 zaten mevcut, eklenmedi.
# Team ID 3223 zaten mevcut, eklenmedi.
# Team ID 3234 zaten mevcut, eklenmedi.
# Team ID 6879 zaten mevcut, eklenmedi.
# Team ID 167106 zaten mevcut, eklenmedi.
# Team ID 526992 zaten mevcut, eklenmedi.
# Team ID 44560 zaten mevcut, eklenmedi.
# Team ID 44563 zaten mevcut, eklenmedi.
# Team ID 38067 zaten mevcut, eklenmedi.
# Team ID 5149 zaten mevcut, eklenmedi.
# Team ID 2888 zaten mevcut, eklenmedi.
# Team ID 3313 zaten mevcut, eklenmedi.
# Team ID 2685 zaten mevcut, eklenmedi.
# Team ID 2404 zaten mevcut, eklenmedi.
# Team ID 2677 zaten mevcut, eklenmedi.
# Team ID 2952 zaten mevcut, eklenmedi.
# Team ID 2673 zaten mevcut, eklenmedi.
# Team ID 3001 zaten mevcut, eklenmedi.
# Team ID 3211 zaten mevcut, eklenmedi.
# Team ID 1967 zaten mevcut, eklenmedi.
# Team ID 110757 zaten mevcut, eklenmedi.
# Team ID 43719 zaten mevcut, eklenmedi.
# Team ID 78151 zaten mevcut, eklenmedi.
# Team ID 43716 zaten mevcut, eklenmedi.
# Team ID 197177 zaten mevcut, eklenmedi.
# Team ID 120866 zaten mevcut, eklenmedi.
# Team ID 42728 zaten mevcut, eklenmedi.
# Team ID 198794 zaten mevcut, eklenmedi.
# Team ID 157226 zaten mevcut, eklenmedi.
# Team ID 268698 zaten mevcut, eklenmedi.
# Team ID 826807 zaten mevcut, eklenmedi.
# Team ID 491231 zaten mevcut, eklenmedi.
# Team ID 264848 zaten mevcut, eklenmedi.
# Team ID 353746 zaten mevcut, eklenmedi.
# Team ID 491481 zaten mevcut, eklenmedi.
# Team ID 1936 zaten mevcut, eklenmedi.
# Team ID 1944 zaten mevcut, eklenmedi.
# Team ID 1941 zaten mevcut, eklenmedi.
# Team ID 1940 zaten mevcut, eklenmedi.
# Team ID 243211 zaten mevcut, eklenmedi.
# Team ID 2 zaten mevcut, eklenmedi.
# Team ID 24 zaten mevcut, eklenmedi.
# Team ID 27 zaten mevcut, eklenmedi.
# Team ID 263 zaten mevcut, eklenmedi.
# Team ID 74 zaten mevcut, eklenmedi.
# Team ID 58 zaten mevcut, eklenmedi.
# Team ID 11 zaten mevcut, eklenmedi.
# Team ID 35092 zaten mevcut, eklenmedi.
# Team ID 33779 zaten mevcut, eklenmedi.
# Team ID 1655 zaten mevcut, eklenmedi.
# Team ID 21982 zaten mevcut, eklenmedi.
# Team ID 2001 zaten mevcut, eklenmedi.
# Team ID 7315 zaten mevcut, eklenmedi.
# Team ID 336664 zaten mevcut, eklenmedi.
# Team ID 2958 zaten mevcut, eklenmedi.
# Team ID 2978 zaten mevcut, eklenmedi.
# Team ID 2963 zaten mevcut, eklenmedi.
# Team ID 46161 zaten mevcut, eklenmedi.
# Team ID 5197 zaten mevcut, eklenmedi.
# Team ID 47 zaten mevcut, eklenmedi.
# Team ID 5 zaten mevcut, eklenmedi.
# Team ID 82 zaten mevcut, eklenmedi.
# Team ID 62 zaten mevcut, eklenmedi.
# Team ID 92 zaten mevcut, eklenmedi.
# Team ID 28 zaten mevcut, eklenmedi.
# Team ID 13 zaten mevcut, eklenmedi.
# Team ID 67 zaten mevcut, eklenmedi.
# Team ID 63 zaten mevcut, eklenmedi.
# Team ID 57 zaten mevcut, eklenmedi.
# Team ID 70 zaten mevcut, eklenmedi.
# Team ID 59 zaten mevcut, eklenmedi.
# Team ID 81 zaten mevcut, eklenmedi.
# Team ID 56 zaten mevcut, eklenmedi.
# Team ID 22 zaten mevcut, eklenmedi.
# Team ID 66 zaten mevcut, eklenmedi.
# Team ID 180 zaten mevcut, eklenmedi.
# Team ID 19 zaten mevcut, eklenmedi.
# Team ID 79 zaten mevcut, eklenmedi.
# Team ID 55 zaten mevcut, eklenmedi.
# Team ID 187 zaten mevcut, eklenmedi.
# Team ID 53 zaten mevcut, eklenmedi.
# Team ID 18 zaten mevcut, eklenmedi.
# Team ID 78 zaten mevcut, eklenmedi.
# Team ID 40655 zaten mevcut, eklenmedi.
# Team ID 3139 zaten mevcut, eklenmedi.
# Team ID 3136 zaten mevcut, eklenmedi.
# Team ID 3140 zaten mevcut, eklenmedi.
# Team ID 458584 zaten mevcut, eklenmedi.
# Team ID 5281 zaten mevcut, eklenmedi.
# Team ID 87854 zaten mevcut, eklenmedi.
# Team ID 33895 zaten mevcut, eklenmedi.
# Team ID 7671 zaten mevcut, eklenmedi.
# Team ID 238384 zaten mevcut, eklenmedi.
# Team ID 42206 zaten mevcut, eklenmedi.
# Team ID 3146 zaten mevcut, eklenmedi.
# Team ID 5127 zaten mevcut, eklenmedi.
# Team ID 47674 zaten mevcut, eklenmedi.
# Team ID 23400 zaten mevcut, eklenmedi.
# Team ID 8018 zaten mevcut, eklenmedi.
# Team ID 40650 zaten mevcut, eklenmedi.
# Team ID 5971 zaten mevcut, eklenmedi.
# Team ID 413276 zaten mevcut, eklenmedi.
# Team ID 6908 zaten mevcut, eklenmedi.
# Team ID 2108 zaten mevcut, eklenmedi.
# Team ID 505268 zaten mevcut, eklenmedi.
# Team ID 268082 zaten mevcut, eklenmedi.
# Team ID 335685 zaten mevcut, eklenmedi.
# Team ID 89364 zaten mevcut, eklenmedi.
# Team ID 213490 zaten mevcut, eklenmedi.
# Team ID 89362 zaten mevcut, eklenmedi.
# Team ID 89358 zaten mevcut, eklenmedi.
# Team ID 6104 zaten mevcut, eklenmedi.
# Team ID 89354 zaten mevcut, eklenmedi.
# Team ID 6108 zaten mevcut, eklenmedi.
# Team ID 89366 zaten mevcut, eklenmedi.
# Team ID 4863 zaten mevcut, eklenmedi.
# Team ID 6191 zaten mevcut, eklenmedi.
# Team ID 114 zaten mevcut, eklenmedi.
# Team ID 65 zaten mevcut, eklenmedi.
# Team ID 87 zaten mevcut, eklenmedi.
# Team ID 131 zaten mevcut, eklenmedi.
# Team ID 77 zaten mevcut, eklenmedi.
# Team ID 37572 zaten mevcut, eklenmedi.
# Team ID 7106 zaten mevcut, eklenmedi.
# Team ID 2273 zaten mevcut, eklenmedi.
# Team ID 2533 zaten mevcut, eklenmedi.
# Team ID 2680 zaten mevcut, eklenmedi.
# Team ID 2532 zaten mevcut, eklenmedi.
# Team ID 5880 zaten mevcut, eklenmedi.
# Team ID 2522 zaten mevcut, eklenmedi.
# Team ID 70944 zaten mevcut, eklenmedi.
# Team ID 23947 zaten mevcut, eklenmedi.
# Team ID 23537 zaten mevcut, eklenmedi.
# Team ID 5791 zaten mevcut, eklenmedi.
# Team ID 2599 zaten mevcut, eklenmedi.
# Team ID 75131 zaten mevcut, eklenmedi.
# Team ID 75115 zaten mevcut, eklenmedi.
# Team ID 5872 zaten mevcut, eklenmedi.
# Team ID 2568 zaten mevcut, eklenmedi.
# Team ID 189471 zaten mevcut, eklenmedi.
# Team ID 135864 zaten mevcut, eklenmedi.
# Team ID 5362 zaten mevcut, eklenmedi.
# Team ID 168446 zaten mevcut, eklenmedi.
# Team ID 5291 zaten mevcut, eklenmedi.
# Team ID 118834 zaten mevcut, eklenmedi.
# Team ID 55035 zaten mevcut, eklenmedi.
# Team ID 55049 zaten mevcut, eklenmedi.
# Team ID 24394 zaten mevcut, eklenmedi.
# Team ID 5270 zaten mevcut, eklenmedi.
# Team ID 3111 zaten mevcut, eklenmedi.
# Team ID 2370 zaten mevcut, eklenmedi.
# Team ID 1768 zaten mevcut, eklenmedi.
# Team ID 115185 zaten mevcut, eklenmedi.
# Team ID 4905 zaten mevcut, eklenmedi.
# Team ID 44561 zaten mevcut, eklenmedi.
# Team ID 413097 zaten mevcut, eklenmedi.
# Team ID 38071 zaten mevcut, eklenmedi.
# Team ID 36914 zaten mevcut, eklenmedi.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 240
#     238 api.season_data()
#     239 api.team_data()
# --> 240 api.match_data()
#     241 print("İşlemler bitti")
#
# Cell In[9], line 181, in SofascoreAPI.match_data(self)
#     171 model_cols = ['id', 'startTimestamp', 'slug', 'tournament.uniqueTournament.id', 'season.id',
#     172               'roundInfo.round', 'status.type', 'homeTeam.id', 'awayTeam.id',
#     173               'homeScore.current', 'homeScore.display', 'homeScore.period1', 'homeScore.period2', 'homeScore.normaltime',
#     174               'awayScore.current', 'awayScore.display', 'awayScore.period1', 'awayScore.period2', 'awayScore.normaltime']
#     176 new_cols = ['id', 'date', 'slug', 'tournament_uniqueTournament_id', 'season_id',
#     177             'roundInfo_round', 'status_type', 'homeTeam_id', 'awayTeam_id',
#     178             'homeScore_current', 'homeScore_display', 'homeScore_period1', 'homeScore_period2', 'homeScore_normaltime',
#     179             'awayScore_current', 'awayScore_display', 'awayScore_period1', 'awayScore_period2', 'awayScore_normaltime']
# --> 181 df1 = verim[model_cols]  # Verileri modeldeki sütunlara göre seçme
#     182 df1.columns = new_cols  # Sütunları yeniden isimlendirme
#     184 for _, row in df1.iterrows():
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:3902, in DataFrame.__getitem__(self, key)
#    3900     if is_iterator(key):
#    3901         key = list(key)
# -> 3902     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3904 # take() does not accept boolean indexers
#    3905 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6114 self._raise_if_missing(keyarr, indexer, axis_name)
#    6116 keyarr = self.take(indexer)
#    6117 if isinstance(key, Index):
#    6118     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6178, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6175     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6177 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6178 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['tournament.uniqueTournament.id', 'season.id', 'roundInfo.round', 'status.type', 'homeTeam.id', 'awayTeam.id', 'homeScore.current', 'homeScore.display', 'homeScore.period1', 'homeScore.period2', 'homeScore.normaltime', 'awayScore.current', 'awayScore.display', 'awayScore.period1', 'awayScore.period2', 'awayScore.normaltime'] not in index"

# %%
Seasonx = Season.objects.all().values()
Seasonx = list(Seasonx)
Seasonx = pd.DataFrame(Seasonx)
Seasonx
# Out:
#      season_id                   season_name season_year  tournament_id
# 0        57284              Allsvenskan 2024        2024             40
# 1        57318           USL League One 2024        2024          13362
# 2        57322              Eliteserien 2024        2024             20
# 3        57356             1st Division 2024        2024             22
# 4        57359        Toppserien, Women 2024        2024            201
# ..         ...                           ...         ...            ...
# 99       65687  Primera Division Women 24/25       24/25           1127
# 100      65961     Indian Super League 24/25       24/25           1900
# 101      66456       UEFA Youth League 24/25       24/25           2132
# 102      66662          Super League 2 24/25       24/25            186
# 103      67785                 Supercup 2024        2024          14688
#
# [104 rows x 4 columns]

# %%
Teamdata = Team.objects.all().values()
Teamdata = list(Teamdata)
Teamdata= pd.DataFrame(Teamdata)
Teamdata
# Out:
#      team_id          team_name                team_slug   team_shortName  \
# 0          3      Wolverhampton            wolverhampton           Wolves
# 1          7     Crystal Palace           crystal-palace   Crystal Palace
# 2         14  Nottingham Forest        nottingham-forest           Forest
# 3         17    Manchester City          manchester-city         Man City
# 4         38            Chelsea                  chelsea          Chelsea
# ..       ...                ...                      ...              ...
# 654   826802     Fiorentina U20   acf-fiorentina-u20-u20   Fiorentina U20
# 655   826810        Udinese U20   udinese-calcio-u20-u20     Udinese U20
# 656   826812          Genoa U20        genoa-cfc-u20-u20       Genoa U20
# 657   826817      Sampdoria U20  sampdoria-genoa-u20-u20   Sampdoria U20
# 658   894568    Asteras B Aktor       asteras-tripolis-b  Asteras B Aktor
#
#     team_nameCode  team_national  tournament_id  season_id
# 0             WOL          False             17      61627
# 1             CRY          False             17      61627
# 2             NFO          False             17      61627
# 3             MCI          False             17      61627
# 4             CHE          False             17      61627
# ..            ...            ...            ...        ...
# 654           ACF          False           2292      64432
# 655           UDI          False           2292      64432
# 656           GEN          False           2292      64432
# 657           SAM          False           2292      64432
# 658           AST          False            186      66662
#
# [659 rows x 8 columns]

# %%
takım = Teamdata[Teamdata["team_id"]==3052]
takım
# Out:
#      team_id   team_name   team_slug team_shortName team_nameCode  \
# 200     3052  Fenerbahçe  fenerbahce     Fenerbahçe           FEN
#
#      team_national  tournament_id  season_id
# 200          False             52      63814

# %%
from basemodels.models import Tournament, Season, Team
Tournamentx = Tournament.objects.all().values()
Tournamentx = list(Tournamentx)
Tournamentx= pd.DataFrame(Tournamentx)
Tournamentx
# Out:
#      tournament_id                 tournament_name  \
# 0                8                          LaLiga
# 1                9           Challenger Pro League
# 2               17                  Premier League
# 3               18                    Championship
# 4               20                     Eliteserien
# ..             ...                             ...
# 99           11621               Liga MX, Apertura
# 100          11653                Primera División
# 101          13362                 USL, League One
# 102          14688                       Super Cup
# 103          16736  Division Profesional, Clausura
#
#                    tournament_slug tournament_category_name  \
# 0                           laliga                    Spain
# 1            challenger-pro-league                  Belgium
# 2                   premier-league                  England
# 3                     championship                  England
# 4                      eliteserien                   Norway
# ..                             ...                      ...
# 99                liga-mx-apertura                   Mexico
# 100               primera-division                    Chile
# 101                 usl-league-one                      USA
# 102                      super-cup                    Egypt
# 103  division-profesional-clausura                  Bolivia
#
#     tournament_category_slug  tournament_uniqueTournament_category_id  \
# 0                      spain                                       32
# 1                    belgium                                       33
# 2                    england                                        1
# 3                    england                                        1
# 4                     norway                                        5
# ..                       ...                                      ...
# 99                    mexico                                       12
# 100                    chile                                       49
# 101                      usa                                       26
# 102                    egypt                                      305
# 103                  bolivia                                      379
#
#      tournament_uniqueTournament_hasEventPlayerStatistics  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 99                                               False
# 100                                              False
# 101                                              False
# 102                                              False
# 103                                              False
#
#      tournament_model_id  tournament_isGroup  \
# 0                     36               False
# 1                    692               False
# 2                      1               False
# 3                      2               False
# 4                      5               False
# ..                   ...                 ...
# 99                    28               False
# 100                64475               False
# 101                71366               False
# 102                22348               False
# 103               130078               False
#
#      tournament_uniqueTournament_hasPerformanceGraphFeature
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 99                                               False
# 100                                              False
# 101                                              False
# 102                                              False
# 103                                              False
#
# [104 rows x 10 columns]

# %%
result = pd.merge(Teamdata,Seasonx , on="season_id")
result
# Out:
#      team_id             team_name                team_slug  team_shortName  \
# 0          3         Wolverhampton            wolverhampton          Wolves
# 1          7        Crystal Palace           crystal-palace  Crystal Palace
# 2         14     Nottingham Forest        nottingham-forest          Forest
# 3         17       Manchester City          manchester-city        Man City
# 4         38               Chelsea                  chelsea         Chelsea
# ..       ...                   ...                      ...             ...
# 654   405294  Central Valley Fuego     central-valley-fuego        CV Fuego
# 655   826802        Fiorentina U20   acf-fiorentina-u20-u20  Fiorentina U20
# 656   826810           Udinese U20   udinese-calcio-u20-u20    Udinese U20
# 657   826812             Genoa U20        genoa-cfc-u20-u20      Genoa U20
# 658   826817         Sampdoria U20  sampdoria-genoa-u20-u20  Sampdoria U20
#
#     team_nameCode  team_national  tournament_id_x  season_id  \
# 0             WOL          False               17      61627
# 1             CRY          False               17      61627
# 2             NFO          False               17      61627
# 3             MCI          False               17      61627
# 4             CHE          False               17      61627
# ..            ...            ...              ...        ...
# 654           FUE          False            13362      57318
# 655           ACF          False             2292      64432
# 656           UDI          False             2292      64432
# 657           GEN          False             2292      64432
# 658           SAM          False             2292      64432
#
#               season_name season_year  tournament_id_y
# 0    Premier League 24/25       24/25               17
# 1    Premier League 24/25       24/25               17
# 2    Premier League 24/25       24/25               17
# 3    Premier League 24/25       24/25               17
# 4    Premier League 24/25       24/25               17
# ..                    ...         ...              ...
# 654   USL League One 2024        2024            13362
# 655     Primavera 1 24/25       24/25             2292
# 656     Primavera 1 24/25       24/25             2292
# 657     Primavera 1 24/25       24/25             2292
# 658     Primavera 1 24/25       24/25             2292
#
# [659 rows x 11 columns]
