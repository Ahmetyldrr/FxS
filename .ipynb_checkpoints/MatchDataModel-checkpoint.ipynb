# %%
import os
import django
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'Home.settings')
django.setup()
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
from basemodels.models import Tournament, Season, Team,Match
from basemodels.models import FikstureModelData
from datetime import datetime, timedelta
import pandas as pd
from django.db import IntegrityError

class SofascoreAPI:
    def __init__(self):
        pass

    def fetch_data(self):
        data = FikstureModelData.objects.all().values()
        data_list = list(data)
        df = pd.DataFrame(data_list)
        df_exploded = df.explode('data')
        expanded_data = pd.json_normalize(df_exploded['data'])
        expanded_data['tarih'] = list(df_exploded['tarih'])
        veri = expanded_data.copy()
        veri.columns = [item.replace(".", "_") for item in veri.columns]
        return veri

    def tournament_data(self):
        verim = self.fetch_data()
        if verim is None:
            raise ValueError("Veri işlenmedi. Önce 'process_data()' metodunu çalıştırın.")
        
        # Aynı uniqueTournament_id'ye sahip olanları tekrar kontrol et
        verim = verim.drop_duplicates("tournament_uniqueTournament_id")
        
        cols = [
            "tournament_uniqueTournament_id", "tournament_name", "tournament_slug", "tournament_category_name",
            "tournament_category_slug", "tournament_uniqueTournament_category_id", 
            "tournament_uniqueTournament_hasEventPlayerStatistics", "tournament_id", "tournament_isGroup", 
            "tournament_uniqueTournament_hasPerformanceGraphFeature"
        ]
        
        for col in cols:
            if col not in verim.columns:
                verim.loc[:, col] = 0

        verim = verim[cols]

        for _, row in verim.iterrows():
            tournament_id = row['tournament_uniqueTournament_id']
            
            if pd.isna(tournament_id):
                print(f"Geçersiz tournament_uniqueTournament_id: {tournament_id}, atlanıyor.")
                continue
        
            if not Tournament.objects.filter(tournament_id=tournament_id).exists():
                Tournament.objects.create(
                    tournament_id=row['tournament_uniqueTournament_id'],
                    tournament_name=row['tournament_name'],
                    tournament_slug=row['tournament_slug'],
                    tournament_category_name=row['tournament_category_name'],
                    tournament_category_slug=row['tournament_category_slug'],
                    tournament_uniqueTournament_category_id=row['tournament_uniqueTournament_category_id'],
                    tournament_model_id=row['tournament_id'],
                    tournament_isGroup=row['tournament_isGroup'] if pd.notna(row['tournament_isGroup']) else False,
                    tournament_uniqueTournament_hasPerformanceGraphFeature=row['tournament_uniqueTournament_hasPerformanceGraphFeature'] if pd.notna(row['tournament_uniqueTournament_hasPerformanceGraphFeature']) else False
                )
                print(f"Tournament ID {tournament_id} başarıyla eklendi.")
            else:
                print(f"Tournament ID {tournament_id} zaten mevcut, eklenmedi.")

    def season_data(self):
        verim = self.fetch_data()
        if verim is None:
            raise ValueError("Veri işlenmedi. Önce 'process_data()' metodunu çalıştırın.")
        
        verim = verim.drop_duplicates("season_id")
        
        season_cols = ["season_id", "season_name", "season_year","tournament_uniqueTournament_id"]

        for col in season_cols:
            if col not in verim.columns:
                verim.loc[:, col] = 0

        verim = verim[season_cols]

        for _, row in verim.iterrows():
            season_id = row['season_id']
            tournament_id = row.get('tournament_uniqueTournament_id')
    
            if pd.isna(season_id) or pd.isna(tournament_id):
                print(f"Geçersiz season_id veya tournament_id: Season ID={season_id}, Tournament ID={tournament_id}. Atlanıyor.")
                continue
    
            if not Season.objects.filter(season_id=season_id).exists():
                tournament_instance = Tournament.objects.filter(tournament_id=tournament_id).first()
                
                if tournament_instance:
                    Season.objects.create(
                        season_id=row['season_id'],
                        season_name=row['season_name'],
                        season_year=row['season_year'],
                        tournament=tournament_instance  # Doğru sütun adı burada kullanılıyor
                    )
                    print(f"Season ID {season_id} başarıyla eklendi.")
                else:
                    print(f"Tournament ID {tournament_id} bulunamadı, Season ID {season_id} eklenemedi.")
            else:
                print(f"Season ID {season_id} zaten mevcut, eklenmedi.")
    
   
    def team_data(self):

        data = self.fetch_data()
        homecols = [
                    "homeTeam_id", "homeTeam_name", "homeTeam_slug", "homeTeam_shortName",
                    "homeTeam_nameCode", "homeTeam_national", "tournament_uniqueTournament_id", "season_id"
                ]
        
        awaycols = [
                    "awayTeam_id", "awayTeam_name", "awayTeam_slug", "awayTeam_shortName",
                    "awayTeam_nameCode", "awayTeam_national", "tournament_uniqueTournament_id", "season_id"
                ]
        
        # Home takımı için veri seçimi ve kolon isimlerinin ayarlanması
        homedata = data[homecols]
        homedata.columns = ["team_id", "team_name", "team_slug", "team_shortName",
                                       "team_nameCode", "team_national", "tournament_id", "season_id"]
        
        # Away takımı için veri seçimi ve kolon isimlerinin ayarlanması
        awaydata = data[awaycols]
        awaydata.columns  = ["team_id", "team_name", "team_slug", "team_shortName",
                                       "team_nameCode", "team_national", "tournament_id", "season_id"]
        
        # Home ve Away takımları birleştirme
        teamdata = pd.concat([homedata, awaydata])
        teamdata = teamdata.drop_duplicates(subset=["team_id", "tournament_id", "season_id"])
       
        for _, row in teamdata.iterrows():
            team_id = row['team_id']
            tournament_id = row['tournament_id']
            season_id = row['season_id']
            
            # Geçersiz veya eksik id'leri atla
            if pd.isna(team_id) or pd.isna(tournament_id) or pd.isna(season_id):
                print(f"Geçersiz değer: Team ID={team_id}, Tournament ID={tournament_id}, Season ID={season_id}. Atlanıyor.")
                continue

            # İlgili tournament ve season nesnelerini getir
            tournament_instance = Tournament.objects.filter(tournament_id=tournament_id).first()
            season_instance = Season.objects.filter(season_id=season_id).first()

            try:
       
                team, created = Team.objects.get_or_create(
                    team_id=team_id,
                    defaults={
                        "team_name": row['team_name'],
                        "team_slug": row['team_slug'],
                        "team_shortName": row['team_shortName'],
                        "team_nameCode": row['team_nameCode'],
                        "team_national": row['team_national'],
                        "tournament": tournament_instance,
                        "season": season_instance,
                    }
                )
                if created:
                    print(f"Team ID {team_id} başarıyla eklendi.")
                else:
                    print(f"Team ID {team_id} zaten mevcut, ekleme yapılmadı.")
                    
            except IntegrityError:
                print(f"UNIQUE constraint hatası! Team ID {team_id} zaten veritabanında mevcut.")

    def match_data(self):
        # Fetch data from the API or existing model
        verim = self.fetch_data()
        if verim is None:
            raise ValueError("Veri işlenmedi. Lütfen önce 'process_data()' metodunu çalıştırın.")
        
     
     
        new_cols = ['id', 'startTimestamp', 'slug', 'tournament_uniqueTournament_id', 'season_id',
                    'roundInfo_round', 'status_type', 'homeTeam_id', 'awayTeam_id',
                    'homeScore_current', 'homeScore_period1', 'homeScore_period2', 'homeScore_normaltime',
                    'awayScore_current', 'awayScore_period1', 'awayScore_period2', 'awayScore_normaltime']
        
        df1 = verim[new_cols] 
        df1['date'] = pd.to_datetime(df1['startTimestamp'], unit='s') + timedelta(hours=3)
        df2 = df1.drop("startTimestamp", axis=1)
        df3 = df2.fillna(0)
        for _, row in df3.iterrows():
            match_id = row['id']
            tournament_id = row['tournament_uniqueTournament_id']
            season_id = row['season_id']
            home_team_id = row['homeTeam_id']
            away_team_id = row['awayTeam_id']
            
            # Geçersiz veya eksik id'leri atla
            if pd.isna(match_id) or pd.isna(tournament_id) or pd.isna(season_id) or pd.isna(home_team_id) or pd.isna(away_team_id):
                print(f"Geçersiz değer: Match ID={match_id}, Tournament ID={tournament_id}, Season ID={season_id}, Home Team ID={home_team_id}, Away Team ID={away_team_id}. Atlanıyor.")
                continue

            # İlgili foreign key nesnelerini getir
            tournament_instance = Tournament.objects.filter(tournament_id=tournament_id).first()
            season_instance = Season.objects.filter(season_id=season_id).first()
            home_team_instance = Team.objects.filter(team_id=home_team_id).first()
            away_team_instance = Team.objects.filter(team_id=away_team_id).first()
            try:
                if tournament_instance and season_instance and home_team_instance and away_team_instance:
                    # Match'in veritabanında olup olmadığını kontrol et, yoksa oluştur
                    match, created = Match.objects.get_or_create(
                        id=match_id,
                        defaults={
                            'startTimestamp': row['date'],  # DateTimeField olarak datetime verisi
                            'slug': row['slug'],
                            'tournament': tournament_instance,
                            'season': season_instance,
                            'homeTeam': home_team_instance,
                            'awayTeam': away_team_instance,
                            'roundInfo_round': row['roundInfo_round'],
                            'homeScore_current': row['homeScore_current'],
                            'homeScore_period1': row['homeScore_period1'],
                            'homeScore_period2': row['homeScore_period2'],
                            'homeScore_normaltime': row['homeScore_normaltime'],
                            'awayScore_current': row['awayScore_current'],
                            'awayScore_period1': row['awayScore_period1'],
                            'awayScore_period2': row['awayScore_period2'],
                            'awayScore_normaltime': row['awayScore_normaltime'],
                            'status_type': row['status_type']
                        }
                    )
                    if created:
                        print(f"Match ID {match_id} başarıyla eklendi.")
                    else:
                        print(f"Match ID {match_id} zaten mevcut, eklenmedi.")
                else:
                    print(f"Tournament ID {tournament_id}, Season ID {season_id}, Home Team ID {home_team_id}, Away Team ID {away_team_id} bulunamadı.")
            except IntegrityError:
                print(f"UNIQUE constraint hatası! Match ID {match_id} zaten veritabanında mevcut.")
            except Exception as e:
                print(f"Match ID {match_id} eklenirken bir hata oluştu: {e}")



# SofascoreAPI sınıfını kullanarak team_data'yı veritabanına kaydetmek için:
api = SofascoreAPI()
teamdata = api.fetch_data()  # Veriyi getirin (API'den ya da dosyadan)
api.tournament_data()
api.season_data()
api.team_data()
api.match_data()
print("İşlemler bitti")
# Out:
# Tournament ID 1 başarıyla eklendi.
# Tournament ID 133 başarıyla eklendi.
# Tournament ID 325 başarıyla eklendi.
# Tournament ID 390 başarıyla eklendi.
# Tournament ID 11653 başarıyla eklendi.
# Tournament ID 808 başarıyla eklendi.
# Tournament ID 196 başarıyla eklendi.
# Tournament ID 13470 başarıyla eklendi.
# Tournament ID 13363 başarıyla eklendi.
# Team ID 36261 başarıyla eklendi.
# Team ID 21904 zaten mevcut, ekleme yapılmadı.
# Team ID 3146 zaten mevcut, ekleme yapılmadı.
# Team ID 5128 zaten mevcut, ekleme yapılmadı.
# Team ID 3143 zaten mevcut, ekleme yapılmadı.
# Team ID 3141 zaten mevcut, ekleme yapılmadı.
# Team ID 3147 zaten mevcut, ekleme yapılmadı.
# Team ID 3138 zaten mevcut, ekleme yapılmadı.
# Team ID 3142 zaten mevcut, ekleme yapılmadı.
# Team ID 38150 başarıyla eklendi.
# Team ID 3134 zaten mevcut, ekleme yapılmadı.
# Team ID 3140 zaten mevcut, ekleme yapılmadı.
# Team ID 5127 zaten mevcut, ekleme yapılmadı.
# Team ID 3149 zaten mevcut, ekleme yapılmadı.
# Team ID 3135 zaten mevcut, ekleme yapılmadı.
# Team ID 21905 zaten mevcut, ekleme yapılmadı.
# Team ID 3137 zaten mevcut, ekleme yapılmadı.
# Team ID 512469 başarıyla eklendi.
# Team ID 243211 zaten mevcut, ekleme yapılmadı.
# Team ID 153498 zaten mevcut, ekleme yapılmadı.
# Team ID 235508 başarıyla eklendi.
# Team ID 204211 başarıyla eklendi.
# Team ID 229758 başarıyla eklendi.
# Team ID 203029 başarıyla eklendi.
# Team ID 36891 başarıyla eklendi.
# Team ID 228035 başarıyla eklendi.
# Team ID 246943 başarıyla eklendi.
# Team ID 73883 başarıyla eklendi.
# Team ID 36095 başarıyla eklendi.
# Team ID 37995 başarıyla eklendi.
# Team ID 45364 başarıyla eklendi.
# Team ID 58167 başarıyla eklendi.
# Team ID 362880 başarıyla eklendi.
# Team ID 7944 başarıyla eklendi.
# Team ID 6337 başarıyla eklendi.
# Team ID 25933 başarıyla eklendi.
# Team ID 229 başarıyla eklendi.
# Team ID 3211 başarıyla eklendi.
# Team ID 3227 zaten mevcut, ekleme yapılmadı.
# Team ID 1930 başarıyla eklendi.
# Team ID 25399 başarıyla eklendi.
# Team ID 6068 başarıyla eklendi.
# Team ID 2320 başarıyla eklendi.
# Team ID 3250 başarıyla eklendi.
# Team ID 2980 başarıyla eklendi.
# Team ID 5366 zaten mevcut, ekleme yapılmadı.
# Team ID 3346 başarıyla eklendi.
# Team ID 68718 zaten mevcut, ekleme yapılmadı.
# Team ID 2404 zaten mevcut, ekleme yapılmadı.
# Team ID 5194 başarıyla eklendi.
# Team ID 43840 zaten mevcut, ekleme yapılmadı.
# Team ID 3361 zaten mevcut, ekleme yapılmadı.
# Team ID 5235 zaten mevcut, ekleme yapılmadı.
# Team ID 6151 başarıyla eklendi.
# Team ID 5346 zaten mevcut, ekleme yapılmadı.
# Team ID 1966 zaten mevcut, ekleme yapılmadı.
# Team ID 313716 zaten mevcut, ekleme yapılmadı.
# Team ID 309888 zaten mevcut, ekleme yapılmadı.
# Team ID 2263 başarıyla eklendi.
# Team ID 2509 zaten mevcut, ekleme yapılmadı.
# Team ID 274650 zaten mevcut, ekleme yapılmadı.
# Team ID 3128 başarıyla eklendi.
# Team ID 5170 başarıyla eklendi.
# Team ID 105969 başarıyla eklendi.
# Team ID 497712 başarıyla eklendi.
# Team ID 37179 başarıyla eklendi.
# Team ID 25613 başarıyla eklendi.
# Team ID 2561 başarıyla eklendi.
# Team ID 2032 başarıyla eklendi.
# Team ID 7922 başarıyla eklendi.
# Team ID 2398 başarıyla eklendi.
# Team ID 2530 başarıyla eklendi.
# Team ID 43194 başarıyla eklendi.
# Team ID 416560 başarıyla eklendi.
# Team ID 36467 başarıyla eklendi.
# Team ID 5777 başarıyla eklendi.
# Team ID 2549 başarıyla eklendi.
# Team ID 447267 başarıyla eklendi.
# Team ID 73 başarıyla eklendi.
# Team ID 61 başarıyla eklendi.
# Team ID 37467 başarıyla eklendi.
# Team ID 7026 başarıyla eklendi.
# Team ID 370885 başarıyla eklendi.
# Team ID 7409 başarıyla eklendi.
# Team ID 1762 zaten mevcut, ekleme yapılmadı.
# Team ID 2397 zaten mevcut, ekleme yapılmadı.
# Team ID 6059 başarıyla eklendi.
# Team ID 5173 başarıyla eklendi.
# Team ID 5241 başarıyla eklendi.
# Team ID 3111 başarıyla eklendi.
# Team ID 325494 başarıyla eklendi.
# Team ID 5355 zaten mevcut, ekleme yapılmadı.
# Team ID 146336 zaten mevcut, ekleme yapılmadı.
# Team ID 312564 zaten mevcut, ekleme yapılmadı.
# Team ID 255156 başarıyla eklendi.
# Team ID 262228 başarıyla eklendi.
# Team ID 261800 zaten mevcut, ekleme yapılmadı.
# Team ID 37962 başarıyla eklendi.
# Team ID 7105 zaten mevcut, ekleme yapılmadı.
# Team ID 5419 başarıyla eklendi.
# Team ID 33584 başarıyla eklendi.
# Team ID 3359 zaten mevcut, ekleme yapılmadı.
# Team ID 46353 başarıyla eklendi.
# Team ID 2246 zaten mevcut, ekleme yapılmadı.
# Team ID 4909 başarıyla eklendi.
# Team ID 36255 başarıyla eklendi.
# Team ID 5222 başarıyla eklendi.
# Team ID 43576 zaten mevcut, ekleme yapılmadı.
# Team ID 36019 başarıyla eklendi.
# Team ID 37860 başarıyla eklendi.
# ...
#   warnings.warn(
# Match ID 12447945 başarıyla eklendi.
# Match ID 11990320 zaten mevcut, eklenmedi.
# UNIQUE constraint hatası! Match ID 12602372 zaten veritabanında mevcut.
# Match ID 11989731 zaten mevcut, eklenmedi.
# Match ID 11989724 zaten mevcut, eklenmedi.
# Match ID 11989729 zaten mevcut, eklenmedi.
# Match ID 12535167 zaten mevcut, eklenmedi.
# Match ID 12535165 zaten mevcut, eklenmedi.
# Match ID 12535171 zaten mevcut, eklenmedi.
# Match ID 12535162 zaten mevcut, eklenmedi.
# Match ID 12535163 zaten mevcut, eklenmedi.
# Match ID 12535153 zaten mevcut, eklenmedi.
# Match ID 12507479 zaten mevcut, eklenmedi.
# Match ID 12507487 zaten mevcut, eklenmedi.
# Match ID 12507476 zaten mevcut, eklenmedi.
# Match ID 12531636 zaten mevcut, eklenmedi.
# Match ID 11921879 zaten mevcut, eklenmedi.
# Match ID 11921875 zaten mevcut, eklenmedi.
# Match ID 11921904 zaten mevcut, eklenmedi.
# Match ID 11921890 zaten mevcut, eklenmedi.
# Match ID 11921891 zaten mevcut, eklenmedi.
# Match ID 11921892 başarıyla eklendi.
# Match ID 12177114 zaten mevcut, eklenmedi.
# Match ID 12177108 zaten mevcut, eklenmedi.
# Match ID 12177113 zaten mevcut, eklenmedi.
# Match ID 12177105 zaten mevcut, eklenmedi.
# Match ID 12085517 zaten mevcut, eklenmedi.
# Match ID 12085523 zaten mevcut, eklenmedi.
# Match ID 12085512 zaten mevcut, eklenmedi.
# Match ID 12444677 zaten mevcut, eklenmedi.
# Match ID 12444679 başarıyla eklendi.
# Match ID 12255986 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-30 16:15:00) while time zone support is active.
#   warnings.warn(
# Match ID 12255987 başarıyla eklendi.
# Match ID 12542699 zaten mevcut, eklenmedi.
# Match ID 11918212 başarıyla eklendi.
# Match ID 11989410 zaten mevcut, eklenmedi.
# Match ID 11989409 zaten mevcut, eklenmedi.
# Match ID 12448860 zaten mevcut, eklenmedi.
# Match ID 12448855 zaten mevcut, eklenmedi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-29 21:30:00) while time zone support is active.
#   warnings.warn(
# Match ID 12448865 başarıyla eklendi.
# Match ID 12494090 zaten mevcut, eklenmedi.
# Match ID 12494105 zaten mevcut, eklenmedi.
# Match ID 12494089 zaten mevcut, eklenmedi.
# Match ID 12494087 zaten mevcut, eklenmedi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-29 20:30:00) while time zone support is active.
#   warnings.warn(
# Match ID 12494094 başarıyla eklendi.
# Match ID 12394495 zaten mevcut, eklenmedi.
# Match ID 12486145 zaten mevcut, eklenmedi.
# Match ID 12486141 zaten mevcut, eklenmedi.
# Match ID 12486140 başarıyla eklendi.
# Match ID 12199075 zaten mevcut, eklenmedi.
# Match ID 12197015 zaten mevcut, eklenmedi.
# Match ID 12197014 zaten mevcut, eklenmedi.
# Match ID 12197010 başarıyla eklendi.
# Match ID 12197012 başarıyla eklendi.
# Match ID 12442086 zaten mevcut, eklenmedi.
# Match ID 12573165 başarıyla eklendi.
# Match ID 12573166 zaten mevcut, eklenmedi.
# Match ID 12573161 zaten mevcut, eklenmedi.
# Match ID 12573163 zaten mevcut, eklenmedi.
# Match ID 12178885 zaten mevcut, eklenmedi.
# Match ID 12178907 zaten mevcut, eklenmedi.
# Match ID 12178887 zaten mevcut, eklenmedi.
# Match ID 12178894 zaten mevcut, eklenmedi.
# Match ID 12178903 zaten mevcut, eklenmedi.
# Match ID 12178886 zaten mevcut, eklenmedi.
# Match ID 12613470 zaten mevcut, eklenmedi.
# Match ID 12538577 zaten mevcut, eklenmedi.
# Match ID 12580851 zaten mevcut, eklenmedi.
# Match ID 12615505 zaten mevcut, eklenmedi.
# Match ID 12538564 zaten mevcut, eklenmedi.
# Match ID 12565207 zaten mevcut, eklenmedi.
# Match ID 12541637 zaten mevcut, eklenmedi.
# Match ID 12543743 zaten mevcut, eklenmedi.
# Match ID 12585553 zaten mevcut, eklenmedi.
# Match ID 12615504 zaten mevcut, eklenmedi.
# Match ID 12360075 zaten mevcut, eklenmedi.
# Match ID 12618414 zaten mevcut, eklenmedi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-29 17:00:00) while time zone support is active.
#   warnings.warn(
# Match ID 12618822 başarıyla eklendi.
# Match ID 12580852 başarıyla eklendi.
# Match ID 12618824 başarıyla eklendi.
# Match ID 12612446 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-30 19:00:00) while time zone support is active.
#   warnings.warn(
# Match ID 12548608 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-30 20:00:00) while time zone support is active.
#   warnings.warn(
# Match ID 12548611 başarıyla eklendi.
# Match ID 12568934 başarıyla eklendi.
# Match ID 12444861 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-30 21:00:00) while time zone support is active.
#   warnings.warn(
# Match ID 12548607 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-30 21:30:00) while time zone support is active.
#   warnings.warn(
# Match ID 12568932 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-30 21:45:00) while time zone support is active.
#   warnings.warn(
# Match ID 12568929 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-30 18:00:00) while time zone support is active.
#   warnings.warn(
# Match ID 12571213 başarıyla eklendi.
# Match ID 12571933 başarıyla eklendi.
# Match ID 12571930 başarıyla eklendi.
# Match ID 12571932 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-30 22:00:00) while time zone support is active.
#   warnings.warn(
# Match ID 12571931 başarıyla eklendi.
# Match ID 11937212 zaten mevcut, eklenmedi.
# Match ID 11937209 zaten mevcut, eklenmedi.
# Match ID 11937208 zaten mevcut, eklenmedi.
# Match ID 11937221 zaten mevcut, eklenmedi.
# Match ID 11937220 zaten mevcut, eklenmedi.
# Match ID 11937219 zaten mevcut, eklenmedi.
# UNIQUE constraint hatası! Match ID 12584774 zaten veritabanında mevcut.
# Match ID 12178925 başarıyla eklendi.
# Match ID 12178912 başarıyla eklendi.
# Match ID 12178919 başarıyla eklendi.
# Match ID 12178916 başarıyla eklendi.
# Match ID 12307982 zaten mevcut, eklenmedi.
# Match ID 12178902 zaten mevcut, eklenmedi.
# Match ID 12178890 başarıyla eklendi.
# Match ID 12178888 başarıyla eklendi.
# Match ID 12290196 zaten mevcut, eklenmedi.
# Match ID 12290203 zaten mevcut, eklenmedi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-31 03:00:00) while time zone support is active.
#   warnings.warn(
# Match ID 12290199 başarıyla eklendi.
# Match ID 12060382 zaten mevcut, eklenmedi.
# Match ID 12021705 zaten mevcut, eklenmedi.
# Match ID 12528587 zaten mevcut, eklenmedi.
# Match ID 12528590 zaten mevcut, eklenmedi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-31 02:00:00) while time zone support is active.
#   warnings.warn(
# Match ID 12528593 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-31 04:10:00) while time zone support is active.
#   warnings.warn(
# Match ID 12528738 başarıyla eklendi.
# Match ID 12402393 zaten mevcut, eklenmedi.
# Match ID 12407764 zaten mevcut, eklenmedi.
# Match ID 12522381 zaten mevcut, eklenmedi.
# Match ID 12461569 zaten mevcut, eklenmedi.
# Match ID 12461572 zaten mevcut, eklenmedi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-30 17:30:00) while time zone support is active.
#   warnings.warn(
# Match ID 12461455 başarıyla eklendi.
# Match ID 12463094 başarıyla eklendi.
# Match ID 12463092 başarıyla eklendi.
# Match ID 12507917 zaten mevcut, eklenmedi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-30 23:00:00) while time zone support is active.
#   warnings.warn(
# Match ID 12507919 başarıyla eklendi.
# Match ID 12507911 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-31 03:30:00) while time zone support is active.
#   warnings.warn(
# Match ID 12507914 başarıyla eklendi.
# Match ID 12538492 zaten mevcut, eklenmedi.
# UNIQUE constraint hatası! Match ID 12538491 zaten veritabanında mevcut.
# Match ID 11907341 zaten mevcut, eklenmedi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-31 04:00:00) while time zone support is active.
#   warnings.warn(
# Match ID 12575529 başarıyla eklendi.
# Match ID 12575528 başarıyla eklendi.
# Match ID 12165795 başarıyla eklendi.
# Match ID 12165800 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-31 05:30:00) while time zone support is active.
#   warnings.warn(
# Match ID 12165803 başarıyla eklendi.
# Match ID 12468363 zaten mevcut, eklenmedi.
# Match ID 12468360 zaten mevcut, eklenmedi.
# Match ID 12468362 zaten mevcut, eklenmedi.
# Match ID 12468361 zaten mevcut, eklenmedi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-31 12:30:00) while time zone support is active.
#   warnings.warn(
# Match ID 12468359 başarıyla eklendi.
# Match ID 12468357 başarıyla eklendi.
# Match ID 12599393 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-31 13:30:00) while time zone support is active.
#   warnings.warn(
# Match ID 12468358 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-31 01:00:00) while time zone support is active.
#   warnings.warn(
# Match ID 12463154 başarıyla eklendi.
# Match ID 12463156 başarıyla eklendi.
# Match ID 12146736 zaten mevcut, eklenmedi.
# Match ID 12146735 zaten mevcut, eklenmedi.
# Match ID 12572441 başarıyla eklendi.
# Match ID 12572443 başarıyla eklendi.
# Match ID 12307964 zaten mevcut, eklenmedi.
# Match ID 12421725 zaten mevcut, eklenmedi.
# Match ID 12421716 zaten mevcut, eklenmedi.
# Match ID 12041152 başarıyla eklendi.
# UNIQUE constraint hatası! Match ID 12580909 zaten veritabanında mevcut.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-31 00:00:00) while time zone support is active.
#   warnings.warn(
# Match ID 12535364 başarıyla eklendi.
# Match ID 12447945 zaten mevcut, eklenmedi.
# Match ID 11921892 zaten mevcut, eklenmedi.
# Match ID 12444679 zaten mevcut, eklenmedi.
# Match ID 12255986 zaten mevcut, eklenmedi.
# Match ID 12255987 zaten mevcut, eklenmedi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-31 15:15:00) while time zone support is active.
#   warnings.warn(
# Match ID 12255985 başarıyla eklendi.
# Match ID 12255983 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-31 16:00:00) while time zone support is active.
#   warnings.warn(
# Match ID 12255978 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-31 00:06:00) while time zone support is active.
#   warnings.warn(
# Match ID 12618415 başarıyla eklendi.
# C:\Users\ahmet.yildirir\AppData\Local\Programs\Python\Python312\Lib\site-packages\django\db\models\fields\__init__.py:1595: RuntimeWarning: DateTimeField Match.startTimestamp received a naive datetime (2024-07-31 05:06:00) while time zone support is active.
#   warnings.warn(
# Match ID 12618418 başarıyla eklendi.
# Match ID 11918212 zaten mevcut, eklenmedi.
# Match ID 11989407 başarıyla eklendi.
# Match ID 12448865 zaten mevcut, eklenmedi.
# Match ID 12494094 zaten mevcut, eklenmedi.
# Match ID 12515235 başarıyla eklendi.
# Match ID 12515251 başarıyla eklendi.
# Match ID 12515226 başarıyla eklendi.
# Match ID 12515236 başarıyla eklendi.
# Match ID 12515228 başarıyla eklendi.
# Match ID 12515234 başarıyla eklendi.
# Match ID 12515237 başarıyla eklendi.
# Match ID 12515225 başarıyla eklendi.
# Match ID 12515231 başarıyla eklendi.
# Match ID 12515233 başarıyla eklendi.
# Match ID 12486140 zaten mevcut, eklenmedi.
# Match ID 12197010 zaten mevcut, eklenmedi.
# Match ID 12197012 zaten mevcut, eklenmedi.
# Match ID 12607076 başarıyla eklendi.
# Match ID 12573165 zaten mevcut, eklenmedi.
# Match ID 12618414 zaten mevcut, eklenmedi.
# Match ID 12618822 zaten mevcut, eklenmedi.
# Match ID 12580852 zaten mevcut, eklenmedi.
# Match ID 12618824 zaten mevcut, eklenmedi.
# Match ID 12612446 zaten mevcut, eklenmedi.
# Match ID 12624502 başarıyla eklendi.
# Match ID 12619949 başarıyla eklendi.
# Match ID 12615586 başarıyla eklendi.
# Match ID 12595657 başarıyla eklendi.
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
df['date'] = pd.to_datetime(df['startTimestamp']).dt.date
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df['date'] = pd.to_datetime(df['startTimestamp']).dt.date
#       2 df
#
# NameError: name 'df' is not defined
