# %%
import os
import django
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'Home.settings')
django.setup()
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
import pandas as pd
from basemodels.models import Match

# %%
data = Match.objects.all().values()
data_list = list(data)
df = pd.DataFrame(data_list)
df
# Out:
#              id            startTimestamp  \
# 0      10923226 2023-11-04 16:30:00+00:00
# 1      10923232 2023-11-06 18:10:00+00:00
# 2      10923238 2023-11-06 18:00:00+00:00
# 3      10923244 2023-11-05 16:30:00+00:00
# 4      10923250 2023-11-05 14:00:00+00:00
# ...         ...                       ...
# 18373  13088296 2024-11-09 16:40:00+00:00
# 18374  13088298 2024-11-10 22:20:00+00:00
# 18375  13088299 2024-11-09 20:45:00+00:00
# 18376  13091021 2024-11-09 21:05:00+00:00
# 18377  13094496 2024-11-10 15:00:00+00:00
#
#                                               slug  tournament_id  season_id  \
# 0                         ik-sirius-djurgardens-if             40      47730
# 1                                 aik-ifk-goteborg             40      47730
# 2                     varbergs-bois-ifk-norrkoping             40      47730
# 3                         degerfors-if-if-elfsborg             40      47730
# 4                               malmo-ff-bk-hacken             40      47730
# ...                                            ...            ...        ...
# 18373              san-telmo-san-martin-de-tucuman            703      57782
# 18374          quilmes-atletico-club-nueva-chicago            703      57782
# 18375  deportivo-madryn-gimnasia-y-esgrima-mendoza            703      57782
# 18376           real-cundinamarca-cucuta-deportivo           1238      57388
# 18377                   drogheda-united-derry-city            195      59994
#
#        roundInfo_round status_type  homeTeam_id  awayTeam_id  \
# 0                   29    finished         1759         1793
# 1                   29    finished         1761         1764
# 2                   29    finished         1769         7101
# 3                   29    finished         1762         1807
# 4                   29    finished         1760         1892
# ...                ...         ...          ...          ...
# 18373                2    finished       213361        23950
# 18374                2    finished         4936         3200
# 18375                2    finished       188441       222120
# 18376                3    finished         6108       484422
# 18377               29    finished         3180         3170
#
#        homeScore_current  homeScore_period1  homeScore_period2  \
# 0                      2                  1                  1
# 1                      1                  1                  0
# 2                      4                  0                  4
# 3                      2                  0                  2
# 4                      4                  1                  3
# ...                  ...                ...                ...
# 18373                  1                  0                  1
# 18374                  0                  0                  0
# 18375                  3                  2                  1
# 18376                  1                  0                  1
# 18377                  2                  1                  1
#
#        homeScore_normaltime  awayScore_current  awayScore_period1  \
# 0                         2                  4                  1
# 1                         1                  1                  0
# 2                         4                  3                  2
# 3                         2                  2                  1
# 4                         4                  2                  1
# ...                     ...                ...                ...
# 18373                     1                  2                  0
# 18374                     0                  0                  0
# 18375                     3                  1                  1
# 18376                     1                  0                  0
# 18377                     2                  0                  0
#
#        awayScore_period2  awayScore_normaltime
# 0                      3                     4
# 1                      1                     1
# 2                      1                     3
# 3                      1                     2
# 4                      1                     2
# ...                  ...                   ...
# 18373                  2                     2
# 18374                  0                     0
# 18375                  0                     1
# 18376                  0                     0
# 18377                  0                     0
#
# [18378 rows x 17 columns]

# %%
dfx = df[df["season_id"]==63814]
dfx
# Out:
#              id            startTimestamp                           slug  \
# 11737  12528185 2024-08-11 16:15:00+00:00          sivasspor-trabzonspor
# 11738  12528186 2024-08-10 18:45:00+00:00     adana-demirspor-fenerbahce
# 11739  12528187 2024-08-12 18:00:00+00:00  basaksehir-fk-caykur-rizespor
# 11740  12528188 2024-08-10 16:15:00+00:00            kasimpasa-konyaspor
# 11741  12528189 2024-08-09 18:00:00+00:00          hatayspor-galatasaray
# ...         ...                       ...                            ...
# 11969  12530884 2024-10-20 16:00:00+00:00          samsunspor-fenerbahce
# 11970  12530885 2024-10-21 17:00:00+00:00         bodrum-caykur-rizespor
# 11971  12530886 2024-10-19 16:00:00+00:00        galatasaray-antalyaspor
# 11972  12530887 2024-10-20 13:00:00+00:00             konyaspor-besiktas
# 11973  12530888 2024-10-20 16:00:00+00:00           alanyaspor-kasimpasa
#
#        tournament_id  season_id  roundInfo_round status_type  homeTeam_id  \
# 11737             52      63814                1    finished         3076
# 11738             52      63814                1    finished         3052
# 11739             52      63814                1    finished         3064
# 11740             52      63814                1    finished         6063
# 11741             52      63814                1    finished         3061
# ...              ...        ...              ...         ...          ...
# 11969             52      63814                9    finished         3053
# 11970             52      63814                9    finished       202390
# 11971             52      63814                9    finished         3056
# 11972             52      63814                9    finished         3050
# 11973             52      63814                9    finished         6362
#
#        awayTeam_id  homeScore_current  homeScore_period1  homeScore_period2  \
# 11737         3051                  0                  0                  0
# 11738         3101                  1                  1                  0
# 11739         3086                  1                  1                  0
# 11740         3085                  2                  0                  2
# 11741         3091                  2                  0                  2
# ...            ...                ...                ...                ...
# 11969         3052                  2                  0                  2
# 11970         3064                  0                  0                  0
# 11971         3061                  0                  0                  0
# 11972         3085                  2                  2                  0
# 11973         6063                  1                  0                  1
#
#        homeScore_normaltime  awayScore_current  awayScore_period1  \
# 11737                     0                  0                  0
# 11738                     1                  0                  0
# 11739                     1                  1                  1
# 11740                     2                  3                  1
# 11741                     2                  1                  0
# ...                     ...                ...                ...
# 11969                     2                  2                  1
# 11970                     0                  1                  0
# 11971                     0                  3                  1
# 11972                     2                  0                  0
# 11973                     1                  2                  2
#
#        awayScore_period2  awayScore_normaltime
# 11737                  0                     0
# 11738                  0                     0
# 11739                  0                     1
# 11740                  2                     3
# 11741                  1                     1
# ...                  ...                   ...
# 11969                  1                     2
# 11970                  1                     1
# 11971                  2                     3
# 11972                  0                     0
# 11973                  0                     2
#
# [108 rows x 17 columns]

# %%
dfx['startTimestamp'] = pd.to_datetime(dfx['startTimestamp']).dt.tz_localize(None)
dfx.to_excel("Turkey_Lig.xlsx")
# Out:
# C:\Users\ahmet.yildirir\AppData\Local\Temp\ipykernel_21532\3103925888.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfx['startTimestamp'] = pd.to_datetime(dfx['startTimestamp']).dt.tz_localize(None)
